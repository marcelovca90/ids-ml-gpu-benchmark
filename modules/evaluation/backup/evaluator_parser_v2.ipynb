# %%
from datetime import datetime
import json
import numpy as np
import pandas as pd

# Show all rows
pd.set_option('display.max_rows', None)

# Optional: prevent column truncation
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 0)  # Auto-detect width

def now():
    now = datetime.now()
    yyyymmdd_hhmmss_part = now.strftime('%Y-%m-%d %H:%M:%S')
    ms_part = f'{int(now.microsecond / 1000):03d}'
    return f'{yyyymmdd_hhmmss_part},{ms_part}'

def get_full_shape(df_filename):
    df = pd.read_parquet(df_filename)
    n_rows, n_cols = df.shape
    n_cols -= 1 # discard target
    n_labels = df['label'].nunique()
    return n_rows, n_cols, n_labels

def get_dtypes(df_filename):
    df = pd.read_parquet(df_filename).drop(columns=['label'])
    dtypes = set([str(x) for x in df.dtypes.tolist()])

    numerical_types = {'int8', 'int16', 'int32', 'int64',
                       'uint8', 'uint16', 'uint32', 'uint64',
                       'float16', 'float32', 'float64'}
    categorical_types = {'category'}

    if dtypes.issubset(numerical_types):
        feature_type = 'numerical'
    elif dtypes.issubset(categorical_types):
        feature_type = 'categorical'
    elif dtypes & numerical_types and dtypes & categorical_types:
        feature_type = 'mixed'
    else:
        feature_type = 'unknown'  # catch-all for object, bool, etc.

    return dtypes, feature_type

# %%
from pathlib import Path
from time import sleep
from tqdm.notebook import tqdm
import os
import papermill as pm

# %%
base_folder = Path("/home/automl/git/iot-threat-classifier/2025-07-05/Input_Multiclass")

file_sizes = {}
shapes = {}
dtypes = {}
feature_types = {}

# Find all .parquet files recursively
parquet_files = list(base_folder.rglob("*.parquet"))

# Sort by file size (ascending)
parquet_files_sorted = sorted(parquet_files, key=lambda p: os.path.getsize(p))

# Iterate
for file in tqdm(parquet_files_sorted, desc='File', leave='False'):

    try:
        file_sizes[file.stem] = os.path.getsize(file) / 1024 / 1024
        shapes[file.stem] = get_full_shape(file)
        _dtypes, _feature_types = get_dtypes(file)
        dtypes[file.stem] = _dtypes
        feature_types[file.stem] = _feature_types
        
    except (ValueError, Exception) as e:
        tqdm.write(f'[{now()}] ERROR      | FILE = {str(file.stem):<64} | EXCEPTION = {e}')
# Out:
# File:   0%|          | 0/75 [00:00<?, ?it/s]

# %%
custom_order = [
    "CIC_IDS_2017_Multiclass",
    "CIC_IOT_Dataset2023_Multiclass",
    "IoT_23_Multiclass",
    "IoT_Network_Intrusion_Macro_Multiclass",
    "IoT_Network_Intrusion_Micro_Multiclass",
    "KDD_Cup_1999_Multiclass",
    "UNSW_NB15_Multiclass",
    "BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass",
    "BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass",
    "BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass",
    "BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass",
    "BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_and_Testing_Multiclass",
    "BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass",
    "BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass",
    "BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass",
    "BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass",
    "BoT_IoT_Macro_Multiclass",
    "BoT_IoT_Micro_Multiclass",
    "CICAPT_IIoT_Phase1_Macro_Multiclass", # nok
    "CICAPT_IIoT_Phase1_Micro_Multiclass", # nok
    "CICAPT_IIoT_Phase2_Macro_Multiclass",
    "CICAPT_IIoT_Phase2_Micro_Multiclass",
    "CICEVSE2024_EVSE-A_Macro_Multiclass",
    "CICEVSE2024_EVSE-A_Micro_Multiclass",
    "CICEVSE2024_EVSE-B_Macro_Multiclass",
    "CICEVSE2024_EVSE-B_Micro_Multiclass",
    "CICIoMT2024_Bluetooth_Multiclass",
    "CICIoMT2024_WiFi_and_MQTT_Multiclass",
    "CICIoV2024_Decimal_Macro_Multiclass",
    "CICIoV2024_Decimal_Micro_Multiclass",
    "EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass",
    "EDGE-IIOTSET_ML-EdgeIIoT_Multiclass",
    "MQTT_IoT_IDS2020_BiflowFeatures_Multiclass",
    "MQTT_IoT_IDS2020_PacketFeatures_Multiclass",
    "MQTT_IoT_IDS2020_UniflowFeatures_Multiclass",
    "NIDS_CIC-BoT-IoT_Multiclass",
    "NIDS_CIC-ToN-IoT_Multiclass",
    "NIDS_NF-BoT-IoT_Multiclass",
    "NIDS_NF-BoT-IoT-v2_Multiclass",
    "NIDS_NF-BoT-IoT-v3_Multiclass",
    "NIDS_NF-CICIDS2018-v3_Multiclass",
    "NIDS_NF-CSE-CIC-IDS2018_Multiclass",
    "NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass",
    "NIDS_NF-ToN-IoT_Multiclass",
    "NIDS_NF-ToN-IoT-v2_Multiclass",
    "NIDS_NF-ToN-IoT-v3_Multiclass",
    "NIDS_NF-UNSW-NB15_Multiclass",
    "NIDS_NF-UNSW-NB15-v2_Multiclass",
    "NIDS_NF-UNSW-NB15-v3_Multiclass",
    "NIDS_NF-UQ-NIDS_Multiclass",
    "NIDS_NF-UQ-NIDS-v2_Multiclass",
    "N_BaIoT_Danmini_Doorbell_Multiclass",
    "N_BaIoT_Ecobee_Thermostat_Multiclass",
    "N_BaIoT_Ennio_Doorbell_Multiclass",
    "N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass",
    "N_BaIoT_Provision_PT_737E_Security_Camera_Multiclass",
    "N_BaIoT_Provision_PT_838_Security_Camera_Multiclass",
    "N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass",
    "N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camera_Multiclass",
    "N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camera_Multiclass",
    "ToN_IoT_IoT_Fridge_Multiclass",
    "ToN_IoT_IoT_GPS_Tracker_Multiclass",
    "ToN_IoT_IoT_Garage_Door_Multiclass",
    "ToN_IoT_IoT_Modbus_Multiclass",
    "ToN_IoT_IoT_Motion_Light_Multiclass", # nok
    "ToN_IoT_IoT_Thermostat_Multiclass",
    "ToN_IoT_IoT_Weather_Multiclass",
    "ToN_IoT_Linux_Disk_Multiclass",
    "ToN_IoT_Linux_Memory_Multiclass",
    "ToN_IoT_Linux_Process_Multiclass",
    "ToN_IoT_Network_Multiclass",
    "ToN_IoT_Windows_10_Multiclass",
    "ToN_IoT_Windows_7_Multiclass"
]

# %%
base_folder = Path("/home/automl/git/iot-threat-classifier/2025-07-05/Input_Multiclass")

metrics_folder = Path(str(base_folder).replace('/Input_Multiclass', '/Output_Multiclass/100_pct'))

def get_metrics(dataset_name):
    metrics_filename = os.path.join(
        metrics_folder, f'{dataset_name}_complexity.json'
    )
    with open(metrics_filename, 'r', encoding='utf-8') as fp:
        metrics = json.load(fp)
    return metrics

def get_overall_difficulty(dataset_name):
    with open('df_ordered.json', 'r', encoding='utf-8') as fp:
        metrics = json.load(fp)
    return metrics.get(dataset_name, {}).get('overall_difficulty', np.nan)

print(get_overall_difficulty('ToN_IoT_Windows_7_Multiclass'))
# Out:
# 0.4691121808

# %%
# Build the DataFrame
df_raw = pd.DataFrame({
    'size_mb': file_sizes,
    'samples': {k: v[0] for k, v in shapes.items()}, 
    'features': {k: v[1] for k, v in shapes.items()},
    'classes': {k: v[2] for k, v in shapes.items()},
    'dtypes': dtypes,
    'feature_types': feature_types
})

# Set index using the row labels (i.e., filenames)
df_raw.index.name = "filename"

df_raw['overall_difficulty'] = df_raw.index.to_series().apply(get_overall_difficulty)

# Filter custom_order to only include datasets that exist in the DataFrame
valid_order = [d for d in custom_order if d in df_raw.index]

# Reorder using the filtered list
df_raw = df_raw.loc[valid_order]

# Now you can style it
input_df = df_raw.style.format({
    'size_mb': '{:.2f}',
    'samples': '{:,.0f}'
})

input_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_ecad3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ecad3_level0_col0" class="col_heading level0 col0" >size_mb</th>
#       <th id="T_ecad3_level0_col1" class="col_heading level0 col1" >samples</th>
#       <th id="T_ecad3_level0_col2" class="col_heading level0 col2" >features</th>
#       <th id="T_ecad3_level0_col3" class="col_heading level0 col3" >classes</th>
#       <th id="T_ecad3_level0_col4" class="col_heading level0 col4" >dtypes</th>
#       <th id="T_ecad3_level0_col5" class="col_heading level0 col5" >feature_types</th>
#       <th id="T_ecad3_level0_col6" class="col_heading level0 col6" >overall_difficulty</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >filename</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecad3_level0_row0" class="row_heading level0 row0" >CIC_IDS_2017_Multiclass</th>
#       <td id="T_ecad3_row0_col0" class="data row0 col0" >48.12</td>
#       <td id="T_ecad3_row0_col1" class="data row0 col1" >1,250,066</td>
#       <td id="T_ecad3_row0_col2" class="data row0 col2" >70</td>
#       <td id="T_ecad3_row0_col3" class="data row0 col3" >15</td>
#       <td id="T_ecad3_row0_col4" class="data row0 col4" >{'int32', 'int64', 'category'}</td>
#       <td id="T_ecad3_row0_col5" class="data row0 col5" >mixed</td>
#       <td id="T_ecad3_row0_col6" class="data row0 col6" >0.516218</td>
#     </tr>
#     <tr>
#       <th id="T_ecad3_level0_row1" class="row_heading level0 row1" >CIC_IOT_Dataset2023_Multiclass</th>
#       <td id="T_ecad3_row1_col0" class="data row1 col0" >103.47</td>
#       <td id="T_ecad3_row1_col1" class="data row1 col1" >4,487,800</td>
#       <td id="T_ecad3_row1_col2" class="data row1 col2" >39</td>
#       <td id="T_ecad3_row1_col3" class="data row1 col3" >35</td>
#       <td id="T_ecad3_row1_col4" class="data row1 col4" >{'int64', 'category', 'float32', 'int32', 'float64'}</td>
#       <td id="T_ecad3_row1_col5" class="data row1 col5" >mixed</td>
#       <td id="T_ecad3_row1_col6" class="data row1 col6" >0.463669</td>
#     </tr>
#     <tr>
#       <th id="T_ecad3_level0_row2" class="row_heading level0 row2" >IoT_23_Multiclass</th>
#       <td id="T_ecad3_row2_col0" class="data row2 col0" >1.98</td>
#       <td id="T_ecad3_row2_col1" class="data row2 col1" >363,889</td>
#       <td id="T_ecad3_row2_col2" class="data row2 col2" >12</td>
#       <td id="T_ecad3_row2_col3" class="data row2 col3" >16</td>
#       <td id="T_ecad3_row2_col4" class="data row2 col4" >{'float32', 'int32', 'category'}</td>
#       <td id="T_ecad3_row2_col5" class="data row2 col5" >mixed</td>
#       <td id="T_ecad3_row2_col6" class="data row2 col6" >0.654002</td>
#     </tr>
#     <tr>
#       <th id="T_ecad3_level0_row3" class="row_heading level0 row3" >IoT_Network_Intrusion_Macro_Multiclass</th>
#       <td id="T_ecad3_row3_col0" class="data row3 col0" >0.39</td>
#       <td id="T_ecad3_row3_col1" class="data row3 col1" >78,938</td>
#       <td id="T_ecad3_row3_col2" class="data row3 col2" >24</td>
#       <td id="T_ecad3_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_ecad3_row3_col4" class="data row3 col4" >{'int32', 'float64', 'category'}</td>
#       <td id="T_ecad3_row3_col5" class="data row3 col5" >mixed</td>
#       <td id="T_ecad3_row3_col6" class="data row3 col6" >0.581516</td>
#     </tr>
#     <tr>
#       <th id="T_ecad3_level0_row4" class="row_heading level0 row4" >IoT_Network_Intrusion_Micro_Multiclass</th>
#       <td id="T_ecad3_row4_col0" class="data row4 col0" >0.39</td>
#       <td id="T_ecad3_row4_col1" class="data row4 col1" >78,963</td>
#       <td id="T_ecad3_row4_col2" class="data row4 col2" >24</td>
#       <td id="T_ecad3_row4_col3" class="data row4 col3" >11</td>
#       <td id="T_ecad3_row4_col4" class="data row4 col4" >{'int32', 'float64', 'category'}</td>
#       <td id="T_ecad3_row4_col5" class="data row4 col5" >mixed</td>
#       <td id="T_ecad3_row4_col6" class="data row4 col6" >0.578433</td>
#     </tr>
#     <tr>
#       <th id="T_ecad3_level0_row5" class="row_heading level0 row5" >KDD_Cup_1999_Multiclass</th>
#       <td id="T_ecad3_row5_col0" class="data row5 col0" >6.02</td>
#       <td id="T_ecad3_row5_col1" class="data row5 col1" >1,074,992</td>
#       <td id="T_ecad3_row5_col2" class="data row5 col2" >40</td>
#       <td id="T_ecad3_row5_col3" class="data row5 col3" >23</td>
#       <td id="T_ecad3_row5_col4" class="data row5 col4" >{'int32', 'int64', 'float32', 'category'}</td>
#       <td id="T_ecad3_row5_col5" class="data row5 col5" >mixed</td>
#       <td id="T_ecad3_row5_col6" class="data row5 col6" >0.533156</td>
#     </tr>
#     <tr>
#       <th id="T_ecad3_level0_row6" class="row_heading level0 row6" >UNSW_NB15_Multiclass</th>
#       <td id="T_ecad3_row6_col0" class="data row6 col0" >46.29</td>
#       <td id="T_ecad3_row6_col1" class="data row6 col1" >1,944,769</td>
#       <td id="T_ecad3_row6_col2" class="data row6 col2" >45</td>
#       <td id="T_ecad3_row6_col3" class="data row6 col3" >11</td>
#       <td id="T_ecad3_row6_col4" class="data row6 col4" >{'int64', 'category', 'float32', 'int32', 'float64'}</td>
#       <td id="T_ecad3_row6_col5" class="data row6 col5" >mixed</td>
#       <td id="T_ecad3_row6_col6" class="data row6 col6" >0.597476</td>
#     </tr>
#     <tr>
#       <th id="T_ecad3_level0_row7" class="row_heading level0 row7" >BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass</th>
#       <td id="T_ecad3_row7_col0" class="data row7 col0" >12.34</td>
#       <td id="T_ecad3_row7_col1" class="data row7 col1" >292,898</td>
#       <td id="T_ecad3_row7_col2" class="data row7 col2" >73</td>
#       <td id="T_ecad3_row7_col3" class="data row7 col3" >12</td>
#       <td id="T_ecad3_row7_col4" class="data row7 col4" >{'int64', 'category', 'float32', 'int32', 'float64'}</td>
#       <td id="T_ecad3_row7_col5" class="data row7 col5" >mixed</td>
#       <td id="T_ecad3_row7_col6" class="data row7 col6" >0.572254</td>
#     </tr>
#     <tr>
#       <th id="T_ecad3_level0_row8" class="row_heading level0 row8" >BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass</th>
#       <td id="T_ecad3_row8_col0" class="data row8 col0" >22.41</td>
#       <td id="T_ecad3_row8_col1" class="data row8 col1" >1,175,500</td>
#       <td id="T_ecad3_row8_col2" class="data row8 col2" >69</td>
#       <td id="T_ecad3_row8_col3" class="data row8 col3" >12</td>
#       <td id="T_ecad3_row8_col4" class="data row8 col4" >{'int64', 'category', 'float32', 'int32', 'float64'}</td>
#       <td id="T_ecad3_row8_col5" class="data row8 col5" >mixed</td>
#       <td id="T_ecad3_row8_col6" class="data row8 col6" >0.519524</td>
#     </tr>
#     <tr>
#       <th id="T_ecad3_level0_row9" class="row_heading level0 row9" >BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass</th>
#       <td id="T_ecad3_row9_col0" class="data row9 col0" >10.50</td>
#       <td id="T_ecad3_row9_col1" class="data row9 col1" >258,558</td>
#       <td id="T_ecad3_row9_col2" class="data row9 col2" >73</td>
#       <td id="T_ecad3_row9_col3" class="data row9 col3" >15</td>
#       <td id="T_ecad3_row9_col4" class="data row9 col4" >{'int32', 'int64', 'float32', 'category'}</td>
#       <td id="T_ecad3_row9_col5" class="data row9 col5" >mixed</td>
#       <td id="T_ecad3_row9_col6" class="data row9 col6" >0.546486</td>
#     </tr>
#     <tr>
#       <th id="T_ecad3_level0_row10" class="row_heading level0 row10" >BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass</th>
#       <td id="T_ecad3_row10_col0" class="data row10 col0" >6.60</td>
#       <td id="T_ecad3_row10_col1" class="data row10 col1" >91,787</td>
#       <td id="T_ecad3_row10_col2" class="data row10 col2" >72</td>
#       <td id="T_ecad3_row10_col3" class="data row10 col3" >2</td>
#       <td id="T_ecad3_row10_col4" class="data row10 col4" >{'int32', 'int64', 'float32', 'category'}</td>
#       <td id="T_ecad3_row10_col5" class

# %%
def format_and_pad_all_columns(df):
    df_str = df.copy()

    # Format columns by type
    for col in df_str.columns:
        if pd.api.types.is_float_dtype(df_str[col]):
            if 'time' in col:
                df_str[col] = df_str[col].map(lambda x: f"{x:,.1f}")
            elif 'size' in col:
                df_str[col] = df_str[col].map(lambda x: f"{x:,.2f}")
            else:
                df_str[col] = df_str[col].map(lambda x: f"{x:,.3f}")
        elif pd.api.types.is_integer_dtype(df_str[col]):
            df_str[col] = df_str[col].map(lambda x: f"{x:,}")
        else:
            df_str[col] = df_str[col].astype(str)

    # Pad each column with spaces to align visually
    for col in df_str.columns:
        max_len = df_str[col].map(len).max()
        df_str[col] = df_str[col].map(lambda x: x.ljust(max_len))

    return df_str

# Apply to your DataFrame
df_pretty = format_and_pad_all_columns(df_raw.loc[custom_order]).drop(columns=['size_mb', 'dtypes'])

# df_pretty.index = df_pretty.index.str.replace('_Multiclass', '', regex=False)

# Export to .tex with aligned source formatting
# df_pretty.to_latex("table_2.tex", header=True, index=True, escape=False)
with open("table_2.tex", "w") as f:
    f.write(df_pretty.to_string())

df_pretty
# Out:
#                                                        samples features  \
# filename
# CIC_IDS_2017_Multiclass                             1,250,066       70
# CIC_IOT_Dataset2023_Multiclass                      4,487,800       39
# IoT_23_Multiclass                                   363,889         12
# IoT_Network_Intrusion_Macro_Multiclass              78,938          24
# IoT_Network_Intrusion_Micro_Multiclass              78,963          24
# KDD_Cup_1999_Multiclass                             1,074,992       40
# UNSW_NB15_Multiclass                                1,944,769       45
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass           292,898         73
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass      1,175,500       69
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass              258,558         73
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass               91,787          72
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...  178,424         71
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass          89,209          73
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass       1,966,383       69
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass            711,664         71
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass            331,398         69
# BoT_IoT_Macro_Multiclass                            1,704,066       20
# BoT_IoT_Micro_Multiclass                            1,705,588       20
# CICAPT_IIoT_Phase1_Macro_Multiclass                 10,260,159      48
# CICAPT_IIoT_Phase1_Micro_Multiclass                 10,260,159      48
# CICAPT_IIoT_Phase2_Macro_Multiclass                 8,209,431       48
# CICAPT_IIoT_Phase2_Micro_Multiclass                 8,209,431       48
# CICEVSE2024_EVSE-A_Macro_Multiclass                 366,517         68
# CICEVSE2024_EVSE-A_Micro_Multiclass                 366,517         68
# CICEVSE2024_EVSE-B_Macro_Multiclass                 286,645         68
# CICEVSE2024_EVSE-B_Micro_Multiclass                 286,675         68
# CICIoMT2024_Bluetooth_Multiclass                    747             7
# CICIoMT2024_WiFi_and_MQTT_Multiclass                1,924,242       44
# CICIoV2024_Decimal_Macro_Multiclass                 3,577           8
# CICIoV2024_Decimal_Micro_Multiclass                 3,579           8
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                1,606,411       45
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                 151,908         41
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass          39,418          28
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass          1,744           17
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass         63,600          16
# NIDS_CIC-BoT-IoT_Multiclass                         1,502,919       79
# NIDS_CIC-ToN-IoT_Multiclass                         169,545         71
# NIDS_NF-BoT-IoT_Multiclass                          94,169          10
# NIDS_NF-BoT-IoT-v2_Multiclass                       143,087         38
# NIDS_NF-BoT-IoT-v3_Multiclass                       682,102         46
# NIDS_NF-CICIDS2018-v3_Multiclass                    8,184,198       45
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                  391,022         10
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass               1,804,117       37
# NIDS_NF-ToN-IoT_Multiclass                          672,305         10
# NIDS_NF-ToN-IoT-v2_Multiclass                       1,165,794       38
# NIDS_NF-ToN-IoT-v3_Multiclass                       4,213,539       46
# NIDS_NF-UNSW-NB15_Multiclass                        426,380         10
# NIDS_NF-UNSW-NB15-v2_Multiclass                     145,077         38
# NIDS_NF-UNSW-NB15-v3_Multiclass                     1,176,457       46
# NIDS_NF-UQ-NIDS_Multiclass                          592,809         10
# NIDS_NF-UQ-NIDS-v2_Multiclass                       3,204,691       38
# N_BaIoT_Danmini_Doorbell_Multiclass                 704,874         115
# N_BaIoT_Ecobee_Thermostat_Multiclass                540,971         115
# N_BaIoT_Ennio_Doorbell_Multiclass                   146,043         115
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass     786,204         115
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...  447,068         115
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...  473,360         115
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass        164,375         115
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...  510,556         115
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...  548,938         115
# ToN_IoT_IoT_Fridge_Multiclass                       1,057           2
# ToN_IoT_IoT_GPS_Tracker_Multiclass                  639             2
# ToN_IoT_IoT_Garage_Door_Multiclass                  18              2
# ToN_IoT_IoT_Modbus_Multiclass                       112,839         4
# ToN_IoT_IoT_Motion_Light_Multiclass                 16              2
# ToN_IoT_IoT_Thermostat_Multiclass                   40,651          2
# ToN_IoT_IoT_Weather_Multiclass                      571,535         3
# ToN_IoT_Linux_Disk_Multiclass                       24,158          5
# ToN_IoT_Linux_Memory_Multiclass                     82,722          9
# ToN_IoT_Linux_Process_Multiclass                    20,919          12
# ToN_IoT_Network_Multiclass                          470,405         40
# ToN_IoT_Windows_10_Multiclass                       35,214          113
# ToN_IoT_Windows_7_Multiclass                        28,097          104
#
#                                                    classes feature_types  \
# filename
# CIC_IDS_2017_Multiclass                                 15   mixed
# CIC_IOT_Dataset2023_Multiclass                          35   mixed
# IoT_23_Multiclass                                       16   mixed
# IoT_Network_Intrusion_Macro_Multiclass                  5    mixed
# IoT_Network_Intrusion_Micro_Multiclass                  11   mixed
# KDD_Cup_1999_Multiclass                                 23   mixed
# UNSW_NB15_Multiclass                                    11   mixed
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass               12   mixed
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass          12   mixed
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                  15   mixed
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                   2    mixed
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...      5    mixed
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass              9    mixed
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass           5    mixed
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                4    mixed
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                5    mixed
# BoT_IoT_Macro_Multiclass                                5    mixed
# BoT_IoT_Micro_Multiclass                                11   mixed
# CICAPT_IIoT_Phase1_Macro_Multiclass                     1    mixed
# CICAPT_IIoT_Phase1_Micro_Multiclass                     1    mixed
# CICAPT_IIoT_Phase2_Macro_Multiclass                     26   mixed
# CICAPT_IIoT_Phase2_Micro_Multiclass                     9    mixed
# CICEVSE2024_EVSE-A_Macro_Multiclass                     16   mixed
# CICEVSE2024_EVSE-A_Micro_Multiclass                     28   mixed
# CICEVSE2024_EVSE-B_Macro_Multiclass                     21   mixed
# CICEVSE2024_EVSE-B_Micro_Multiclass                     31   mixed
# CICIoMT2024_Bluetooth_Multiclass                        2    numerical
# CICIoMT2024_WiFi_and_MQTT_Multiclass                    19   mixed
# CICIoV2024_Decimal_Macro_Multiclass                     3    numerical
# CICIoV2024_Decimal_Micro_Multiclass                     6    numerical
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                    15   mixed
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                     15   mixed
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass              5    mixed
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass              5    mixed
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass             5    mixed
# NIDS_CIC-BoT-IoT_Multiclass                             5    mixed
# NIDS_CIC-ToN-IoT_Multiclass                             10   mixed
# NIDS_NF-BoT-IoT_Multiclass                              5    mixed
# NIDS_NF-BoT-IoT-v2_Multiclass                           5    mixed
# NIDS_NF-BoT-IoT-v3_Multiclass                           5    mixed
# NIDS_NF-CICIDS2018-v3_Multiclass                        15   mixed
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                      15   mixed
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                   15   mixed
# NIDS_NF-ToN-IoT_Multiclass                              10   mixed
# NIDS_NF-ToN-IoT-v2_Multiclass                           10   mixed
# NIDS_NF-ToN-IoT-v3_Multiclass                           10   mixed
# NIDS_NF-UNSW-NB15_Multiclass                            10   mixed
# NIDS_NF-UNSW-NB15-v2_Multiclass                         10   mixed
# NIDS_NF-UNSW-NB15-v3_Multiclass                         10   mixed
# NIDS_NF-UQ-NIDS_Multiclass                              21   mixed
# NIDS_NF-UQ-NIDS-v2_Multiclass                           21   mixed
# N_BaIoT_Danmini_Doorbell_Multiclass                     11   mixed
# N_BaIoT_Ecobee_Thermostat_Multiclass                    11   mixed
# N_BaIoT_Ennio_Doorbell_Multiclass                       6    mixed
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass         11   mixed
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...      11   mixed
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...      11   mixed
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass            6    mixed
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...      11   mixed
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...      11   mixed
# ToN_IoT_IoT_Fridge_Multiclass                           7    mixed
# ToN_IoT_IoT_GPS_Tracker_Multiclass                      8    categorical
# ToN_IoT_IoT_Garage_Door_Multiclass                      8    categorical
# ToN_IoT_IoT_Modbus_Multiclass                           6    numerical
# ToN_IoT_IoT_Motion_Light_Multiclass                     8    mixed
# ToN_IoT_IoT_Thermostat_Multiclass                       7    numerical
# ToN_IoT_IoT_Weather_Multiclass                          8    numerical
# ToN_IoT_Linux_Disk_Multiclass                           8    mixed
# ToN_IoT_Linux_Memory_Multiclass                         6    mixed
# ToN_IoT_Linux_Process_Multiclass                        8    mixed
# ToN_IoT_Network_Multiclass                              10   mixed
# ToN_IoT_Windows_10_Multiclass                           8    mixed
# ToN_IoT_Windows_7_Multiclass                            8    mixed
#
#                                                    overall_difficulty
# filename
# CIC_IDS_2017_Multiclass                                         0.516
# CIC_IOT_Dataset2023_Multiclass                                  0.464
# IoT_23_Multiclass                                               0.654
# IoT_Network_Intrusion_Macro_Multiclass                          0.582
# IoT_Network_Intrusion_Micro_Multiclass                          0.578
# KDD_Cup_1999_Multiclass                                         0.533
# UNSW_NB15_Multiclass                                            0.597
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                       0.572
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                  0.520
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                          0.546
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                           0.461
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...              0.492
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                      0.594
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                   0.361
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                        0.548
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                        0.570
# BoT_IoT_Macro_Multiclass                                        0.619
# BoT_IoT_Micro_Multiclass                                        0.567
# CICAPT_IIoT_Phase1_Macro_Multiclass                             nan
# CICAPT_IIoT_Phase1_Micro_Multiclass                             nan
# CICAPT_IIoT_Phase2_Macro_Multiclass                             0.517
# CICAPT_IIoT_Phase2_Micro_Multiclass                             0.518
# CICEVSE2024_EVSE-A_Macro_Multiclass                             0.570
# CICEVSE2024_EVSE-A_Micro_Multiclass                             0.419
# CICEVSE2024_EVSE-B_Macro_Multiclass                             0.504
# CICEVSE2024_EVSE-B_Micro_Multiclass                             0.479
# CICIoMT2024_Bluetooth_Multiclass                                0.539
# CICIoMT2024_WiFi_and_MQTT_Multiclass                            0.398
# CICIoV2024_Decimal_Macro_Multiclass                             0.590
# CICIoV2024_Decimal_Micro_Multiclass                             0.581
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                            0.526
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                             0.536
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                      0.429
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                      0.507
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                     0.467
# NIDS_CIC-BoT-IoT_Multiclass                                     0.595
# NIDS_CIC-ToN-IoT_Multiclass                                     0.465
# NIDS_NF-BoT-IoT_Multiclass                                      0.641
# NIDS_NF-BoT-IoT-v2_Multiclass                                   0.537
# NIDS_NF-BoT-IoT-v3_Multiclass                                   0.576
# NIDS_NF-CICIDS2018-v3_Multiclass                                0.527
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                              0.550
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                           0.517
# NIDS_NF-ToN-IoT_Multiclass                                      0.636
# NIDS_NF-ToN-IoT-v2_Multiclass                                   0.583
# NIDS_NF-ToN-IoT-v3_Multiclass                                   0.551
# NIDS_NF-UNSW-NB15_Multiclass                                    0.628
# NIDS_NF-UNSW-NB15-v2_Multiclass                                 0.599
# NIDS_NF-UNSW-NB15-v3_Multiclass                                 0.544
# NIDS_NF-UQ-NIDS_Multiclass                                      0.620
# NIDS_NF-UQ-NIDS-v2_Multiclass                                   0.596
# N_BaIoT_Danmini_Doorbell_Multiclass                             0.371
# N_BaIoT_Ecobee_Thermostat_Multiclass                            0.395
# N_BaIoT_Ennio_Doorbell_Multiclass                               0.489
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                 0.386
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...              0.397
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...              0.389
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                    0.438
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...              0.396
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...              0.406
# ToN_IoT_IoT_Fridge_Multiclass                                   0.669
# ToN_IoT_IoT_GPS_Tracker_Multiclass                              0.545
# ToN_IoT_IoT_Garage_Door_Multiclass                              0.725
# ToN_IoT_IoT_Modbus_Multiclass                                   0.663
# ToN_IoT_IoT_Motion_Light_Multiclass                             nan
# ToN_IoT_IoT_Thermostat_Multiclass                               0.640
# ToN_IoT_IoT_Weather_Multiclass                                  0.666
# ToN_IoT_Linux_Disk_Multiclass                                   0.631
# ToN_IoT_Linux_Memory_Multiclass                                 0.632
# ToN_IoT_Linux_Process_Multiclass                                0.590
# ToN_IoT_Network_Multiclass                                      0.611
# ToN_IoT_Windows_10_Multiclass                                   0.426
# ToN_IoT_Windows_7_Multiclass                                    0.469

# %%
df_pretty.shape
# Out:
# (73, 5)

# %%
base_folder = Path("/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600")

def get_model_size(dataset_name, stage):
    ds_folder = os.path.join(base_folder, dataset_name)
    model_filename = os.path.join(ds_folder, f'xgb_{stage}_model.json')
    size_bytes = os.path.getsize(model_filename)
    return size_bytes

def get_scores(dataset_name, stage):
    results = {}
    ds_folder = os.path.join(base_folder, dataset_name)
    if stage.lower() in ['full', 'sampled', 'reduced', 'filtered']:
        metric_filename = os.path.join(ds_folder, f'xgb_{stage.lower()}_metrics.json')
        try:
            with open(metric_filename, 'r', encoding='utf-8') as fp:
                results = json.load(fp)
        except Exception as e:
            print(f'Could not open {metric_filename}. Reason: {str(e)}')
            results = {}
    elif stage.lower() == 'hpo':
        metric_filename = os.path.join(ds_folder, 'xgb_hpo_trials.xlsx')
        try:
            results_df = pd.read_excel(metric_filename).dropna()
            
            # Convert datetime columns to actual datetime objects
            results_df["datetime_start"] = pd.to_datetime(results_df["datetime_start"])
            results_df["datetime_complete"] = pd.to_datetime(results_df["datetime_complete"])
            
            # Calculate training time as a new column
            results_df["training_time_sec"] = (results_df["datetime_complete"] - results_df["datetime_start"]).dt.total_seconds()

            model_sizes = [
                get_model_size(dataset_name, 'best_balance') / 1024 / 1024,
                get_model_size(dataset_name, 'best_latency') / 1024 / 1024,
                get_model_size(dataset_name, 'best_weighted_f1_score') / 1024 / 1024,
            ]
            
            results = {
                'training_time': {
                    'min': results_df['training_time_sec'].min(),
                    'max': results_df['training_time_sec'].max(),
                    'mean': results_df['training_time_sec'].mean(),
                    'std': results_df['training_time_sec'].std(),
                },
                'latency': {
                    'min': results_df['latency'].min(),
                    'max': results_df['latency'].max(),
                    'mean': results_df['latency'].mean(),
                    'std': results_df['latency'].std(),
                },
                'f1_score': {
                    'min': results_df['f1_score'].min(),
                    'max': results_df['f1_score'].max(),
                    'mean': results_df['f1_score'].mean(),
                    'std': results_df['f1_score'].std(),
                },
                'size': {
                    'min': np.min(model_sizes),
                    'max': np.max(model_sizes),
                    'mean': np.mean(model_sizes),
                    'std': np.std(model_sizes),
                }
            }
        except Exception as e:
            print(f'Could not open {metric_filename}. Reason: {str(e)}')
            results = {
                'training_time': {
                    'min': np.nan,
                    'max': np.nan,
                    'mean': np.nan,
                    'std': np.nan,
                },
                'latency': {
                    'min': np.nan,
                    'max': np.nan,
                    'mean': np.nan,
                    'std': np.nan,
                },
                'f1_score': {
                    'min': np.nan,
                    'max': np.nan,
                    'mean': np.nan,
                    'std': np.nan,
                },
                'size': {
                    'min': np.nan,
                    'max': np.nan,
                    'mean': np.nan,
                    'std': np.nan,
                }
            }
    return results

for stage in ['full', 'sampled', 'reduced', 'filtered']:
    print(stage, get_scores('KDD_Cup_1999_Multiclass', stage), '\n')

print('hpo', get_scores('KDD_Cup_1999_Multiclass', 'hpo'), '\n')
# Out:
# full {'accuracy': 0.9997999990697631, 'balanced_accuracy': 0.7806832556202591, 'mcc': 0.999470146976705, 'cohen_kappa': 0.9994701224482787, 'precision_micro': 0.9997999990697631, 'recall_micro': 0.9997999990697631, 'f1_micro': 0.9997999990697631, 'precision_macro': 0.8202571305646795, 'recall_macro': 0.7806832556202591, 'f1_macro': 0.7920855963925386, 'precision_weighted': 0.9997749763378312, 'recall_weighted': 0.9997999990697631, 'f1_weighted': 0.9997845584213136, 'log_loss': 0.000894361642066211, 'roc_auc_ovr_micro': nan, 'roc_auc_ovo_micro': nan, 'roc_auc_ovr_macro': 0.9999577869344055, 'roc_auc_ovo_macro': 0.976270743618668, 'roc_auc_ovr_weighted': 0.9999993743827758, 'roc_auc_ovo_weighted': 0.9999559765230411, 'training_time': 13.170625686645508, 'test_time': 0.08667612075805664, 'latency': 4.0314662281246255e-07, 'model_size': 2.34}
#
# sampled {'accuracy': 0.9994511602379546, 'balanced_accuracy': 0.7547325664787659, 'mcc': 0.9985456947834608, 'cohen_kappa': 0.9985455107115699, 'precision_micro': 0.9994511602379546, 'recall_micro': 0.9994511602379546, 'f1_micro': 0.9994511602379546, 'precision_macro': 0.7787673155012741, 'recall_macro': 0.7547325664787659, 'f1_macro': 0.7619560209357167, 'precision_weighted': 0.9994466125102729, 'recall_weighted': 0.9994511602379546, 'f1_weighted': 0.9994434712320268, 'log_loss': 0.0028907397813504503, 'roc_auc_ovr_micro': nan, 'roc_auc_ovo_micro': nan, 'roc_auc_ovr_macro': 0.9996165037926059, 'roc_auc_ovo_macro': 0.9522241925159988, 'roc_auc_ovr_weighted': 0.9999853145722666, 'roc_auc_ovo_weighted': 0.9996348497546936, 'training_time': 7.664759159088135, 'test_time': 0.09029102325439453, 'latency': 4.1996020099811874e-07, 'model_size': 1.71}
#
# reduced {'accuracy': 0.9769859394694859, 'balanced_accuracy': 0.12653158914747226, 'mcc': 0.9379476800022003, 'cohen_kappa': 0.9371406862371123, 'precision_micro': 0.9769859394694859, 'recall_micro': 0.9769859394694859, 'f1_micro': 0.9769859394694859, 'precision_macro': 0.11693608456323604, 'recall_macro': 0.12653158914747226, 'f1_macro': 0.12126792380481169, 'precision_weighted': 0.959694138122388, 'recall_weighted': 0.9769859394694859, 'f1_weighted': 0.9682542462258226, 'log_loss': 0.1268391420935465, 'roc_auc_ovr_micro': nan, 'roc_auc_ovo_micro': nan, 'roc_auc_ovr_macro': 0.7134716656573484, 'roc_auc_ovo_macro': 0.6003341984818528, 'roc_auc_ovr_weighted': 0.974096114325592, 'roc_auc_ovo_weighted': 0.7069174964809471, 'training_time': 5.027577638626099, 'test_time': 0.11393308639526367, 'latency': 5.299237968328396e-07, 'model_size': 1.3}
#
# filtered {'accuracy': 0.18941948567202638, 'balanced_accuracy': 0.09649727489852004, 'mcc': 0.39052512631011516, 'cohen_kappa': 0.14980764972508598, 'precision_micro': 0.18941948567202638, 'recall_micro': 0.18941948567202638, 'f1_micro': 0.18941948567202638, 'precision_macro': 0.04819500396651133, 'recall_macro': 0.09649727489852004, 'f1_macro': 0.04879203350111551, 'precision_weighted': 0.21336864133864883, 'recall_weighted': 0.18941948567202638, 'f1_weighted': 0.19834299083189783, 'log_loss': 4.100054602707339, 'roc_auc_ovr_micro': nan, 'roc_auc_ovo_micro': nan, 'roc_auc_ovr_macro': 0.6374008912422315, 'roc_auc_ovo_macro': 0.5673151920909769, 'roc_auc_ovr_weighted': 0.9291444515500147, 'roc_auc_ovo_weighted': 0.620398619147843, 'training_time': 1.3358697891235352, 'test_time': 0.03983283042907715, 'latency': 1.852698404600819e-07, 'model_size': 0.3}
#
# hpo {'training_time': {'min': 3.759, 'max': 14.712, 'mean': 6.1068, 'std': 2.0458382068045}, 'latency': {'min': 4.189989353403305e-05, 'max': 0.001005566295332805, 'mean': 0.00015725087657372615, 'std': 0.00015313600445361947}, 'f1_score': {'min': 0.1026112, 'max': 0.96925615, 'mean': 0.739050260943099, 'std': 0.24739877700173687}, 'size': {'min': 0.15745067596435547, 'max': 0.7745895385742188, 'mean': 0.3646961847941081, 'std': 0.2898444476302386}}

# %%
for dataset_name in df_pretty.index:
    try:
        # Extract metrics
        new_data = {
            # f1 scores
            'f1_full': get_scores(dataset_name, 'full').get('f1_weighted', np.nan),
            'f1_sampled': get_scores(dataset_name, 'sampled').get('f1_weighted', np.nan),
            'f1_reduced': get_scores(dataset_name, 'reduced').get('f1_weighted', np.nan),
            'f1_filtered': get_scores(dataset_name, 'filtered').get('f1_weighted', np.nan),
            'f1_hpo_min': get_scores(dataset_name, 'hpo').get('f1_score', {}).get('min', np.nan),
            'f1_hpo_max': get_scores(dataset_name, 'hpo').get('f1_score', {}).get('max', np.nan),
            'f1_hpo_mean': get_scores(dataset_name, 'hpo').get('f1_score', {}).get('mean', np.nan),
            'f1_hpo_std': get_scores(dataset_name, 'hpo').get('f1_score', {}).get('std', np.nan),
            # training times
            'time_full': get_scores(dataset_name, 'full').get('training_time', np.nan),
            'time_sampled': get_scores(dataset_name, 'sampled').get('training_time', np.nan),
            'time_reduced': get_scores(dataset_name, 'reduced').get('training_time', np.nan),
            'time_filtered': get_scores(dataset_name, 'filtered').get('training_time', np.nan),
            'time_hpo_min': get_scores(dataset_name, 'hpo').get('training_time', {}).get('min', np.nan),
            'time_hpo_max': get_scores(dataset_name, 'hpo').get('training_time', {}).get('max', np.nan),
            'time_hpo_mean': get_scores(dataset_name, 'hpo').get('training_time', {}).get('mean', np.nan),
            'time_hpo_std': get_scores(dataset_name, 'hpo').get('training_time', {}).get('std', np.nan),
            # size
            'size_full': get_scores(dataset_name, 'full').get('model_size', np.nan),
            'size_sampled': get_scores(dataset_name, 'sampled').get('model_size', np.nan),
            'size_reduced': get_scores(dataset_name, 'reduced').get('model_size', np.nan),
            'size_filtered': get_scores(dataset_name, 'filtered').get('model_size', np.nan),
            'size_hpo_min': get_scores(dataset_name, 'hpo').get('size', {}).get('min', np.nan),
            'size_hpo_max': get_scores(dataset_name, 'hpo').get('size', {}).get('max', np.nan),
            'size_hpo_mean': get_scores(dataset_name, 'hpo').get('size', {}).get('mean', np.nan),
            'size_hpo_std': get_scores(dataset_name, 'hpo').get('size', {}).get('std', np.nan),
        }

        # Assign values into the existing df_pretty using .at
        for col, val in new_data.items():
            df_pretty.at[dataset_name, col] = val

    except Exception as e:
        print(f"Skipping {dataset_name} due to: {e}")
        # pass

df_pretty
# Out:
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_full_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_full_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_sampled_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_sampled_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_reduced_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_reduced_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_filtered_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_filtered_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_full_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_full_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_sampled_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_sampled_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_reduced_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_reduced_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_filtered_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_filtered_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_full_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_full_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_sampled_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_sampled_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_reduced_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_reduced_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_filtered_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_filtered_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Macro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_full_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_full_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_sampled_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_sampled_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_reduced_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_reduced_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_filtered_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_filtered_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_full_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_full_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_sampled_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_sampled_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_reduced_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_reduced_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_filtered_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_filtered_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_full_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_full_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_sampled_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_sampled_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_reduced_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_reduced_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_filtered_metrics.json. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_filtered_metrics.json'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx'
# Could not open /home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx. Reason: [Errno 2] No such file or directory: '/home/automl/git/iot-threat-classifier/2025-07-05/Output_Multiclass_3600/CICAPT_IIoT_Phase1_Micro_Multiclass/xgb_hpo_trials.xlsx'
#                                                        samples features  \
# filename
# CIC_IDS_2017_Multiclass                             1,250,066       70
# CIC_IOT_Dataset2023_Multiclass                      4,487,800       39
# IoT_23_Multiclass                                   363,889         12
# IoT_Network_Intrusion_Macro_Multiclass              78,938          24
# IoT_Network_Intrusion_Micro_Multiclass              78,963          24
# KDD_Cup_1999_Multiclass                             1,074,992       40
# UNSW_NB15_Multiclass                                1,944,769       45
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass           292,898         73
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass      1,175,500       69
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass              258,558         73
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass               91,787          72
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...  178,424         71
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass          89,209          73
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass       1,966,383       69
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass            711,664         71
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass            331,398         69
# BoT_IoT_Macro_Multiclass                            1,704,066       20
# BoT_IoT_Micro_Multiclass                            1,705,588       20
# CICAPT_IIoT_Phase1_Macro_Multiclass                 10,260,159      48
# CICAPT_IIoT_Phase1_Micro_Multiclass                 10,260,159      48
# CICAPT_IIoT_Phase2_Macro_Multiclass                 8,209,431       48
# CICAPT_IIoT_Phase2_Micro_Multiclass                 8,209,431       48
# CICEVSE2024_EVSE-A_Macro_Multiclass                 366,517         68
# CICEVSE2024_EVSE-A_Micro_Multiclass                 366,517         68
# CICEVSE2024_EVSE-B_Macro_Multiclass                 286,645         68
# CICEVSE2024_EVSE-B_Micro_Multiclass                 286,675         68
# CICIoMT2024_Bluetooth_Multiclass                    747             7
# CICIoMT2024_WiFi_and_MQTT_Multiclass                1,924,242       44
# CICIoV2024_Decimal_Macro_Multiclass                 3,577           8
# CICIoV2024_Decimal_Micro_Multiclass                 3,579           8
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                1,606,411       45
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                 151,908         41
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass          39,418          28
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass          1,744           17
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass         63,600          16
# NIDS_CIC-BoT-IoT_Multiclass                         1,502,919       79
# NIDS_CIC-ToN-IoT_Multiclass                         169,545         71
# NIDS_NF-BoT-IoT_Multiclass                          94,169          10
# NIDS_NF-BoT-IoT-v2_Multiclass                       143,087         38
# NIDS_NF-BoT-IoT-v3_Multiclass                       682,102         46
# NIDS_NF-CICIDS2018-v3_Multiclass                    8,184,198       45
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                  391,022         10
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass               1,804,117       37
# NIDS_NF-ToN-IoT_Multiclass                          672,305         10
# NIDS_NF-ToN-IoT-v2_Multiclass                       1,165,794       38
# NIDS_NF-ToN-IoT-v3_Multiclass                       4,213,539       46
# NIDS_NF-UNSW-NB15_Multiclass                        426,380         10
# NIDS_NF-UNSW-NB15-v2_Multiclass                     145,077         38
# NIDS_NF-UNSW-NB15-v3_Multiclass                     1,176,457       46
# NIDS_NF-UQ-NIDS_Multiclass                          592,809         10
# NIDS_NF-UQ-NIDS-v2_Multiclass                       3,204,691       38
# N_BaIoT_Danmini_Doorbell_Multiclass                 704,874         115
# N_BaIoT_Ecobee_Thermostat_Multiclass                540,971         115
# N_BaIoT_Ennio_Doorbell_Multiclass                   146,043         115
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass     786,204         115
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...  447,068         115
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...  473,360         115
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass        164,375         115
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...  510,556         115
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...  548,938         115
# ToN_IoT_IoT_Fridge_Multiclass                       1,057           2
# ToN_IoT_IoT_GPS_Tracker_Multiclass                  639             2
# ToN_IoT_IoT_Garage_Door_Multiclass                  18              2
# ToN_IoT_IoT_Modbus_Multiclass                       112,839         4
# ToN_IoT_IoT_Motion_Light_Multiclass                 16              2
# ToN_IoT_IoT_Thermostat_Multiclass                   40,651          2
# ToN_IoT_IoT_Weather_Multiclass                      571,535         3
# ToN_IoT_Linux_Disk_Multiclass                       24,158          5
# ToN_IoT_Linux_Memory_Multiclass                     82,722          9
# ToN_IoT_Linux_Process_Multiclass                    20,919          12
# ToN_IoT_Network_Multiclass                          470,405         40
# ToN_IoT_Windows_10_Multiclass                       35,214          113
# ToN_IoT_Windows_7_Multiclass                        28,097          104
#
#                                                    classes feature_types  \
# filename
# CIC_IDS_2017_Multiclass                                 15   mixed
# CIC_IOT_Dataset2023_Multiclass                          35   mixed
# IoT_23_Multiclass                                       16   mixed
# IoT_Network_Intrusion_Macro_Multiclass                  5    mixed
# IoT_Network_Intrusion_Micro_Multiclass                  11   mixed
# KDD_Cup_1999_Multiclass                                 23   mixed
# UNSW_NB15_Multiclass                                    11   mixed
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass               12   mixed
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass          12   mixed
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                  15   mixed
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                   2    mixed
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...      5    mixed
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass              9    mixed
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass           5    mixed
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                4    mixed
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                5    mixed
# BoT_IoT_Macro_Multiclass                                5    mixed
# BoT_IoT_Micro_Multiclass                                11   mixed
# CICAPT_IIoT_Phase1_Macro_Multiclass                     1    mixed
# CICAPT_IIoT_Phase1_Micro_Multiclass                     1    mixed
# CICAPT_IIoT_Phase2_Macro_Multiclass                     26   mixed
# CICAPT_IIoT_Phase2_Micro_Multiclass                     9    mixed
# CICEVSE2024_EVSE-A_Macro_Multiclass                     16   mixed
# CICEVSE2024_EVSE-A_Micro_Multiclass                     28   mixed
# CICEVSE2024_EVSE-B_Macro_Multiclass                     21   mixed
# CICEVSE2024_EVSE-B_Micro_Multiclass                     31   mixed
# CICIoMT2024_Bluetooth_Multiclass                        2    numerical
# CICIoMT2024_WiFi_and_MQTT_Multiclass                    19   mixed
# CICIoV2024_Decimal_Macro_Multiclass                     3    numerical
# CICIoV2024_Decimal_Micro_Multiclass                     6    numerical
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                    15   mixed
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                     15   mixed
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass              5    mixed
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass              5    mixed
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass             5    mixed
# NIDS_CIC-BoT-IoT_Multiclass                             5    mixed
# NIDS_CIC-ToN-IoT_Multiclass                             10   mixed
# NIDS_NF-BoT-IoT_Multiclass                              5    mixed
# NIDS_NF-BoT-IoT-v2_Multiclass                           5    mixed
# NIDS_NF-BoT-IoT-v3_Multiclass                           5    mixed
# NIDS_NF-CICIDS2018-v3_Multiclass                        15   mixed
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                      15   mixed
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                   15   mixed
# NIDS_NF-ToN-IoT_Multiclass                              10   mixed
# NIDS_NF-ToN-IoT-v2_Multiclass                           10   mixed
# NIDS_NF-ToN-IoT-v3_Multiclass                           10   mixed
# NIDS_NF-UNSW-NB15_Multiclass                            10   mixed
# NIDS_NF-UNSW-NB15-v2_Multiclass                         10   mixed
# NIDS_NF-UNSW-NB15-v3_Multiclass                         10   mixed
# NIDS_NF-UQ-NIDS_Multiclass                              21   mixed
# NIDS_NF-UQ-NIDS-v2_Multiclass                           21   mixed
# N_BaIoT_Danmini_Doorbell_Multiclass                     11   mixed
# N_BaIoT_Ecobee_Thermostat_Multiclass                    11   mixed
# N_BaIoT_Ennio_Doorbell_Multiclass                       6    mixed
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass         11   mixed
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...      11   mixed
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...      11   mixed
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass            6    mixed
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...      11   mixed
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...      11   mixed
# ToN_IoT_IoT_Fridge_Multiclass                           7    mixed
# ToN_IoT_IoT_GPS_Tracker_Multiclass                      8    categorical
# ToN_IoT_IoT_Garage_Door_Multiclass                      8    categorical
# ToN_IoT_IoT_Modbus_Multiclass                           6    numerical
# ToN_IoT_IoT_Motion_Light_Multiclass                     8    mixed
# ToN_IoT_IoT_Thermostat_Multiclass                       7    numerical
# ToN_IoT_IoT_Weather_Multiclass                          8    numerical
# ToN_IoT_Linux_Disk_Multiclass                           8    mixed
# ToN_IoT_Linux_Memory_Multiclass                         6    mixed
# ToN_IoT_Linux_Process_Multiclass                        8    mixed
# ToN_IoT_Network_Multiclass                              10   mixed
# ToN_IoT_Windows_10_Multiclass                           8    mixed
# ToN_IoT_Windows_7_Multiclass                            8    mixed
#
#                                                    overall_difficulty  \
# filename
# CIC_IDS_2017_Multiclass                                         0.516
# CIC_IOT_Dataset2023_Multiclass                                  0.464
# IoT_23_Multiclass                                               0.654
# IoT_Network_Intrusion_Macro_Multiclass                          0.582
# IoT_Network_Intrusion_Micro_Multiclass                          0.578
# KDD_Cup_1999_Multiclass                                         0.533
# UNSW_NB15_Multiclass                                            0.597
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                       0.572
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                  0.520
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                          0.546
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                           0.461
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...              0.492
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                      0.594
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                   0.361
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                        0.548
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                        0.570
# BoT_IoT_Macro_Multiclass                                        0.619
# BoT_IoT_Micro_Multiclass                                        0.567
# CICAPT_IIoT_Phase1_Macro_Multiclass                             nan
# CICAPT_IIoT_Phase1_Micro_Multiclass                             nan
# CICAPT_IIoT_Phase2_Macro_Multiclass                             0.517
# CICAPT_IIoT_Phase2_Micro_Multiclass                             0.518
# CICEVSE2024_EVSE-A_Macro_Multiclass                             0.570
# CICEVSE2024_EVSE-A_Micro_Multiclass                             0.419
# CICEVSE2024_EVSE-B_Macro_Multiclass                             0.504
# CICEVSE2024_EVSE-B_Micro_Multiclass                             0.479
# CICIoMT2024_Bluetooth_Multiclass                                0.539
# CICIoMT2024_WiFi_and_MQTT_Multiclass                            0.398
# CICIoV2024_Decimal_Macro_Multiclass                             0.590
# CICIoV2024_Decimal_Micro_Multiclass                             0.581
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                            0.526
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                             0.536
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                      0.429
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                      0.507
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                     0.467
# NIDS_CIC-BoT-IoT_Multiclass                                     0.595
# NIDS_CIC-ToN-IoT_Multiclass                                     0.465
# NIDS_NF-BoT-IoT_Multiclass                                      0.641
# NIDS_NF-BoT-IoT-v2_Multiclass                                   0.537
# NIDS_NF-BoT-IoT-v3_Multiclass                                   0.576
# NIDS_NF-CICIDS2018-v3_Multiclass                                0.527
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                              0.550
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                           0.517
# NIDS_NF-ToN-IoT_Multiclass                                      0.636
# NIDS_NF-ToN-IoT-v2_Multiclass                                   0.583
# NIDS_NF-ToN-IoT-v3_Multiclass                                   0.551
# NIDS_NF-UNSW-NB15_Multiclass                                    0.628
# NIDS_NF-UNSW-NB15-v2_Multiclass                                 0.599
# NIDS_NF-UNSW-NB15-v3_Multiclass                                 0.544
# NIDS_NF-UQ-NIDS_Multiclass                                      0.620
# NIDS_NF-UQ-NIDS-v2_Multiclass                                   0.596
# N_BaIoT_Danmini_Doorbell_Multiclass                             0.371
# N_BaIoT_Ecobee_Thermostat_Multiclass                            0.395
# N_BaIoT_Ennio_Doorbell_Multiclass                               0.489
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                 0.386
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...              0.397
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...              0.389
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                    0.438
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...              0.396
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...              0.406
# ToN_IoT_IoT_Fridge_Multiclass                                   0.669
# ToN_IoT_IoT_GPS_Tracker_Multiclass                              0.545
# ToN_IoT_IoT_Garage_Door_Multiclass                              0.725
# ToN_IoT_IoT_Modbus_Multiclass                                   0.663
# ToN_IoT_IoT_Motion_Light_Multiclass                             nan
# ToN_IoT_IoT_Thermostat_Multiclass                               0.640
# ToN_IoT_IoT_Weather_Multiclass                                  0.666
# ToN_IoT_Linux_Disk_Multiclass                                   0.631
# ToN_IoT_Linux_Memory_Multiclass                                 0.632
# ToN_IoT_Linux_Process_Multiclass                                0.590
# ToN_IoT_Network_Multiclass                                      0.611
# ToN_IoT_Windows_10_Multiclass                                   0.426
# ToN_IoT_Windows_7_Multiclass                                    0.469
#
#                                                      f1_full  f1_sampled  \
# filename
# CIC_IDS_2017_Multiclass                             0.999263    0.998707
# CIC_IOT_Dataset2023_Multiclass                      0.768569    0.749499
# IoT_23_Multiclass                                   0.992632    0.990753
# IoT_Network_Intrusion_Macro_Multiclass              0.916200    0.912424
# IoT_Network_Intrusion_Micro_Multiclass              0.914868    0.910227
# KDD_Cup_1999_Multiclass                             0.999785    0.999443
# UNSW_NB15_Multiclass                                0.982184    0.980002
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass           0.755286    0.734931
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass      0.999140    0.998761
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass              0.943162    0.932279
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass               0.999945    0.999449
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...  0.964178    0.953269
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass          0.923990    0.912825
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass       0.978839    0.974509
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass            0.979179    0.975893
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass            0.997807    0.997167
# BoT_IoT_Macro_Multiclass                            0.988779    0.982993
# BoT_IoT_Micro_Multiclass                            0.987832    0.980934
# CICAPT_IIoT_Phase1_Macro_Multiclass                      NaN         NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                      NaN         NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                 0.999988    0.999890
# CICAPT_IIoT_Phase2_Micro_Multiclass                 0.999986    0.999914
# CICEVSE2024_EVSE-A_Macro_Multiclass                 0.994884    0.994907
# CICEVSE2024_EVSE-A_Micro_Multiclass                 0.995671    0.994052
# CICEVSE2024_EVSE-B_Macro_Multiclass                 0.947832    0.948975
# CICEVSE2024_EVSE-B_Micro_Multiclass                 0.946067    0.948789
# CICIoMT2024_Bluetooth_Multiclass                    0.704818    0.626070
# CICIoMT2024_WiFi_and_MQTT_Multiclass                0.992589    0.989992
# CICIoV2024_Decimal_Macro_Multiclass                 0.998539    0.985339
# CICIoV2024_Decimal_Micro_Multiclass                 0.996739    0.988902
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                0.941385    0.939816
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                 0.948093    0.939909
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass          0.997590    0.996310
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass          0.957921    0.942670
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass         0.998193    0.996774
# NIDS_CIC-BoT-IoT_Multiclass                         0.469435    0.495485
# NIDS_CIC-ToN-IoT_Multiclass                         0.870825    0.880136
# NIDS_NF-BoT-IoT_Multiclass                          0.429842    0.461391
# NIDS_NF-BoT-IoT-v2_Multiclass                       0.907984    0.879901
# NIDS_NF-BoT-IoT-v3_Multiclass                       0.994539    0.987135
# NIDS_NF-CICIDS2018-v3_Multiclass                    0.994022    0.993792
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                  0.969482    0.969646
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass               0.988869    0.988434
# NIDS_NF-ToN-IoT_Multiclass                          0.537154    0.540316
# NIDS_NF-ToN-IoT-v2_Multiclass                       0.887541    0.868774
# NIDS_NF-ToN-IoT-v3_Multiclass                       0.946815    0.942985
# NIDS_NF-UNSW-NB15_Multiclass                        0.949722    0.940063
# NIDS_NF-UNSW-NB15-v2_Multiclass                     0.906217    0.882833
# NIDS_NF-UNSW-NB15-v3_Multiclass                     0.978174    0.974326
# NIDS_NF-UQ-NIDS_Multiclass                          0.835708    0.834956
# NIDS_NF-UQ-NIDS-v2_Multiclass                       0.942341    0.933721
# N_BaIoT_Danmini_Doorbell_Multiclass                 0.999893    0.999353
# N_BaIoT_Ecobee_Thermostat_Multiclass                0.999861    0.999469
# N_BaIoT_Ennio_Doorbell_Multiclass                   0.999504    0.998427
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass     0.999910    0.999601
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...  0.999724    0.998951
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...  0.999786    0.999154
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass        0.999725    0.998325
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...  0.999822    0.999302
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...  0.999852    0.999363
# ToN_IoT_IoT_Fridge_Multiclass                       0.004244    0.098933
# ToN_IoT_IoT_GPS_Tracker_Multiclass                  0.339420    0.427620
# ToN_IoT_IoT_Garage_Door_Multiclass                  0.000000    0.000000
# ToN_IoT_IoT_Modbus_Multiclass                       0.703038    0.702523
# ToN_IoT_IoT_Motion_Light_Multiclass                 0.035714    0.035714
# ToN_IoT_IoT_Thermostat_Multiclass                   0.326382    0.358608
# ToN_IoT_IoT_Weather_Multiclass                      0.885410    0.845362
# ToN_IoT_Linux_Disk_Multiclass                       0.551186    0.580356
# ToN_IoT_Linux_Memory_Multiclass                     0.853013    0.809581
# ToN_IoT_Linux_Process_Multiclass                    0.450981    0.456725
# ToN_IoT_Network_Multiclass                          0.982596    0.973609
# ToN_IoT_Windows_10_Multiclass                       0.983429    0.975507
# ToN_IoT_Windows_7_Multiclass                        0.994792    0.990307
#
#                                                     f1_reduced  f1_filtered  \
# filename
# CIC_IDS_2017_Multiclass                               0.996949     0.991532
# CIC_IOT_Dataset2023_Multiclass                        0.720069     0.646485
# IoT_23_Multiclass                                     0.989082     0.887855
# IoT_Network_Intrusion_Macro_Multiclass                0.913172     0.873815
# IoT_Network_Intrusion_Micro_Multiclass                0.910547     0.879279
# KDD_Cup_1999_Multiclass                               0.968254     0.198343
# UNSW_NB15_Multiclass                                  0.980519     0.976690
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass             0.733061     0.602627
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass        0.998053     0.989125
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                0.932078     0.894938
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                 0.998832     0.997678
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...    0.949706     0.939027
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass            0.912700     0.877681
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass         0.955045     0.379032
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass              0.975724     0.960333
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass              0.997057     0.486625
# BoT_IoT_Macro_Multiclass                              0.982348     0.921355
# BoT_IoT_Micro_Multiclass                              0.946090     0.874508
# CICAPT_IIoT_Phase1_Macro_Multiclass                        NaN          NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                        NaN          NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                   0.999904     0.999824
# CICAPT_IIoT_Phase2_Micro_Multiclass                   0.999915     0.999831
# CICEVSE2024_EVSE-A_Macro_Multiclass                   0.975931     0.973712
# CICEVSE2024_EVSE-A_Micro_Multiclass                   0.987553     0.966611
# CICEVSE2024_EVSE-B_Macro_Multiclass                   0.925912     0.751370
# CICEVSE2024_EVSE-B_Micro_Multiclass                   0.944345     0.520495
# CICIoMT2024_Bluetooth_Multiclass                      0.626070     0.621965
# CICIoMT2024_WiFi_and_MQTT_Multiclass                  0.989586     0.910964
# CICIoV2024_Decimal_Macro_Multiclass                   0.985339     0.988130
# CICIoV2024_Decimal_Micro_Multiclass                   0.989623     0.994326
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                  0.856922     0.074342
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                   0.473421     0.171908
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass            0.995252     0.978366
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass            0.946796     0.693962
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass           0.996463     0.987553
# NIDS_CIC-BoT-IoT_Multiclass                           0.495363     0.479389
# NIDS_CIC-ToN-IoT_Multiclass                           0.880905     0.870441
# NIDS_NF-BoT-IoT_Multiclass                            0.459977     0.457189
# NIDS_NF-BoT-IoT-v2_Multiclass                         0.867252     0.839968
# NIDS_NF-BoT-IoT-v3_Multiclass                         0.982839     0.952899
# NIDS_NF-CICIDS2018-v3_Multiclass                      0.993591     0.947704
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                    0.968697     0.900877
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                 0.986669     0.884014
# NIDS_NF-ToN-IoT_Multiclass                            0.538546     0.528037
# NIDS_NF-ToN-IoT-v2_Multiclass                         0.866353     0.829752
# NIDS_NF-ToN-IoT-v3_Multiclass                         0.942177     0.907078
# NIDS_NF-UNSW-NB15_Multiclass                          0.940106     0.905926
# NIDS_NF-UNSW-NB15-v2_Multiclass                       0.885205     0.854870
# NIDS_NF-UNSW-NB15-v3_Multiclass                       0.974639     0.971901
# NIDS_NF-UQ-NIDS_Multiclass                            0.830905     0.669063
# NIDS_NF-UQ-NIDS-v2_Multiclass                         0.929643     0.880049
# N_BaIoT_Danmini_Doorbell_Multiclass                   0.998838     0.955769
# N_BaIoT_Ecobee_Thermostat_Multiclass                  0.999501     0.973911
# N_BaIoT_Ennio_Doorbell_Multiclass                     0.998532     0.708479
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass       0.999647     0.888983
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...    0.997717     0.242992
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...    0.984025     0.224831
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass          0.998151     0.742627
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...    0.998204     0.428999
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...    0.999378     0.921819
# ToN_IoT_IoT_Fridge_Multiclass                         0.098933     0.093671
# ToN_IoT_IoT_GPS_Tracker_Multiclass                    0.423159     0.281715
# ToN_IoT_IoT_Garage_Door_Multiclass                    0.000000     0.119048
# ToN_IoT_IoT_Modbus_Multiclass                         0.702995     0.702820
# ToN_IoT_IoT_Motion_Light_Multiclass                   0.035714     0.035714
# ToN_IoT_IoT_Thermostat_Multiclass                     0.358608     0.307649
# ToN_IoT_IoT_Weather_Multiclass                        0.845362     0.791205
# ToN_IoT_Linux_Disk_Multiclass                         0.580356     0.570751
# ToN_IoT_Linux_Memory_Multiclass                       0.807241     0.745256
# ToN_IoT_Linux_Process_Multiclass                      0.457836     0.400215
# ToN_IoT_Network_Multiclass                            0.971578     0.889576
# ToN_IoT_Windows_10_Multiclass                         0.975098     0.970268
# ToN_IoT_Windows_7_Multiclass                          0.990497     0.986085
#
#                                                     f1_hpo_min  f1_hpo_max  \
# filename
# CIC_IDS_2017_Multiclass                               0.545708    0.991472
# CIC_IOT_Dataset2023_Multiclass                        0.565177    0.755990
# IoT_23_Multiclass                                     0.627741    0.945173
# IoT_Network_Intrusion_Macro_Multiclass                0.693923    0.890342
# IoT_Network_Intrusion_Micro_Multiclass                0.527966    0.927388
# KDD_Cup_1999_Multiclass                               0.102611    0.969256
# UNSW_NB15_Multiclass                                  0.787879    0.972032
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass             0.436561    0.600713
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass        0.856272    0.992117
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                0.546967    0.907479
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                 0.447510    0.980969
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...    0.884890    0.961685
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass            0.675851    0.869482
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass         0.741824    0.991887
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass              0.801524    0.949018
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass              0.189533    0.878500
# BoT_IoT_Macro_Multiclass                              0.817216    0.955979
# BoT_IoT_Micro_Multiclass                              0.769872    0.908966
# CICAPT_IIoT_Phase1_Macro_Multiclass                        NaN         NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                        NaN         NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                   0.978385    0.999939
# CICAPT_IIoT_Phase2_Micro_Multiclass                   0.992518    0.999788
# CICEVSE2024_EVSE-A_Macro_Multiclass                   0.710736    0.973432
# CICEVSE2024_EVSE-A_Micro_Multiclass                   0.697732    0.966959
# CICEVSE2024_EVSE-B_Macro_Multiclass                   0.214858    0.858314
# CICEVSE2024_EVSE-B_Micro_Multiclass                   0.172700    0.564994
# CICIoMT2024_Bluetooth_Multiclass                      0.239048    0.503663
# CICIoMT2024_WiFi_and_MQTT_Multiclass                  0.801666    0.982069
# CICIoV2024_Decimal_Macro_Multiclass                   0.807143    0.992383
# CICIoV2024_Decimal_Micro_Multiclass                   0.249513    0.980749
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                  0.103664    0.732434
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                   0.152297    0.956175
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass            0.987947    0.998861
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass            0.040465    0.855407
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass           0.964172    0.999895
# NIDS_CIC-BoT-IoT_Multiclass                           0.494109    0.688586
# NIDS_CIC-ToN-IoT_Multiclass                           0.713605    0.878772
# NIDS_NF-BoT-IoT_Multiclass                            0.451003    0.655196
# NIDS_NF-BoT-IoT-v2_Multiclass                         0.699511    0.875704
# NIDS_NF-BoT-IoT-v3_Multiclass                         0.824253    0.944441
# NIDS_NF-CICIDS2018-v3_Multiclass                      0.935659    0.994953
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                    0.675876    0.933313
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                 0.824692    0.988413
# NIDS_NF-ToN-IoT_Multiclass                            0.424186    0.668455
# NIDS_NF-ToN-IoT-v2_Multiclass                         0.712637    0.875342
# NIDS_NF-ToN-IoT-v3_Multiclass                         0.787301    0.959009
# NIDS_NF-UNSW-NB15_Multiclass                          0.648448    0.944584
# NIDS_NF-UNSW-NB15-v2_Multiclass                       0.590795    0.865085
# ...
# ToN_IoT_IoT_Modbus_Multiclass                           0.037604
# ToN_IoT_IoT_Motion_Light_Multiclass                     0.056890
# ToN_IoT_IoT_Thermostat_Multiclass                       0.043715
# ToN_IoT_IoT_Weather_Multiclass                          0.049904
# ToN_IoT_Linux_Disk_Multiclass                           0.049907
# ToN_IoT_Linux_Memory_Multiclass                         0.037609
# ToN_IoT_Linux_Process_Multiclass                        0.050084
# ToN_IoT_Network_Multiclass                              0.062709
# ToN_IoT_Windows_10_Multiclass                           0.120615
# ToN_IoT_Windows_7_Multiclass                            0.051482
#
#                                                     size_hpo_max  \
# filename
# CIC_IDS_2017_Multiclass                                 2.869674
# CIC_IOT_Dataset2023_Multiclass                          6.409143
# IoT_23_Multiclass                                       6.261447
# IoT_Network_Intrusion_Macro_Multiclass                  0.835489
# IoT_Network_Intrusion_Micro_Multiclass                  2.416603
# KDD_Cup_1999_Multiclass                                 0.774590
# UNSW_NB15_Multiclass                                    3.685615
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass              22.095797
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass          1.544098
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                  6.702052
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                   0.185932
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...      2.688976
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass              1.199781
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass           0.164474
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                0.773303
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                0.200388
# BoT_IoT_Macro_Multiclass                                1.059593
# BoT_IoT_Micro_Multiclass                                1.183562
# CICAPT_IIoT_Phase1_Macro_Multiclass                          NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                          NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                     6.988331
# CICAPT_IIoT_Phase2_Micro_Multiclass                     0.337094
# CICEVSE2024_EVSE-A_Macro_Multiclass                     2.120276
# CICEVSE2024_EVSE-A_Micro_Multiclass                     3.272855
# CICEVSE2024_EVSE-B_Macro_Multiclass                     0.417101
# CICEVSE2024_EVSE-B_Micro_Multiclass                     0.388049
# CICIoMT2024_Bluetooth_Multiclass                        0.013169
# CICIoMT2024_WiFi_and_MQTT_Multiclass                    4.100984
# CICIoV2024_Decimal_Macro_Multiclass                     0.358191
# CICIoV2024_Decimal_Micro_Multiclass                     0.736898
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                    0.120079
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                     0.266648
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass              0.833952
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass              0.290751
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass             0.282307
# NIDS_CIC-BoT-IoT_Multiclass                            45.884043
# NIDS_CIC-ToN-IoT_Multiclass                             0.757040
# NIDS_NF-BoT-IoT_Multiclass                              1.326172
# NIDS_NF-BoT-IoT-v2_Multiclass                           1.130544
# NIDS_NF-BoT-IoT-v3_Multiclass                           1.999536
# NIDS_NF-CICIDS2018-v3_Multiclass                        6.930197
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                      0.322418
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                   0.505463
# NIDS_NF-ToN-IoT_Multiclass                              1.832535
# NIDS_NF-ToN-IoT-v2_Multiclass                          23.266541
# NIDS_NF-ToN-IoT-v3_Multiclass                           0.796247
# NIDS_NF-UNSW-NB15_Multiclass                            1.599246
# NIDS_NF-UNSW-NB15-v2_Multiclass                         0.372813
# NIDS_NF-UNSW-NB15-v3_Multiclass                         1.916162
# NIDS_NF-UQ-NIDS_Multiclass                              4.248571
# NIDS_NF-UQ-NIDS-v2_Multiclass                           2.009458
# N_BaIoT_Danmini_Doorbell_Multiclass                     1.161085
# N_BaIoT_Ecobee_Thermostat_Multiclass                    2.305598
# N_BaIoT_Ennio_Doorbell_Multiclass                       0.630723
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass         3.914552
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...      0.728309
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...      1.338088
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass            0.680285
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...      3.175485
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...      9.930750
# ToN_IoT_IoT_Fridge_Multiclass                           0.065059
# ToN_IoT_IoT_GPS_Tracker_Multiclass                      0.049559
# ToN_IoT_IoT_Garage_Door_Multiclass                      0.057015
# ToN_IoT_IoT_Modbus_Multiclass                           0.345082
# ToN_IoT_IoT_Motion_Light_Multiclass                     0.239352
# ToN_IoT_IoT_Thermostat_Multiclass                       1.852890
# ToN_IoT_IoT_Weather_Multiclass                          1.252829
# ToN_IoT_Linux_Disk_Multiclass                           3.218622
# ToN_IoT_Linux_Memory_Multiclass                        76.991473
# ToN_IoT_Linux_Process_Multiclass                        1.483236
# ToN_IoT_Network_Multiclass                              1.192116
# ToN_IoT_Windows_10_Multiclass                           0.479671
# ToN_IoT_Windows_7_Multiclass                            1.506967
#
#                                                     size_hpo_mean  \
# filename
# CIC_IDS_2017_Multiclass                                  1.763736
# CIC_IOT_Dataset2023_Multiclass                           3.518790
# IoT_23_Multiclass                                        2.359870
# IoT_Network_Intrusion_Macro_Multiclass                   0.461259
# IoT_Network_Intrusion_Micro_Multiclass                   1.328024
# KDD_Cup_1999_Multiclass                                  0.364696
# UNSW_NB15_Multiclass                                     1.954737
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                8.349218
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass           0.969681
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                   3.171470
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                    0.126288
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...       1.062896
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass               0.539497
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass            0.100558
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                 0.340213
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                 0.098017
# BoT_IoT_Macro_Multiclass                                 0.601695
# BoT_IoT_Micro_Multiclass                                 0.574122
# CICAPT_IIoT_Phase1_Macro_Multiclass                           NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                           NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                      4.656077
# CICAPT_IIoT_Phase2_Micro_Multiclass                      0.337094
# CICEVSE2024_EVSE-A_Macro_Multiclass                      0.984678
# CICEVSE2024_EVSE-A_Micro_Multiclass                      1.595200
# CICEVSE2024_EVSE-B_Macro_Multiclass                      0.257599
# CICEVSE2024_EVSE-B_Micro_Multiclass                      0.295742
# CICIoMT2024_Bluetooth_Multiclass                         0.009084
# CICIoMT2024_WiFi_and_MQTT_Multiclass                     2.239055
# CICIoV2024_Decimal_Macro_Multiclass                      0.244151
# CICIoV2024_Decimal_Micro_Multiclass                      0.623457
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                     0.109568
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                      0.163555
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass               0.370612
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass               0.161426
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass              0.137458
# NIDS_CIC-BoT-IoT_Multiclass                             16.112153
# NIDS_CIC-ToN-IoT_Multiclass                              0.514805
# NIDS_NF-BoT-IoT_Multiclass                               0.801900
# NIDS_NF-BoT-IoT-v2_Multiclass                            0.505730
# NIDS_NF-BoT-IoT-v3_Multiclass                            0.935907
# NIDS_NF-CICIDS2018-v3_Multiclass                         3.389477
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                       0.215362
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                    0.353648
# NIDS_NF-ToN-IoT_Multiclass                               0.970104
# NIDS_NF-ToN-IoT-v2_Multiclass                            8.926737
# NIDS_NF-ToN-IoT-v3_Multiclass                            0.473491
# NIDS_NF-UNSW-NB15_Multiclass                             0.661040
# NIDS_NF-UNSW-NB15-v2_Multiclass                          0.265621
# NIDS_NF-UNSW-NB15-v3_Multiclass                          1.242677
# NIDS_NF-UQ-NIDS_Multiclass                               1.815126
# NIDS_NF-UQ-NIDS-v2_Multiclass                            1.156382
# N_BaIoT_Danmini_Doorbell_Multiclass                      0.568284
# N_BaIoT_Ecobee_Thermostat_Multiclass                     1.016571
# N_BaIoT_Ennio_Doorbell_Multiclass                        0.298344
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass          1.683428
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...       0.484486
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...       0.588267
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass             0.280431
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...       1.859751
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...       4.057032
# ToN_IoT_IoT_Fridge_Multiclass                            0.054542
# ToN_IoT_IoT_GPS_Tracker_Multiclass                       0.049540
# ToN_IoT_IoT_Garage_Door_Multiclass                       0.055545
# ToN_IoT_IoT_Modbus_Multiclass                            0.140097
# ToN_IoT_IoT_Motion_Light_Multiclass                      0.118867
# ToN_IoT_IoT_Thermostat_Multiclass                        0.690193
# ToN_IoT_IoT_Weather_Multiclass                           0.664517
# ToN_IoT_Linux_Disk_Multiclass                            1.156098
# ToN_IoT_Linux_Memory_Multiclass                         25.807587
# ToN_IoT_Linux_Process_Multiclass                         0.583994
# ToN_IoT_Network_Multiclass                               0.633215
# ToN_IoT_Windows_10_Multiclass                            0.357508
# ToN_IoT_Windows_7_Multiclass                             0.615720
#
#                                                     size_hpo_std
# filename
# CIC_IDS_2017_Multiclass                                 1.201587
# CIC_IOT_Dataset2023_Multiclass                          2.544199
# IoT_23_Multiclass                                       2.770389
# IoT_Network_Intrusion_Macro_Multiclass                  0.330508
# IoT_Network_Intrusion_Micro_Multiclass                  0.966040
# KDD_Cup_1999_Multiclass                                 0.289844
# UNSW_NB15_Multiclass                                    1.480627
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass               9.787297
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass          0.640937
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                  2.716692
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                   0.084349
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...      1.163492
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass              0.483125
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass           0.054449
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                0.316426
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                0.073473
# BoT_IoT_Macro_Multiclass                                0.427027
# BoT_IoT_Micro_Multiclass                                0.461043
# CICAPT_IIoT_Phase1_Macro_Multiclass                          NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                          NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                     1.926693
# CICAPT_IIoT_Phase2_Micro_Multiclass                     0.000000
# CICEVSE2024_EVSE-A_Macro_Multiclass                     0.843734
# CICEVSE2024_EVSE-A_Micro_Multiclass                     1.278072
# CICEVSE2024_EVSE-B_Macro_Multiclass                     0.119213
# CICEVSE2024_EVSE-B_Micro_Multiclass                     0.080244
# CICIoMT2024_Bluetooth_Multiclass                        0.002902
# CICIoMT2024_WiFi_and_MQTT_Multiclass                    1.636069
# CICIoV2024_Decimal_Macro_Multiclass                     0.080638
# CICIoV2024_Decimal_Micro_Multiclass                     0.159969
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                    0.011644
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                     0.074476
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass              0.339189
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass              0.095335
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass             0.106041
# NIDS_CIC-BoT-IoT_Multiclass                            21.074472
# NIDS_CIC-ToN-IoT_Multiclass                             0.319785
# NIDS_NF-BoT-IoT_Multiclass                              0.556476
# NIDS_NF-BoT-IoT-v2_Multiclass                           0.461077
# NIDS_NF-BoT-IoT-v3_Multiclass                           0.811108
# NIDS_NF-CICIDS2018-v3_Multiclass                        2.796389
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                      0.094136
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                   0.184906
# NIDS_NF-ToN-IoT_Multiclass                              0.723388
# NIDS_NF-ToN-IoT-v2_Multiclass                          10.232271
# NIDS_NF-ToN-IoT-v3_Multiclass                           0.305732
# NIDS_NF-UNSW-NB15_Multiclass                            0.671798
# NIDS_NF-UNSW-NB15-v2_Multiclass                         0.143432
# NIDS_NF-UNSW-NB15-v3_Multiclass                         0.837107
# NIDS_NF-UQ-NIDS_Multiclass                              1.762612
# NIDS_NF-UQ-NIDS-v2_Multiclass                           0.776425
# N_BaIoT_Danmini_Doorbell_Multiclass                     0.450858
# N_BaIoT_Ecobee_Thermostat_Multiclass                    0.944512
# N_BaIoT_Ennio_Doorbell_Multiclass                       0.247329
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass         1.629467
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...      0.295551
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...      0.543231
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass            0.284853
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...      1.312191
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...      4.241172
# ToN_IoT_IoT_Fridge_Multiclass                           0.008071
# ToN_IoT_IoT_GPS_Tracker_Multiclass                      0.000013
# ToN_IoT_IoT_Garage_Door_Multiclass                      0.001082
# ToN_IoT_IoT_Modbus_Multiclass                           0.144946
# ToN_IoT_IoT_Motion_Light_Multiclass                     0.085208
# ToN_IoT_IoT_Thermostat_Multiclass                       0.823869
# ToN_IoT_IoT_Weather_Multiclass                          0.491444
# ToN_IoT_Linux_Disk_Multiclass                           1.459708
# ToN_IoT_Linux_Memory_Multiclass                        36.192765
# ToN_IoT_Linux_Process_Multiclass                        0.639574
# ToN_IoT_Network_Multiclass                              0.461151
# ToN_IoT_Windows_10_Multiclass                           0.167536
# ToN_IoT_Windows_7_Multiclass                            0.637605

# %%
df_pretty.shape
# Out:
# (73, 29)

# %%
df_super_pretty = format_and_pad_all_columns(df_pretty.loc[custom_order])
with open("df_super_pretty.tex", "w") as f:
    f.write(df_super_pretty.to_string())

# %% [markdown]
# # $F_1$ Score Analysis

# %%
# Columns to compare against "full"
cols_to_compare = ['f1_sampled', 'f1_reduced', 'f1_filtered', 'f1_hpo_max', 'f1_hpo_mean']

# Make a numeric copy to compute differences safely
df_numeric = df_pretty.copy()

# Compute best alternative and delta
# best_alternative = df_numeric[cols_to_compare].max(axis=1)
# df_pretty['f1_delta_abs'] = best_alternative - df_numeric['f1_full']
# df_pretty['f1_delta_pct'] = df_pretty['f1_delta_abs'] / df_numeric['f1_full']

# # Enforce +/- signs and percentage for 2nd col
# df_pretty['f1_delta_abs'] = df_pretty['f1_delta_abs'].map(lambda x: f"{x:+.3f}")
# df_pretty['f1_delta_pct'] = df_pretty['f1_delta_pct'].apply(lambda x: f"{x * 100:+.2f}")

# Apply to your DataFrame
df_pretty = format_and_pad_all_columns(df_pretty.loc[custom_order])

# Export to .tex with aligned source formatting
# df_pretty.to_latex("table_3.tex", header=True, index=True, escape=False)
selected_cols = ["f1_full", "f1_sampled", "f1_reduced", "f1_filtered", "f1_hpo_max"]
with open("table_3.tex", "w") as f:
    df_pretty_chopped = df_pretty[selected_cols]
    df_pretty_chopped = format_and_pad_all_columns(df_pretty_chopped.loc[custom_order])
    f.write(df_pretty_chopped.to_string())

df_pretty[selected_cols]
# Out:
#                                                    f1_full f1_sampled  \
# filename
# CIC_IDS_2017_Multiclass                              0.999      0.999
# CIC_IOT_Dataset2023_Multiclass                       0.769      0.749
# IoT_23_Multiclass                                    0.993      0.991
# IoT_Network_Intrusion_Macro_Multiclass               0.916      0.912
# IoT_Network_Intrusion_Micro_Multiclass               0.915      0.910
# KDD_Cup_1999_Multiclass                              1.000      0.999
# UNSW_NB15_Multiclass                                 0.982      0.980
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass            0.755      0.735
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass       0.999      0.999
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass               0.943      0.932
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                1.000      0.999
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...   0.964      0.953
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass           0.924      0.913
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass        0.979      0.975
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass             0.979      0.976
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass             0.998      0.997
# BoT_IoT_Macro_Multiclass                             0.989      0.983
# BoT_IoT_Micro_Multiclass                             0.988      0.981
# CICAPT_IIoT_Phase1_Macro_Multiclass                  nan        nan
# CICAPT_IIoT_Phase1_Micro_Multiclass                  nan        nan
# CICAPT_IIoT_Phase2_Macro_Multiclass                  1.000      1.000
# CICAPT_IIoT_Phase2_Micro_Multiclass                  1.000      1.000
# CICEVSE2024_EVSE-A_Macro_Multiclass                  0.995      0.995
# CICEVSE2024_EVSE-A_Micro_Multiclass                  0.996      0.994
# CICEVSE2024_EVSE-B_Macro_Multiclass                  0.948      0.949
# CICEVSE2024_EVSE-B_Micro_Multiclass                  0.946      0.949
# CICIoMT2024_Bluetooth_Multiclass                     0.705      0.626
# CICIoMT2024_WiFi_and_MQTT_Multiclass                 0.993      0.990
# CICIoV2024_Decimal_Macro_Multiclass                  0.999      0.985
# CICIoV2024_Decimal_Micro_Multiclass                  0.997      0.989
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                 0.941      0.940
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                  0.948      0.940
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass           0.998      0.996
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass           0.958      0.943
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass          0.998      0.997
# NIDS_CIC-BoT-IoT_Multiclass                          0.469      0.495
# NIDS_CIC-ToN-IoT_Multiclass                          0.871      0.880
# NIDS_NF-BoT-IoT_Multiclass                           0.430      0.461
# NIDS_NF-BoT-IoT-v2_Multiclass                        0.908      0.880
# NIDS_NF-BoT-IoT-v3_Multiclass                        0.995      0.987
# NIDS_NF-CICIDS2018-v3_Multiclass                     0.994      0.994
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                   0.969      0.970
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                0.989      0.988
# NIDS_NF-ToN-IoT_Multiclass                           0.537      0.540
# NIDS_NF-ToN-IoT-v2_Multiclass                        0.888      0.869
# NIDS_NF-ToN-IoT-v3_Multiclass                        0.947      0.943
# NIDS_NF-UNSW-NB15_Multiclass                         0.950      0.940
# NIDS_NF-UNSW-NB15-v2_Multiclass                      0.906      0.883
# NIDS_NF-UNSW-NB15-v3_Multiclass                      0.978      0.974
# NIDS_NF-UQ-NIDS_Multiclass                           0.836      0.835
# NIDS_NF-UQ-NIDS-v2_Multiclass                        0.942      0.934
# N_BaIoT_Danmini_Doorbell_Multiclass                  1.000      0.999
# N_BaIoT_Ecobee_Thermostat_Multiclass                 1.000      0.999
# N_BaIoT_Ennio_Doorbell_Multiclass                    1.000      0.998
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass      1.000      1.000
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...   1.000      0.999
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...   1.000      0.999
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass         1.000      0.998
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...   1.000      0.999
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...   1.000      0.999
# ToN_IoT_IoT_Fridge_Multiclass                        0.004      0.099
# ToN_IoT_IoT_GPS_Tracker_Multiclass                   0.339      0.428
# ToN_IoT_IoT_Garage_Door_Multiclass                   0.000      0.000
# ToN_IoT_IoT_Modbus_Multiclass                        0.703      0.703
# ToN_IoT_IoT_Motion_Light_Multiclass                  0.036      0.036
# ToN_IoT_IoT_Thermostat_Multiclass                    0.326      0.359
# ToN_IoT_IoT_Weather_Multiclass                       0.885      0.845
# ToN_IoT_Linux_Disk_Multiclass                        0.551      0.580
# ToN_IoT_Linux_Memory_Multiclass                      0.853      0.810
# ToN_IoT_Linux_Process_Multiclass                     0.451      0.457
# ToN_IoT_Network_Multiclass                           0.983      0.974
# ToN_IoT_Windows_10_Multiclass                        0.983      0.976
# ToN_IoT_Windows_7_Multiclass                         0.995      0.990
#
#                                                    f1_reduced f1_filtered  \
# filename
# CIC_IDS_2017_Multiclass                                 0.997       0.992
# CIC_IOT_Dataset2023_Multiclass                          0.720       0.646
# IoT_23_Multiclass                                       0.989       0.888
# IoT_Network_Intrusion_Macro_Multiclass                  0.913       0.874
# IoT_Network_Intrusion_Micro_Multiclass                  0.911       0.879
# KDD_Cup_1999_Multiclass                                 0.968       0.198
# UNSW_NB15_Multiclass                                    0.981       0.977
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass               0.733       0.603
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass          0.998       0.989
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                  0.932       0.895
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                   0.999       0.998
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...      0.950       0.939
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass              0.913       0.878
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass           0.955       0.379
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                0.976       0.960
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                0.997       0.487
# BoT_IoT_Macro_Multiclass                                0.982       0.921
# BoT_IoT_Micro_Multiclass                                0.946       0.875
# CICAPT_IIoT_Phase1_Macro_Multiclass                     nan         nan
# CICAPT_IIoT_Phase1_Micro_Multiclass                     nan         nan
# CICAPT_IIoT_Phase2_Macro_Multiclass                     1.000       1.000
# CICAPT_IIoT_Phase2_Micro_Multiclass                     1.000       1.000
# CICEVSE2024_EVSE-A_Macro_Multiclass                     0.976       0.974
# CICEVSE2024_EVSE-A_Micro_Multiclass                     0.988       0.967
# CICEVSE2024_EVSE-B_Macro_Multiclass                     0.926       0.751
# CICEVSE2024_EVSE-B_Micro_Multiclass                     0.944       0.520
# CICIoMT2024_Bluetooth_Multiclass                        0.626       0.622
# CICIoMT2024_WiFi_and_MQTT_Multiclass                    0.990       0.911
# CICIoV2024_Decimal_Macro_Multiclass                     0.985       0.988
# CICIoV2024_Decimal_Micro_Multiclass                     0.990       0.994
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                    0.857       0.074
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                     0.473       0.172
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass              0.995       0.978
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass              0.947       0.694
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass             0.996       0.988
# NIDS_CIC-BoT-IoT_Multiclass                             0.495       0.479
# NIDS_CIC-ToN-IoT_Multiclass                             0.881       0.870
# NIDS_NF-BoT-IoT_Multiclass                              0.460       0.457
# NIDS_NF-BoT-IoT-v2_Multiclass                           0.867       0.840
# NIDS_NF-BoT-IoT-v3_Multiclass                           0.983       0.953
# NIDS_NF-CICIDS2018-v3_Multiclass                        0.994       0.948
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                      0.969       0.901
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                   0.987       0.884
# NIDS_NF-ToN-IoT_Multiclass                              0.539       0.528
# NIDS_NF-ToN-IoT-v2_Multiclass                           0.866       0.830
# NIDS_NF-ToN-IoT-v3_Multiclass                           0.942       0.907
# NIDS_NF-UNSW-NB15_Multiclass                            0.940       0.906
# NIDS_NF-UNSW-NB15-v2_Multiclass                         0.885       0.855
# NIDS_NF-UNSW-NB15-v3_Multiclass                         0.975       0.972
# NIDS_NF-UQ-NIDS_Multiclass                              0.831       0.669
# NIDS_NF-UQ-NIDS-v2_Multiclass                           0.930       0.880
# N_BaIoT_Danmini_Doorbell_Multiclass                     0.999       0.956
# N_BaIoT_Ecobee_Thermostat_Multiclass                    1.000       0.974
# N_BaIoT_Ennio_Doorbell_Multiclass                       0.999       0.708
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass         1.000       0.889
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...      0.998       0.243
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...      0.984       0.225
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass            0.998       0.743
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...      0.998       0.429
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...      0.999       0.922
# ToN_IoT_IoT_Fridge_Multiclass                           0.099       0.094
# ToN_IoT_IoT_GPS_Tracker_Multiclass                      0.423       0.282
# ToN_IoT_IoT_Garage_Door_Multiclass                      0.000       0.119
# ToN_IoT_IoT_Modbus_Multiclass                           0.703       0.703
# ToN_IoT_IoT_Motion_Light_Multiclass                     0.036       0.036
# ToN_IoT_IoT_Thermostat_Multiclass                       0.359       0.308
# ToN_IoT_IoT_Weather_Multiclass                          0.845       0.791
# ToN_IoT_Linux_Disk_Multiclass                           0.580       0.571
# ToN_IoT_Linux_Memory_Multiclass                         0.807       0.745
# ToN_IoT_Linux_Process_Multiclass                        0.458       0.400
# ToN_IoT_Network_Multiclass                              0.972       0.890
# ToN_IoT_Windows_10_Multiclass                           0.975       0.970
# ToN_IoT_Windows_7_Multiclass                            0.990       0.986
#
#                                                    f1_hpo_max
# filename
# CIC_IDS_2017_Multiclass                                 0.991
# CIC_IOT_Dataset2023_Multiclass                          0.756
# IoT_23_Multiclass                                       0.945
# IoT_Network_Intrusion_Macro_Multiclass                  0.890
# IoT_Network_Intrusion_Micro_Multiclass                  0.927
# KDD_Cup_1999_Multiclass                                 0.969
# UNSW_NB15_Multiclass                                    0.972
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass               0.601
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass          0.992
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                  0.907
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                   0.981
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...      0.962
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass              0.869
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass           0.992
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                0.949
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                0.878
# BoT_IoT_Macro_Multiclass                                0.956
# BoT_IoT_Micro_Multiclass                                0.909
# CICAPT_IIoT_Phase1_Macro_Multiclass                     nan
# CICAPT_IIoT_Phase1_Micro_Multiclass                     nan
# CICAPT_IIoT_Phase2_Macro_Multiclass                     1.000
# CICAPT_IIoT_Phase2_Micro_Multiclass                     1.000
# CICEVSE2024_EVSE-A_Macro_Multiclass                     0.973
# CICEVSE2024_EVSE-A_Micro_Multiclass                     0.967
# CICEVSE2024_EVSE-B_Macro_Multiclass                     0.858
# CICEVSE2024_EVSE-B_Micro_Multiclass                     0.565
# CICIoMT2024_Bluetooth_Multiclass                        0.504
# CICIoMT2024_WiFi_and_MQTT_Multiclass                    0.982
# CICIoV2024_Decimal_Macro_Multiclass                     0.992
# CICIoV2024_Decimal_Micro_Multiclass                     0.981
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                    0.732
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                     0.956
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass              0.999
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass              0.855
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass             1.000
# NIDS_CIC-BoT-IoT_Multiclass                             0.689
# NIDS_CIC-ToN-IoT_Multiclass                             0.879
# NIDS_NF-BoT-IoT_Multiclass                              0.655
# NIDS_NF-BoT-IoT-v2_Multiclass                           0.876
# NIDS_NF-BoT-IoT-v3_Multiclass                           0.944
# NIDS_NF-CICIDS2018-v3_Multiclass                        0.995
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                      0.933
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                   0.988
# NIDS_NF-ToN-IoT_Multiclass                              0.668
# NIDS_NF-ToN-IoT-v2_Multiclass                           0.875
# NIDS_NF-ToN-IoT-v3_Multiclass                           0.959
# NIDS_NF-UNSW-NB15_Multiclass                            0.945
# NIDS_NF-UNSW-NB15-v2_Multiclass                         0.865
# NIDS_NF-UNSW-NB15-v3_Multiclass                         0.962
# NIDS_NF-UQ-NIDS_Multiclass                              0.779
# NIDS_NF-UQ-NIDS-v2_Multiclass                           0.893
# N_BaIoT_Danmini_Doorbell_Multiclass                     0.971
# N_BaIoT_Ecobee_Thermostat_Multiclass                    0.936
# N_BaIoT_Ennio_Doorbell_Multiclass                       0.992
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass         0.967
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...      0.389
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...      0.375
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass            0.995
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...      0.431
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...      0.972
# ToN_IoT_IoT_Fridge_Multiclass                           0.179
# ToN_IoT_IoT_GPS_Tracker_Multiclass                      0.160
# ToN_IoT_IoT_Garage_Door_Multiclass                      0.187
# ToN_IoT_IoT_Modbus_Multiclass                           0.704
# ToN_IoT_IoT_Motion_Light_Multiclass                     0.099
# ToN_IoT_IoT_Thermostat_Multiclass                       0.327
# ToN_IoT_IoT_Weather_Multiclass                          0.757
# ToN_IoT_Linux_Disk_Multiclass                           0.524
# ToN_IoT_Linux_Memory_Multiclass                         0.727
# ToN_IoT_Linux_Process_Multiclass                        0.372
# ToN_IoT_Network_Multiclass                              0.906
# ToN_IoT_Windows_10_Multiclass                           0.986
# ToN_IoT_Windows_7_Multiclass                            0.986

# %%
df_pretty.shape
# Out:
# (73, 29)

# %%
# Define target and metrics
target_col = 'overall_difficulty'
perf_cols = ['f1_full', 'f1_sampled', 'f1_reduced', 'f1_filtered', 'f1_hpo_max']
methods = ['pearson', 'spearman', 'kendall']

# Ensure numeric types
df_numeric = df_numeric.copy()
df_numeric[target_col] = df_numeric[target_col].astype(float)
for col in perf_cols:
    df_numeric[col] = df_numeric[col].astype(float)

# Compute all correlations into a dictionary
corr_data = {}
for method in methods:
    corr = (
        df_numeric[perf_cols + [target_col]]
        .corr(method=method)
        .loc[perf_cols, target_col]
    )
    corr_data[method] = corr

# Combine into a single DataFrame
df_corr_all = pd.DataFrame(corr_data)
df_corr_all.index.name = 'metric'
df_corr_all.reset_index(inplace=True)

# Export to .tex with aligned source formatting
# df_pretty.to_latex("table_3.tex", header=True, index=True, escape=False)
with open("table_4.tex", "w") as f:
    f.write(format_and_pad_all_columns(df_corr_all).to_string())

df_corr_all
# Out:
#         metric   pearson  spearman   kendall
# 0      f1_full -0.528909 -0.647467 -0.467371
# 1   f1_sampled -0.547094 -0.659592 -0.477315
# 2   f1_reduced -0.531520 -0.629918 -0.448312
# 3  f1_filtered -0.143817 -0.217292 -0.146675
# 4   f1_hpo_max -0.277290 -0.419887 -0.302465

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# 🔧 Set global font sizes
plt.rcParams.update({
    'font.size': 18,            # Base font size
    'axes.titlesize': 20,       # Title font
    'axes.labelsize': 18,       # Axis labels
    'xtick.labelsize': 16,      # Tick labels
    'ytick.labelsize': 16,
    'legend.fontsize': 16,      # Legend
    'figure.titlesize': 22      # Figure title
})

def bootstrap_kde_ci(data, x_vals, n_boot=1000, ci=95):
    boot_kdes = np.zeros((n_boot, len(x_vals)))
    for i in range(n_boot):
        sample = np.random.choice(data, size=len(data), replace=True)
        kde = gaussian_kde(sample)
        boot_kdes[i] = kde(x_vals)
    lower = np.percentile(boot_kdes, (100 - ci) / 2, axis=0)
    upper = np.percentile(boot_kdes, 100 - (100 - ci) / 2, axis=0)
    return lower, upper

# Setup
ref_col = "f1_full"
columns = [col for col in perf_cols if col != ref_col]
x_vals = np.linspace(df_numeric[perf_cols].min().min(),
                     df_numeric[perf_cols].max().max(), 500)

ref_data = df_numeric[ref_col].dropna().values
ref_kde = gaussian_kde(ref_data)(x_vals)
ref_lower, ref_upper = bootstrap_kde_ci(ref_data, x_vals)

col_map = {
    'f1_full': 'Baseline (Full)',
    'f1_sampled': 'Sampled ($S$)',
    'f1_reduced': 'Reduced ($R$)',
    'f1_filtered': 'Filtered ($F$)',
    'f1_hpo_max': 'HPO (Max)'
}

for col in columns:
    target_data = df_numeric[col].dropna().values
    target_kde = gaussian_kde(target_data)(x_vals)
    target_lower, target_upper = bootstrap_kde_ci(target_data, x_vals)

    # Difference and CI
    diff = target_kde - ref_kde
    diff_lower = target_lower - ref_upper
    diff_upper = target_upper - ref_lower

    # Plot
    plt.figure(figsize=(20, 5.5))
    plt.plot(x_vals, ref_kde, label=f"{col_map[ref_col]}", color='black', linestyle='--')
    plt.plot(x_vals, target_kde, label=f"{col_map[col]}", color='darkblue')
    plt.plot(x_vals, diff, label=f"Δ {col_map[col]} - {col_map[ref_col]}", color='blue')
    plt.fill_between(x_vals, diff_lower, diff_upper, alpha=0.2, color='blue', label="95% CI")
    plt.axhline(0, color='gray', linestyle='--', linewidth=1)

    # Labels
    plt.xlabel("Normalized Value")
    plt.ylabel("Density / Difference")
    plt.legend()
    plt.tight_layout()

    # Save and show
    plt.savefig(f"plots/kde_{col}_vs_{ref_col}.pdf", dpi=300)
    plt.show()
    plt.close()

# %% [markdown]
# # Training Time Analysis

# %%
# Columns to compare against "full"
cols_to_compare = ['time_sampled', 'time_reduced', 'time_filtered', 'time_hpo_min']

# Make a numeric copy to compute differences safely
df_numeric = df_pretty.copy()

# Compute best alternative and delta
# best_alternative = df_numeric[cols_to_compare].max(axis=1)
# df_pretty['time_delta_abs'] = best_alternative - df_numeric['time_full']
# df_pretty['time_delta_pct'] = df_pretty['time_delta_abs'] / df_numeric['time_full']

# # Enforce +/- signs and percentage for 2nd col
# df_pretty['time_delta_abs'] = df_pretty['time_delta_abs'].map(lambda x: f"{x:+.3f}")
# df_pretty['time_delta_pct'] = df_pretty['time_delta_pct'].apply(lambda x: f"{x * 100:+.2f}")

# Apply to your DataFrame
df_pretty = format_and_pad_all_columns(df_pretty.loc[custom_order])

# Export to .tex with aligned source formatting
# df_pretty.to_latex("table_3.tex", header=True, index=True, escape=False)
selected_cols = ["time_full", "time_sampled", "time_reduced", "time_filtered", "time_hpo_min"]
with open("table_3.tex", "w") as f:
    df_pretty_chopped = df_pretty[selected_cols]
    df_pretty_chopped = format_and_pad_all_columns(df_pretty_chopped.loc[custom_order])
    f.write(df_pretty_chopped.to_string())

df_pretty[selected_cols]
# Out:
#                                                    time_full time_sampled  \
# filename
# CIC_IDS_2017_Multiclass                                7.7           8.6
# CIC_IOT_Dataset2023_Multiclass                         284.4         70.8
# IoT_23_Multiclass                                      8.1           4.8
# IoT_Network_Intrusion_Macro_Multiclass                 2.4           2.4
# IoT_Network_Intrusion_Micro_Multiclass                 5.6           3.6
# KDD_Cup_1999_Multiclass                                13.2          7.7
# UNSW_NB15_Multiclass                                   5.8           3.8
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass              24.2          5.0
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass         6.1           4.1
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                 8.4           3.6
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                  0.7           0.7
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...     5.4           1.8
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass             3.2           2.3
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass          8.4           3.5
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass               9.5           2.7
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass               1.9           1.6
# BoT_IoT_Macro_Multiclass                               15.8          9.1
# BoT_IoT_Micro_Multiclass                               33.1          18.2
# CICAPT_IIoT_Phase1_Macro_Multiclass                    nan           nan
# CICAPT_IIoT_Phase1_Micro_Multiclass                    nan           nan
# CICAPT_IIoT_Phase2_Macro_Multiclass                    62.3          8.4
# CICAPT_IIoT_Phase2_Micro_Multiclass                    24.6          3.4
# CICEVSE2024_EVSE-A_Macro_Multiclass                    4.8           4.8
# CICEVSE2024_EVSE-A_Micro_Multiclass                    6.4           5.6
# CICEVSE2024_EVSE-B_Macro_Multiclass                    6.1           4.3
# CICEVSE2024_EVSE-B_Micro_Multiclass                    7.2           5.7
# CICIoMT2024_Bluetooth_Multiclass                       0.4           0.1
# CICIoMT2024_WiFi_and_MQTT_Multiclass                   40.0          12.8
# CICIoV2024_Decimal_Macro_Multiclass                    0.5           0.2
# CICIoV2024_Decimal_Micro_Multiclass                    0.8           1.0
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                   10.9          4.3
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                    6.3           4.0
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass             1.1           1.0
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass             0.8           0.8
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass            1.0           0.7
# NIDS_CIC-BoT-IoT_Multiclass                            10.8          2.6
# NIDS_CIC-ToN-IoT_Multiclass                            3.5           2.3
# NIDS_NF-BoT-IoT_Multiclass                             1.4           1.1
# NIDS_NF-BoT-IoT-v2_Multiclass                          9.7           3.1
# NIDS_NF-BoT-IoT-v3_Multiclass                          13.7          8.9
# NIDS_NF-CICIDS2018-v3_Multiclass                       34.6          5.5
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                     7.2           4.0
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                  16.1          5.1
# NIDS_NF-ToN-IoT_Multiclass                             9.0           4.0
# NIDS_NF-ToN-IoT-v2_Multiclass                          54.6          14.1
# NIDS_NF-ToN-IoT-v3_Multiclass                          39.0          8.5
# NIDS_NF-UNSW-NB15_Multiclass                           10.8          3.8
# NIDS_NF-UNSW-NB15-v2_Multiclass                        9.4           2.8
# NIDS_NF-UNSW-NB15-v3_Multiclass                        13.1          3.1
# NIDS_NF-UQ-NIDS_Multiclass                             25.9          8.2
# NIDS_NF-UQ-NIDS-v2_Multiclass                          68.7          21.2
# N_BaIoT_Danmini_Doorbell_Multiclass                    11.2          8.7
# N_BaIoT_Ecobee_Thermostat_Multiclass                   7.3           4.8
# N_BaIoT_Ennio_Doorbell_Multiclass                      2.3           4.5
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass        8.6           5.2
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...     8.3           10.2
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...     8.9           9.1
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass           2.7           6.1
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...     11.0          7.8
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...     8.9           10.8
# ToN_IoT_IoT_Fridge_Multiclass                          0.6           0.3
# ToN_IoT_IoT_GPS_Tracker_Multiclass                     0.9           0.8
# ToN_IoT_IoT_Garage_Door_Multiclass                     0.6           0.5
# ToN_IoT_IoT_Modbus_Multiclass                          0.9           0.9
# ToN_IoT_IoT_Motion_Light_Multiclass                    0.4           0.3
# ToN_IoT_IoT_Thermostat_Multiclass                      1.6           0.9
# ToN_IoT_IoT_Weather_Multiclass                         16.0          8.9
# ToN_IoT_Linux_Disk_Multiclass                          2.1           1.5
# ToN_IoT_Linux_Memory_Multiclass                        9.5           3.4
# ToN_IoT_Linux_Process_Multiclass                       2.2           1.6
# ToN_IoT_Network_Multiclass                             14.3          6.4
# ToN_IoT_Windows_10_Multiclass                          2.2           1.5
# ToN_IoT_Windows_7_Multiclass                           2.0           1.8
#
#                                                    time_reduced time_filtered  \
# filename
# CIC_IDS_2017_Multiclass                                    8.8           3.7
# CIC_IOT_Dataset2023_Multiclass                             60.1          12.9
# IoT_23_Multiclass                                          7.4           2.2
# IoT_Network_Intrusion_Macro_Multiclass                     1.9           1.2
# IoT_Network_Intrusion_Micro_Multiclass                     3.2           2.4
# KDD_Cup_1999_Multiclass                                    5.0           1.3
# UNSW_NB15_Multiclass                                       3.2           3.8
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                  4.4           2.8
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass             4.4           9.8
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                     5.2           3.4
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                      0.6           0.6
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...         1.5           1.3
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                 3.0           1.8
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass              5.8           0.4
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                   2.4           2.0
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                   1.2           0.4
# BoT_IoT_Macro_Multiclass                                   9.5           1.9
# BoT_IoT_Micro_Multiclass                                   15.6          2.4
# CICAPT_IIoT_Phase1_Macro_Multiclass                        nan           nan
# CICAPT_IIoT_Phase1_Micro_Multiclass                        nan           nan
# CICAPT_IIoT_Phase2_Macro_Multiclass                        8.8           12.8
# CICAPT_IIoT_Phase2_Micro_Multiclass                        6.9           3.1
# CICEVSE2024_EVSE-A_Macro_Multiclass                        3.8           3.2
# CICEVSE2024_EVSE-A_Micro_Multiclass                        10.9          2.9
# CICEVSE2024_EVSE-B_Macro_Multiclass                        9.5           2.0
# CICEVSE2024_EVSE-B_Micro_Multiclass                        12.1          2.3
# CICIoMT2024_Bluetooth_Multiclass                           0.1           0.1
# CICIoMT2024_WiFi_and_MQTT_Multiclass                       11.1          4.8
# CICIoV2024_Decimal_Macro_Multiclass                        0.3           0.3
# CICIoV2024_Decimal_Micro_Multiclass                        0.6           0.7
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                       12.7          1.0
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                        2.8           1.2
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                 0.9           0.3
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                 0.9           0.7
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                0.5           0.6
# NIDS_CIC-BoT-IoT_Multiclass                                2.1           2.5
# NIDS_CIC-ToN-IoT_Multiclass                                2.0           1.9
# NIDS_NF-BoT-IoT_Multiclass                                 1.7           1.1
# NIDS_NF-BoT-IoT-v2_Multiclass                              1.8           0.9
# NIDS_NF-BoT-IoT-v3_Multiclass                              9.5           4.0
# NIDS_NF-CICIDS2018-v3_Multiclass                           5.1           3.2
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                         3.7           1.7
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                      4.7           3.4
# NIDS_NF-ToN-IoT_Multiclass                                 3.8           2.1
# NIDS_NF-ToN-IoT-v2_Multiclass                              13.4          5.1
# NIDS_NF-ToN-IoT-v3_Multiclass                              10.1          2.0
# NIDS_NF-UNSW-NB15_Multiclass                               5.0           2.2
# NIDS_NF-UNSW-NB15-v2_Multiclass                            3.6           2.2
# NIDS_NF-UNSW-NB15-v3_Multiclass                            3.6           3.1
# NIDS_NF-UQ-NIDS_Multiclass                                 9.6           5.1
# NIDS_NF-UQ-NIDS-v2_Multiclass                              37.1          4.3
# N_BaIoT_Danmini_Doorbell_Multiclass                        5.8           2.3
# N_BaIoT_Ecobee_Thermostat_Multiclass                       4.4           2.6
# N_BaIoT_Ennio_Doorbell_Multiclass                          1.9           0.8
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass            3.7           2.4
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...         6.2           1.4
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...         3.5           1.6
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass               2.3           0.9
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...         6.1           1.8
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...         5.6           2.9
# ToN_IoT_IoT_Fridge_Multiclass                              0.5           0.4
# ToN_IoT_IoT_GPS_Tracker_Multiclass                         0.6           0.8
# ToN_IoT_IoT_Garage_Door_Multiclass                         0.4           0.4
# ToN_IoT_IoT_Modbus_Multiclass                              0.6           0.8
# ToN_IoT_IoT_Motion_Light_Multiclass                        0.3           0.3
# ToN_IoT_IoT_Thermostat_Multiclass                          0.8           0.7
# ToN_IoT_IoT_Weather_Multiclass                             9.3           1.7
# ToN_IoT_Linux_Disk_Multiclass                              1.6           1.3
# ToN_IoT_Linux_Memory_Multiclass                            2.7           1.3
# ToN_IoT_Linux_Process_Multiclass                           1.5           1.4
# ToN_IoT_Network_Multiclass                                 5.9           3.0
# ToN_IoT_Windows_10_Multiclass                              1.2           0.9
# ToN_IoT_Windows_7_Multiclass                               1.9           1.5
#
#                                                    time_hpo_min
# filename
# CIC_IDS_2017_Multiclass                                    4.3
# CIC_IOT_Dataset2023_Multiclass                             15.9
# IoT_23_Multiclass                                          4.6
# IoT_Network_Intrusion_Macro_Multiclass                     2.1
# IoT_Network_Intrusion_Micro_Multiclass                     2.7
# KDD_Cup_1999_Multiclass                                    3.8
# UNSW_NB15_Multiclass                                       4.7
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                  4.3
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass             4.6
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                     5.2
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                      0.9
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...         2.6
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                 3.5
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass              1.7
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                   2.6
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                   1.3
# BoT_IoT_Macro_Multiclass                                   2.7
# BoT_IoT_Micro_Multiclass                                   4.9
# CICAPT_IIoT_Phase1_Macro_Multiclass                        nan
# CICAPT_IIoT_Phase1_Micro_Multiclass                        nan
# CICAPT_IIoT_Phase2_Macro_Multiclass                        7.7
# CICAPT_IIoT_Phase2_Micro_Multiclass                        2.9
# CICEVSE2024_EVSE-A_Macro_Multiclass                        5.3
# CICEVSE2024_EVSE-A_Micro_Multiclass                        7.3
# CICEVSE2024_EVSE-B_Macro_Multiclass                        5.1
# CICEVSE2024_EVSE-B_Micro_Multiclass                        6.4
# CICIoMT2024_Bluetooth_Multiclass                           0.5
# CICIoMT2024_WiFi_and_MQTT_Multiclass                       7.2
# CICIoV2024_Decimal_Macro_Multiclass                        0.6
# CICIoV2024_Decimal_Micro_Multiclass                        0.9
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                       3.8
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                        3.0
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                 1.0
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                 1.3
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                1.1
# NIDS_CIC-BoT-IoT_Multiclass                                4.0
# NIDS_CIC-ToN-IoT_Multiclass                                3.9
# NIDS_NF-BoT-IoT_Multiclass                                 1.7
# NIDS_NF-BoT-IoT-v2_Multiclass                              2.1
# NIDS_NF-BoT-IoT-v3_Multiclass                              2.5
# NIDS_NF-CICIDS2018-v3_Multiclass                           6.7
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                         3.7
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                      4.7
# NIDS_NF-ToN-IoT_Multiclass                                 3.5
# NIDS_NF-ToN-IoT-v2_Multiclass                              5.7
# NIDS_NF-ToN-IoT-v3_Multiclass                              5.5
# NIDS_NF-UNSW-NB15_Multiclass                               3.4
# NIDS_NF-UNSW-NB15-v2_Multiclass                            3.5
# NIDS_NF-UNSW-NB15-v3_Multiclass                            3.5
# NIDS_NF-UQ-NIDS_Multiclass                                 6.1
# NIDS_NF-UQ-NIDS-v2_Multiclass                              8.2
# N_BaIoT_Danmini_Doorbell_Multiclass                        3.8
# N_BaIoT_Ecobee_Thermostat_Multiclass                       4.0
# N_BaIoT_Ennio_Doorbell_Multiclass                          2.3
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass            4.2
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...         3.9
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...         4.2
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass               2.3
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...         4.7
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...         3.9
# ToN_IoT_IoT_Fridge_Multiclass                              1.1
# ToN_IoT_IoT_GPS_Tracker_Multiclass                         1.5
# ToN_IoT_IoT_Garage_Door_Multiclass                         1.3
# ToN_IoT_IoT_Modbus_Multiclass                              1.1
# ToN_IoT_IoT_Motion_Light_Multiclass                        1.8
# ToN_IoT_IoT_Thermostat_Multiclass                          1.3
# ToN_IoT_IoT_Weather_Multiclass                             1.9
# ToN_IoT_Linux_Disk_Multiclass                              2.2
# ToN_IoT_Linux_Memory_Multiclass                            2.1
# ToN_IoT_Linux_Process_Multiclass                           2.5
# ToN_IoT_Network_Multiclass                                 4.0
# ToN_IoT_Windows_10_Multiclass                              1.9
# ToN_IoT_Windows_7_Multiclass                               2.0

# %%
df_pretty.shape
# Out:
# (73, 29)

# %%
# Define target and metrics
target_col = 'overall_difficulty'
perf_cols = ['time_full', 'time_sampled', 'time_reduced', 'time_filtered', 'time_hpo_min']
methods = ['pearson', 'spearman', 'kendall']

# Ensure numeric types
df_numeric = df_numeric.copy()
df_numeric[target_col] = df_numeric[target_col].astype(float)
for col in perf_cols:
    df_numeric[col] = df_numeric[col].astype(float)

# Compute all correlations into a dictionary
corr_data = {}
for method in methods:
    corr = (
        df_numeric[perf_cols + [target_col]]
        .corr(method=method)
        .loc[perf_cols, target_col]
    )
    corr_data[method] = corr

# Combine into a single DataFrame
df_corr_all = pd.DataFrame(corr_data)
df_corr_all.index.name = 'metric'
df_corr_all.reset_index(inplace=True)

# Export to .tex with aligned source formatting
# df_pretty.to_latex("table_3.tex", header=True, index=True, escape=False)
with open("table_4.tex", "w") as f:
    f.write(format_and_pad_all_columns(df_corr_all).to_string())

df_corr_all
# Out:
#           metric   pearson  spearman   kendall
# 0      time_full -0.083516 -0.060605 -0.053145
# 1   time_sampled -0.165782 -0.250061 -0.174367
# 2   time_reduced -0.087644 -0.159161 -0.111645
# 3  time_filtered -0.080975 -0.047921 -0.035536
# 4   time_hpo_min -0.207881 -0.203916 -0.142891

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# 🔧 Set global font sizes
plt.rcParams.update({
    'font.size': 18,            # Base font size
    'axes.titlesize': 20,       # Title font
    'axes.labelsize': 18,       # Axis labels
    'xtick.labelsize': 16,      # Tick labels
    'ytick.labelsize': 16,
    'legend.fontsize': 16,      # Legend
    'figure.titlesize': 22      # Figure title
})

def bootstrap_kde_ci(data, x_vals, n_boot=1000, ci=95):
    boot_kdes = np.zeros((n_boot, len(x_vals)))
    for i in range(n_boot):
        sample = np.random.choice(data, size=len(data), replace=True)
        kde = gaussian_kde(sample)
        boot_kdes[i] = kde(x_vals)
    lower = np.percentile(boot_kdes, (100 - ci) / 2, axis=0)
    upper = np.percentile(boot_kdes, 100 - (100 - ci) / 2, axis=0)
    return lower, upper

# Setup
ref_col = "time_full"
columns = [col for col in perf_cols if col != ref_col]
x_vals = np.linspace(df_numeric[perf_cols].min().min(),
                     df_numeric[perf_cols].max().max(), 500)

df_numeric["time_full"] = pd.to_numeric(df_numeric["time_full"], errors="coerce")
ref_data = df_numeric["time_full"].dropna().astype(float).values
ref_kde = gaussian_kde(ref_data)(x_vals)
ref_lower, ref_upper = bootstrap_kde_ci(ref_data, x_vals)

col_map = {
    'time_full': 'Baseline (Full)',
    'time_sampled': 'Sampled ($S$)',
    'time_reduced': 'Reduced ($R$)',
    'time_filtered': 'Filtered ($F$)',
    'time_hpo_min': 'HPO (Min)'
}

for col in columns:
    df_numeric[col] = pd.to_numeric(df_numeric[col], errors="coerce")
    target_data = df_numeric[col].dropna().astype(float).values
    target_kde = gaussian_kde(target_data)(x_vals)
    target_lower, target_upper = bootstrap_kde_ci(target_data, x_vals)

    # Difference and CI
    diff = target_kde - ref_kde
    diff_lower = target_lower - ref_upper
    diff_upper = target_upper - ref_lower

    # Plot
    plt.figure(figsize=(20, 5.5))
    plt.plot(x_vals, ref_kde, label=f"{col_map[ref_col]}", color='black', linestyle='--')
    plt.plot(x_vals, target_kde, label=f"{col_map[col]}", color='darkblue')
    plt.plot(x_vals, diff, label=f"Δ {col_map[col]} - {col_map[ref_col]}", color='blue')
    plt.fill_between(x_vals, diff_lower, diff_upper, alpha=0.2, color='blue', label="95% CI")
    plt.axhline(0, color='gray', linestyle='--', linewidth=1)

    # Labels
    plt.xlabel("Normalized Value")
    plt.ylabel("Density / Difference")
    plt.legend()
    plt.tight_layout()

    # Save and show
    plt.savefig(f"plots/kde_{col}_vs_{ref_col}.pdf", dpi=300)
    plt.show()
    plt.close()

# %% [markdown]
# # Model Size Analysis

# %%
# Columns to compare against "full"
cols_to_compare = ['size_sampled', 'size_reduced', 'size_filtered', 'size_hpo_min']

# Make a numeric copy to compute differences safely
df_numeric = df_pretty.copy()

# Compute best alternative and delta
# best_alternative = df_numeric[cols_to_compare].max(axis=1)
# df_pretty['size_delta_abs'] = best_alternative - df_numeric['size_full']
# df_pretty['size_delta_pct'] = df_pretty['size_delta_abs'] / df_numeric['size_full']

# # Enforce +/- signs and percentage for 2nd col
# df_pretty['size_delta_abs'] = df_pretty['size_delta_abs'].map(lambda x: f"{x:+.3f}")
# df_pretty['size_delta_pct'] = df_pretty['size_delta_pct'].apply(lambda x: f"{x * 100:+.2f}")

# Apply to your DataFrame
df_pretty = format_and_pad_all_columns(df_pretty.loc[custom_order])

# Export to .tex with aligned source formatting
# df_pretty.to_latex("table_3.tex", header=True, index=True, escape=False)
selected_cols = ["size_full", "size_sampled", "size_reduced", "size_filtered", "size_hpo_min"]
with open("table_3.tex", "w") as f:
    df_pretty_chopped = df_pretty[selected_cols]
    df_pretty_chopped = format_and_pad_all_columns(df_pretty_chopped.loc[custom_order])
    f.write(df_pretty_chopped.to_string())

df_pretty[selected_cols]
# Out:
#                                                    size_full size_sampled  \
# filename
# CIC_IDS_2017_Multiclass                                2.70         2.48
# CIC_IOT_Dataset2023_Multiclass                         52.26        15.24
# IoT_23_Multiclass                                      2.67         1.33
# IoT_Network_Intrusion_Macro_Multiclass                 1.51         0.58
# IoT_Network_Intrusion_Micro_Multiclass                 2.29         0.79
# KDD_Cup_1999_Multiclass                                2.34         1.71
# UNSW_NB15_Multiclass                                   3.13         1.76
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass              10.69        2.16
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass         1.22         0.80
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                 6.81         2.21
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                  0.07         0.09
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...     4.20         0.77
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass             1.44         0.61
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass          5.17         2.06
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass               1.87         0.55
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass               1.52         0.53
# BoT_IoT_Macro_Multiclass                               4.59         3.27
# BoT_IoT_Micro_Multiclass                               10.32        6.01
# CICAPT_IIoT_Phase1_Macro_Multiclass                    nan          nan
# CICAPT_IIoT_Phase1_Micro_Multiclass                    nan          nan
# CICAPT_IIoT_Phase2_Macro_Multiclass                    6.48         1.99
# CICAPT_IIoT_Phase2_Micro_Multiclass                    2.74         0.78
# CICEVSE2024_EVSE-A_Macro_Multiclass                    1.23         0.87
# CICEVSE2024_EVSE-A_Micro_Multiclass                    1.82         1.26
# CICEVSE2024_EVSE-B_Macro_Multiclass                    1.84         1.36
# CICEVSE2024_EVSE-B_Micro_Multiclass                    2.31         1.55
# CICIoMT2024_Bluetooth_Multiclass                       0.05         0.01
# CICIoMT2024_WiFi_and_MQTT_Multiclass                   9.04         3.54
# CICIoV2024_Decimal_Macro_Multiclass                    0.13         0.08
# CICIoV2024_Decimal_Micro_Multiclass                    0.30         0.28
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                   3.18         1.28
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                    1.58         1.00
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass             0.24         0.30
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass             0.26         0.26
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass            0.28         0.22
# NIDS_CIC-BoT-IoT_Multiclass                            18.15        4.02
# NIDS_CIC-ToN-IoT_Multiclass                            1.46         0.91
# NIDS_NF-BoT-IoT_Multiclass                             0.70         0.48
# NIDS_NF-BoT-IoT-v2_Multiclass                          8.56         1.51
# NIDS_NF-BoT-IoT-v3_Multiclass                          4.79         3.25
# NIDS_NF-CICIDS2018-v3_Multiclass                       5.15         1.41
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                     2.02         1.00
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                  4.12         1.16
# NIDS_NF-ToN-IoT_Multiclass                             3.38         1.34
# NIDS_NF-ToN-IoT-v2_Multiclass                          10.85        3.33
# NIDS_NF-ToN-IoT-v3_Multiclass                          10.62        3.72
# NIDS_NF-UNSW-NB15_Multiclass                           4.28         1.10
# NIDS_NF-UNSW-NB15-v2_Multiclass                        2.89         0.80
# NIDS_NF-UNSW-NB15-v3_Multiclass                        3.62         0.90
# NIDS_NF-UQ-NIDS_Multiclass                             7.83         2.74
# NIDS_NF-UQ-NIDS-v2_Multiclass                          21.64        7.01
# N_BaIoT_Danmini_Doorbell_Multiclass                    3.02         2.69
# N_BaIoT_Ecobee_Thermostat_Multiclass                   1.83         1.35
# N_BaIoT_Ennio_Doorbell_Multiclass                      0.75         1.00
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass        2.32         1.58
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...     2.61         3.48
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...     2.38         3.01
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass           0.95         1.55
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...     2.27         2.43
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...     2.39         2.95
# ToN_IoT_IoT_Fridge_Multiclass                          0.20         0.11
# ToN_IoT_IoT_GPS_Tracker_Multiclass                     0.55         0.20
# ToN_IoT_IoT_Garage_Door_Multiclass                     0.10         0.10
# ToN_IoT_IoT_Modbus_Multiclass                          0.75         0.46
# ToN_IoT_IoT_Motion_Light_Multiclass                    0.09         0.09
# ToN_IoT_IoT_Thermostat_Multiclass                      0.70         0.41
# ToN_IoT_IoT_Weather_Multiclass                         7.41         4.54
# ToN_IoT_Linux_Disk_Multiclass                          4.18         1.38
# ToN_IoT_Linux_Memory_Multiclass                        58.14        10.53
# ToN_IoT_Linux_Process_Multiclass                       4.87         2.49
# ToN_IoT_Network_Multiclass                             6.51         2.26
# ToN_IoT_Windows_10_Multiclass                          0.51         0.29
# ToN_IoT_Windows_7_Multiclass                           0.42         0.36
#
#                                                    size_reduced size_filtered  \
# filename
# CIC_IDS_2017_Multiclass                                   2.23           0.90
# CIC_IOT_Dataset2023_Multiclass                            11.45          3.15
# IoT_23_Multiclass                                         1.64           0.54
# IoT_Network_Intrusion_Macro_Multiclass                    0.54           0.33
# IoT_Network_Intrusion_Micro_Multiclass                    0.87           0.63
# KDD_Cup_1999_Multiclass                                   1.30           0.30
# UNSW_NB15_Multiclass                                      1.65           1.45
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                 2.35           1.52
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass            0.90           2.31
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                    2.27           1.76
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                     0.05           0.06
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...        0.76           0.78
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                0.62           0.46
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass             1.19           0.09
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                  0.51           0.47
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                  0.73           0.11
# BoT_IoT_Macro_Multiclass                                  3.34           0.59
# BoT_IoT_Micro_Multiclass                                  5.12           0.83
# CICAPT_IIoT_Phase1_Macro_Multiclass                       nan            nan
# CICAPT_IIoT_Phase1_Micro_Multiclass                       nan            nan
# CICAPT_IIoT_Phase2_Macro_Multiclass                       2.00           3.02
# CICAPT_IIoT_Phase2_Micro_Multiclass                       1.37           0.59
# CICEVSE2024_EVSE-A_Macro_Multiclass                       0.96           0.62
# CICEVSE2024_EVSE-A_Micro_Multiclass                       3.12           0.64
# CICEVSE2024_EVSE-B_Macro_Multiclass                       2.82           0.43
# CICEVSE2024_EVSE-B_Micro_Multiclass                       3.38           0.47
# CICIoMT2024_Bluetooth_Multiclass                          0.01           0.01
# CICIoMT2024_WiFi_and_MQTT_Multiclass                      2.88           1.11
# CICIoV2024_Decimal_Macro_Multiclass                       0.08           0.11
# CICIoV2024_Decimal_Micro_Multiclass                       0.23           0.27
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                      3.52           0.21
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                       0.78           0.19
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                0.32           0.12
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                0.24           0.16
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass               0.20           0.24
# NIDS_CIC-BoT-IoT_Multiclass                               4.44           3.63
# NIDS_CIC-ToN-IoT_Multiclass                               0.93           0.71
# NIDS_NF-BoT-IoT_Multiclass                                0.45           0.39
# NIDS_NF-BoT-IoT-v2_Multiclass                             1.55           0.86
# NIDS_NF-BoT-IoT-v3_Multiclass                             2.88           1.04
# NIDS_NF-CICIDS2018-v3_Multiclass                          1.54           0.83
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                        0.93           0.48
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                     1.15           0.99
# NIDS_NF-ToN-IoT_Multiclass                                1.22           0.68
# NIDS_NF-ToN-IoT-v2_Multiclass                             3.34           1.75
# NIDS_NF-ToN-IoT-v3_Multiclass                             3.94           0.85
# NIDS_NF-UNSW-NB15_Multiclass                              1.29           0.61
# NIDS_NF-UNSW-NB15-v2_Multiclass                           0.84           0.59
# NIDS_NF-UNSW-NB15-v3_Multiclass                           0.96           0.87
# NIDS_NF-UQ-NIDS_Multiclass                                2.81           1.40
# NIDS_NF-UQ-NIDS-v2_Multiclass                             6.17           1.63
# N_BaIoT_Danmini_Doorbell_Multiclass                       2.05           1.03
# N_BaIoT_Ecobee_Thermostat_Multiclass                      1.52           1.05
# N_BaIoT_Ennio_Doorbell_Multiclass                         0.50           0.20
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass           1.36           1.48
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...        3.15           2.06
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...        1.64           1.92
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass              0.57           0.21
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...        3.08           2.40
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...        1.92           1.49
# ToN_IoT_IoT_Fridge_Multiclass                             0.11           0.10
# ToN_IoT_IoT_GPS_Tracker_Multiclass                        0.20           0.26
# ToN_IoT_IoT_Garage_Door_Multiclass                        0.10           0.09
# ToN_IoT_IoT_Modbus_Multiclass                             0.45           0.45
# ToN_IoT_IoT_Motion_Light_Multiclass                       0.09           0.09
# ToN_IoT_IoT_Thermostat_Multiclass                         0.41           0.30
# ToN_IoT_IoT_Weather_Multiclass                            4.54           0.91
# ToN_IoT_Linux_Disk_Multiclass                             1.38           1.54
# ToN_IoT_Linux_Memory_Multiclass                           10.78          5.65
# ToN_IoT_Linux_Process_Multiclass                          2.41           1.99
# ToN_IoT_Network_Multiclass                                2.09           0.88
# ToN_IoT_Windows_10_Multiclass                             0.28           0.28
# ToN_IoT_Windows_7_Multiclass                              0.35           0.36
#
#                                                    size_hpo_min
# filename
# CIC_IDS_2017_Multiclass                                    0.09
# CIC_IOT_Dataset2023_Multiclass                             0.22
# IoT_23_Multiclass                                          0.10
# IoT_Network_Intrusion_Macro_Multiclass                     0.03
# IoT_Network_Intrusion_Micro_Multiclass                     0.07
# KDD_Cup_1999_Multiclass                                    0.16
# UNSW_NB15_Multiclass                                       0.07
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                  0.08
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass             0.08
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                     0.09
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                      0.01
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...         0.03
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                 0.06
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass              0.03
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                   0.03
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                   0.03
# BoT_IoT_Macro_Multiclass                                   0.03
# BoT_IoT_Micro_Multiclass                                   0.07
# CICAPT_IIoT_Phase1_Macro_Multiclass                        nan
# CICAPT_IIoT_Phase1_Micro_Multiclass                        nan
# CICAPT_IIoT_Phase2_Macro_Multiclass                        2.27
# CICAPT_IIoT_Phase2_Micro_Multiclass                        0.34
# CICEVSE2024_EVSE-A_Macro_Multiclass                        0.10
# CICEVSE2024_EVSE-A_Micro_Multiclass                        0.17
# CICEVSE2024_EVSE-B_Macro_Multiclass                        0.13
# CICEVSE2024_EVSE-B_Micro_Multiclass                        0.19
# CICIoMT2024_Bluetooth_Multiclass                           0.01
# CICIoMT2024_WiFi_and_MQTT_Multiclass                       0.12
# CICIoV2024_Decimal_Macro_Multiclass                        0.19
# CICIoV2024_Decimal_Micro_Multiclass                        0.40
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                       0.09
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                        0.09
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                 0.03
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                 0.06
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                0.03
# NIDS_CIC-BoT-IoT_Multiclass                                0.03
# NIDS_CIC-ToN-IoT_Multiclass                                0.06
# NIDS_NF-BoT-IoT_Multiclass                                 0.03
# NIDS_NF-BoT-IoT-v2_Multiclass                              0.03
# NIDS_NF-BoT-IoT-v3_Multiclass                              0.03
# NIDS_NF-CICIDS2018-v3_Multiclass                           0.09
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                         0.09
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                      0.09
# NIDS_NF-ToN-IoT_Multiclass                                 0.06
# NIDS_NF-ToN-IoT-v2_Multiclass                              0.08
# NIDS_NF-ToN-IoT-v3_Multiclass                              0.06
# NIDS_NF-UNSW-NB15_Multiclass                               0.06
# NIDS_NF-UNSW-NB15-v2_Multiclass                            0.06
# NIDS_NF-UNSW-NB15-v3_Multiclass                            0.06
# NIDS_NF-UQ-NIDS_Multiclass                                 0.13
# NIDS_NF-UQ-NIDS-v2_Multiclass                              0.13
# N_BaIoT_Danmini_Doorbell_Multiclass                        0.07
# N_BaIoT_Ecobee_Thermostat_Multiclass                       0.07
# N_BaIoT_Ennio_Doorbell_Multiclass                          0.04
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass            0.07
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...         0.07
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...         0.07
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass               0.04
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...         0.07
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...         0.07
# ToN_IoT_IoT_Fridge_Multiclass                              0.05
# ToN_IoT_IoT_GPS_Tracker_Multiclass                         0.05
# ToN_IoT_IoT_Garage_Door_Multiclass                         0.05
# ToN_IoT_IoT_Modbus_Multiclass                              0.04
# ToN_IoT_IoT_Motion_Light_Multiclass                        0.06
# ToN_IoT_IoT_Thermostat_Multiclass                          0.04
# ToN_IoT_IoT_Weather_Multiclass                             0.05
# ToN_IoT_Linux_Disk_Multiclass                              0.05
# ToN_IoT_Linux_Memory_Multiclass                            0.04
# ToN_IoT_Linux_Process_Multiclass                           0.05
# ToN_IoT_Network_Multiclass                                 0.06
# ToN_IoT_Windows_10_Multiclass                              0.12
# ToN_IoT_Windows_7_Multiclass                               0.05

# %%
df_pretty.shape
# Out:
# (73, 29)

# %%
# Define target and metrics
target_col = 'overall_difficulty'
perf_cols = ['size_full', 'size_sampled', 'size_reduced', 'size_filtered', 'size_hpo_min']
methods = ['pearson', 'spearman', 'kendall']

# Ensure numeric types
df_numeric = df_numeric.copy()
df_numeric[target_col] = df_numeric[target_col].astype(float)
for col in perf_cols:
    df_numeric[col] = df_numeric[col].astype(float)

# Compute all correlations into a dictionary
corr_data = {}
for method in methods:
    corr = (
        df_numeric[perf_cols + [target_col]]
        .corr(method=method)
        .loc[perf_cols, target_col]
    )
    corr_data[method] = corr

# Combine into a single DataFrame
df_corr_all = pd.DataFrame(corr_data)
df_corr_all.index.name = 'metric'
df_corr_all.reset_index(inplace=True)

# Export to .tex with aligned source formatting
# df_pretty.to_latex("table_3.tex", header=True, index=True, escape=False)
with open("table_4.tex", "w") as f:
    f.write(format_and_pad_all_columns(df_corr_all).to_string())

df_corr_all
# Out:
#           metric   pearson  spearman   kendall
# 0      size_full  0.098631  0.129461  0.083731
# 1   size_sampled -0.032223 -0.077147 -0.055164
# 2   size_reduced  0.016240 -0.028373 -0.016183
# 3  size_filtered -0.025763 -0.043956 -0.026152
# 4   size_hpo_min -0.042885 -0.174109 -0.121819

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# 🔧 Set global font sizes
plt.rcParams.update({
    'font.size': 18,            # Base font size
    'axes.titlesize': 20,       # Title font
    'axes.labelsize': 18,       # Axis labels
    'xtick.labelsize': 16,      # Tick labels
    'ytick.labelsize': 16,
    'legend.fontsize': 16,      # Legend
    'figure.titlesize': 22      # Figure title
})

def bootstrap_kde_ci(data, x_vals, n_boot=1000, ci=95):
    boot_kdes = np.zeros((n_boot, len(x_vals)))
    for i in range(n_boot):
        sample = np.random.choice(data, size=len(data), replace=True)
        kde = gaussian_kde(sample)
        boot_kdes[i] = kde(x_vals)
    lower = np.percentile(boot_kdes, (100 - ci) / 2, axis=0)
    upper = np.percentile(boot_kdes, 100 - (100 - ci) / 2, axis=0)
    return lower, upper

# Setup
ref_col = "size_full"
columns = [col for col in perf_cols if col != ref_col]
x_vals = np.linspace(df_numeric[perf_cols].min().min(),
                     df_numeric[perf_cols].max().max(), 500)

df_numeric["size_full"] = pd.to_numeric(df_numeric["size_full"], errors="coerce")
ref_data = df_numeric["size_full"].dropna().astype(float).values
ref_kde = gaussian_kde(ref_data)(x_vals)
ref_lower, ref_upper = bootstrap_kde_ci(ref_data, x_vals)

col_map = {
    'size_full': 'Baseline (Full)',
    'size_sampled': 'Sampled ($S$)',
    'size_reduced': 'Reduced ($R$)',
    'size_filtered': 'Filtered ($F$)',
    'size_hpo_min': 'HPO (Min)'
}

for col in columns:
    df_numeric[col] = pd.to_numeric(df_numeric[col], errors="coerce")
    target_data = df_numeric[col].dropna().astype(float).values
    target_kde = gaussian_kde(target_data)(x_vals)
    target_lower, target_upper = bootstrap_kde_ci(target_data, x_vals)

    # Difference and CI
    diff = target_kde - ref_kde
    diff_lower = target_lower - ref_upper
    diff_upper = target_upper - ref_lower

    # Plot
    plt.figure(figsize=(20, 5.5))
    plt.plot(x_vals, ref_kde, label=f"{col_map[ref_col]}", color='black', linestyle='--')
    plt.plot(x_vals, target_kde, label=f"{col_map[col]}", color='darkblue')
    plt.plot(x_vals, diff, label=f"Δ {col_map[col]} - {col_map[ref_col]}", color='blue')
    plt.fill_between(x_vals, diff_lower, diff_upper, alpha=0.2, color='blue', label="95% CI")
    plt.axhline(0, color='gray', linestyle='--', linewidth=1)

    # Labels
    plt.xlabel("Normalized Value")
    plt.ylabel("Density / Difference")
    plt.legend()
    plt.tight_layout()

    # Save and show
    plt.savefig(f"plots/kde_{col}_vs_{ref_col}.pdf", dpi=300)
    plt.show()
    plt.close()

# %% [markdown]
# # ----

# %%
def summarize_results(df_filename, results_filename):
    df = pd.read_excel(results_filename)
    row_full = df.loc[df['Unnamed: 0'] == 'full', 'X_train_shape'].values[0]
    row_max = df.loc[df['f1_score_abs'].idxmax()].to_dict()
    if 'Unnamed: 0' in row_max:
        row_max['best_config'] = row_max.pop('Unnamed: 0')
    summary = {'filename': df_filename, 'shape': row_full,}
    summary.update(row_max)
    return summary

# %%
base_folder = Path("/home/automl/git/iot-threat-classifier/2025-06-28/Output_Multiclass")

summary_rows = []

# Find all .parquet files recursively
result_files = list(base_folder.rglob("*table.xlsx"))

# Iterate
for file in tqdm(result_files, desc='File', leave='False'):

    try:
        short_filename = str(file.parent.stem)
        row = summarize_results(short_filename, file)
        summary_rows.append(row)
        
    except (ValueError, Exception) as e:
        tqdm.write(f'[{now()}] ERROR      | FILE = {str(file.stem):<64} | EXCEPTION = {e}')
# Out:
# File:   0%|          | 0/66 [00:00<?, ?it/s]

# %%
output_df = pd.DataFrame(summary_rows).set_index("filename")

output_df
# Out:
#                                                             shape  \
# filename
# CICEVSE2024_EVSE-B_Macro_Multiclass                  (171987, 68)
# NIDS_NF-ToN-IoT-v2_Multiclass                        (699477, 38)
# ToN_IoT_Network_Multiclass                           (282243, 40)
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...  (329363, 115)
# NIDS_NF-BoT-IoT-v2_Multiclass                         (85853, 38)
# NIDS_CIC-ToN-IoT_Multiclass                          (101735, 71)
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass     (471723, 115)
# ToN_IoT_Linux_Disk_Multiclass                          (14495, 5)
# CICAPT_IIoT_Phase2_Macro_Multiclass                 (4925659, 48)
# NIDS_NF-CICIDS2018-v3_Multiclass                    (4910519, 45)
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass           (38160, 16)
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass       (1179830, 69)
# ToN_IoT_Windows_10_Multiclass                        (21129, 113)
# CICEVSE2024_EVSE-A_Micro_Multiclass                  (219912, 68)
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...  (306334, 115)
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass            (53526, 73)
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass            (23651, 28)
# CICIoMT2024_WiFi_and_MQTT_Multiclass                (1154546, 44)
# NIDS_NF-BoT-IoT-v3_Multiclass                        (409262, 46)
# ToN_IoT_IoT_Modbus_Multiclass                          (67704, 4)
# UNSW_NB15_Multiclass                                (1166862, 45)
# CICIoV2024_Decimal_Macro_Multiclass                     (2147, 8)
# NIDS_NF-UNSW-NB15_Multiclass                         (255828, 10)
# CICEVSE2024_EVSE-B_Micro_Multiclass                  (172005, 68)
# ToN_IoT_IoT_Weather_Multiclass                        (342921, 3)
# ToN_IoT_IoT_Thermostat_Multiclass                      (24391, 2)
# CICAPT_IIoT_Phase2_Micro_Multiclass                 (4925659, 48)
# N_BaIoT_Ennio_Doorbell_Multiclass                    (87626, 115)
# KDD_Cup_1999_Multiclass                              (645000, 40)
# NIDS_CIC-BoT-IoT_Multiclass                          (901752, 79)
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                   (234614, 10)
# CIC_IOT_Dataset2023_Multiclass                      (2692680, 39)
# NIDS_NF-UNSW-NB15-v2_Multiclass                       (87047, 38)
# N_BaIoT_Danmini_Doorbell_Multiclass                 (422925, 115)
# BoT_IoT_Macro_Multiclass                            (1022440, 20)
# CICIoV2024_Decimal_Micro_Multiclass                     (2152, 8)
# IoT_Network_Intrusion_Micro_Multiclass               (129388, 26)
# NIDS_NF-ToN-IoT_Multiclass                           (403383, 10)
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...  (268241, 115)
# ToN_IoT_Linux_Process_Multiclass                      (12552, 12)
# NIDS_NF-BoT-IoT_Multiclass                            (56502, 10)
# ToN_IoT_IoT_Fridge_Multiclass                            (635, 2)
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                   (91145, 41)
# N_BaIoT_Ecobee_Thermostat_Multiclass                (324583, 115)
# NIDS_NF-UQ-NIDS-v2_Multiclass                       (1922815, 38)
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass               (155135, 73)
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass            (175739, 73)
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass         (98625, 115)
# CICEVSE2024_EVSE-A_Macro_Multiclass                  (219912, 68)
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass             (1047, 17)
# IoT_Network_Intrusion_Macro_Multiclass               (129388, 26)
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                 (963847, 45)
# NIDS_NF-UNSW-NB15-v3_Multiclass                      (705875, 46)
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...  (284016, 115)
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass             (426999, 71)
# IoT_23_Multiclass                                    (218338, 12)
# ToN_IoT_IoT_GPS_Tracker_Multiclass                       (384, 2)
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass             (198839, 69)
# CIC_IDS_2017_Multiclass                              (750040, 70)
# NIDS_NF-ToN-IoT-v3_Multiclass                       (2528124, 46)
# BoT_IoT_Micro_Multiclass                            (1023353, 20)
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass               (1082471, 37)
# ToN_IoT_Windows_7_Multiclass                         (16859, 104)
# NIDS_NF-UQ-NIDS_Multiclass                           (355686, 10)
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...   (107055, 71)
# ToN_IoT_Linux_Memory_Multiclass                        (49634, 9)
#
#                                                     X_train_shape  \
# filename
# CICEVSE2024_EVSE-B_Macro_Multiclass                   (17190, 68)
# NIDS_NF-ToN-IoT-v2_Multiclass                        (699477, 38)
# ToN_IoT_Network_Multiclass                           (282243, 40)
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...  (329363, 115)
# NIDS_NF-BoT-IoT-v2_Multiclass                         (85853, 38)
# NIDS_CIC-ToN-IoT_Multiclass                           (10176, 31)
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass     (471723, 115)
# ToN_IoT_Linux_Disk_Multiclass                           (1445, 5)
# CICAPT_IIoT_Phase2_Macro_Multiclass                 (4925659, 48)
# NIDS_NF-CICIDS2018-v3_Multiclass                    (4910519, 45)
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass           (38160, 16)
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass       (1179830, 69)
# ToN_IoT_Windows_10_Multiclass                        (21129, 113)
# CICEVSE2024_EVSE-A_Micro_Multiclass                  (219912, 68)
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...  (306334, 115)
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass            (53526, 73)
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass            (23651, 28)
# CICIoMT2024_WiFi_and_MQTT_Multiclass                (1154546, 44)
# NIDS_NF-BoT-IoT-v3_Multiclass                        (409262, 46)
# ToN_IoT_IoT_Modbus_Multiclass                           (6087, 4)
# UNSW_NB15_Multiclass                                (1166862, 45)
# CICIoV2024_Decimal_Macro_Multiclass                     (2147, 8)
# NIDS_NF-UNSW-NB15_Multiclass                         (255828, 10)
# CICEVSE2024_EVSE-B_Micro_Multiclass                   (17187, 68)
# ToN_IoT_IoT_Weather_Multiclass                        (342921, 3)
# ToN_IoT_IoT_Thermostat_Multiclass                       (2436, 2)
# CICAPT_IIoT_Phase2_Micro_Multiclass                 (4925659, 48)
# N_BaIoT_Ennio_Doorbell_Multiclass                    (87626, 115)
# KDD_Cup_1999_Multiclass                              (645000, 40)
# NIDS_CIC-BoT-IoT_Multiclass                           (90173, 79)
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                    (23456, 10)
# CIC_IOT_Dataset2023_Multiclass                      (2692680, 39)
# NIDS_NF-UNSW-NB15-v2_Multiclass                       (87047, 38)
# N_BaIoT_Danmini_Doorbell_Multiclass                 (422925, 115)
# BoT_IoT_Macro_Multiclass                            (1022440, 20)
# CICIoV2024_Decimal_Micro_Multiclass                     (2152, 8)
# IoT_Network_Intrusion_Micro_Multiclass               (129388, 26)
# NIDS_NF-ToN-IoT_Multiclass                            (40334, 10)
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...  (268241, 115)
# ToN_IoT_Linux_Process_Multiclass                       (1251, 11)
# NIDS_NF-BoT-IoT_Multiclass                             (5647, 10)
# ToN_IoT_IoT_Fridge_Multiclass                             (63, 2)
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                   (91145, 41)
# N_BaIoT_Ecobee_Thermostat_Multiclass                (324583, 115)
# NIDS_NF-UQ-NIDS-v2_Multiclass                       (1922815, 38)
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass               (155135, 73)
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass            (175739, 73)
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass         (98625, 115)
# CICEVSE2024_EVSE-A_Macro_Multiclass                   (21990, 68)
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass             (1047, 17)
# IoT_Network_Intrusion_Macro_Multiclass               (129388, 26)
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                 (963847, 45)
# NIDS_NF-UNSW-NB15-v3_Multiclass                      (705875, 46)
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...  (284016, 115)
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass             (426999, 71)
# IoT_23_Multiclass                                    (218338, 12)
# ToN_IoT_IoT_GPS_Tracker_Multiclass                        (38, 2)
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass             (198839, 69)
# CIC_IDS_2017_Multiclass                              (750040, 70)
# NIDS_NF-ToN-IoT-v3_Multiclass                       (2528124, 46)
# BoT_IoT_Micro_Multiclass                            (1023353, 20)
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass               (1082471, 37)
# ToN_IoT_Windows_7_Multiclass                         (16859, 104)
# NIDS_NF-UQ-NIDS_Multiclass                           (355686, 10)
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...   (107055, 71)
# ToN_IoT_Linux_Memory_Multiclass                        (49634, 9)
#
#                                                       X_val_shape  \
# filename
# CICEVSE2024_EVSE-B_Macro_Multiclass                   (57329, 68)
# NIDS_NF-ToN-IoT-v2_Multiclass                        (233159, 38)
# ToN_IoT_Network_Multiclass                            (94081, 40)
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...  (109788, 115)
# NIDS_NF-BoT-IoT-v2_Multiclass                         (28617, 38)
# NIDS_CIC-ToN-IoT_Multiclass                           (33911, 31)
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass     (157241, 115)
# ToN_IoT_Linux_Disk_Multiclass                           (4832, 5)
# CICAPT_IIoT_Phase2_Macro_Multiclass                 (1641886, 48)
# NIDS_NF-CICIDS2018-v3_Multiclass                    (1636840, 45)
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass           (12720, 16)
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass        (393277, 69)
# ToN_IoT_Windows_10_Multiclass                         (7043, 113)
# CICEVSE2024_EVSE-A_Micro_Multiclass                   (73304, 68)
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...  (102111, 115)
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass            (17842, 73)
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass             (7884, 28)
# CICIoMT2024_WiFi_and_MQTT_Multiclass                 (384848, 44)
# NIDS_NF-BoT-IoT-v3_Multiclass                        (136420, 46)
# ToN_IoT_IoT_Modbus_Multiclass                          (22568, 4)
# UNSW_NB15_Multiclass                                 (388954, 45)
# CICIoV2024_Decimal_Macro_Multiclass                      (715, 8)
# NIDS_NF-UNSW-NB15_Multiclass                          (85276, 10)
# CICEVSE2024_EVSE-B_Micro_Multiclass                   (57335, 68)
# ToN_IoT_IoT_Weather_Multiclass                        (114307, 3)
# ToN_IoT_IoT_Thermostat_Multiclass                       (8130, 2)
# CICAPT_IIoT_Phase2_Micro_Multiclass                 (1641886, 48)
# N_BaIoT_Ennio_Doorbell_Multiclass                    (29209, 115)
# KDD_Cup_1999_Multiclass                              (215000, 40)
# NIDS_CIC-BoT-IoT_Multiclass                          (300584, 79)
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                    (78204, 10)
# CIC_IOT_Dataset2023_Multiclass                       (897560, 39)
# NIDS_NF-UNSW-NB15-v2_Multiclass                       (29015, 38)
# N_BaIoT_Danmini_Doorbell_Multiclass                 (140975, 115)
# BoT_IoT_Macro_Multiclass                             (340813, 20)
# CICIoV2024_Decimal_Micro_Multiclass                      (717, 8)
# IoT_Network_Intrusion_Micro_Multiclass                (43129, 26)
# NIDS_NF-ToN-IoT_Multiclass                           (134461, 10)
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...   (89414, 115)
# ToN_IoT_Linux_Process_Multiclass                       (4184, 11)
# NIDS_NF-BoT-IoT_Multiclass                            (18834, 10)
# ToN_IoT_IoT_Fridge_Multiclass                            (211, 2)
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                   (30382, 41)
# N_BaIoT_Ecobee_Thermostat_Multiclass                (108194, 115)
# NIDS_NF-UQ-NIDS-v2_Multiclass                        (640938, 38)
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                (51712, 73)
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass             (58580, 73)
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass         (32875, 115)
# CICEVSE2024_EVSE-A_Macro_Multiclass                   (73304, 68)
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass              (349, 17)
# IoT_Network_Intrusion_Macro_Multiclass                (43129, 26)
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                 (321282, 45)
# NIDS_NF-UNSW-NB15-v3_Multiclass                      (235291, 46)
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...   (94672, 115)
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass             (142333, 71)
# IoT_23_Multiclass                                     (72779, 12)
# ToN_IoT_IoT_GPS_Tracker_Multiclass                       (128, 2)
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass              (66280, 69)
# CIC_IDS_2017_Multiclass                              (250013, 70)
# NIDS_NF-ToN-IoT-v3_Multiclass                        (842708, 46)
# BoT_IoT_Micro_Multiclass                             (341118, 20)
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                (360823, 37)
# ToN_IoT_Windows_7_Multiclass                          (5619, 104)
# NIDS_NF-UQ-NIDS_Multiclass                           (118562, 10)
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...    (35685, 71)
# ToN_IoT_Linux_Memory_Multiclass                        (16544, 9)
#
#                                                      X_test_shape  \
# filename
# CICEVSE2024_EVSE-B_Macro_Multiclass                   (57329, 68)
# NIDS_NF-ToN-IoT-v2_Multiclass                        (233158, 38)
# ToN_IoT_Network_Multiclass                            (94081, 40)
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...  (109787, 115)
# NIDS_NF-BoT-IoT-v2_Multiclass                         (28617, 38)
# NIDS_CIC-ToN-IoT_Multiclass                           (33911, 31)
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass     (157240, 115)
# ToN_IoT_Linux_Disk_Multiclass                           (4831, 5)
# CICAPT_IIoT_Phase2_Macro_Multiclass                 (1641886, 48)
# NIDS_NF-CICIDS2018-v3_Multiclass                    (1636839, 45)
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass           (12720, 16)
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass        (393276, 69)
# ToN_IoT_Windows_10_Multiclass                         (7042, 113)
# CICEVSE2024_EVSE-A_Micro_Multiclass                   (73304, 68)
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...  (102111, 115)
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass            (17841, 73)
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass             (7883, 28)
# CICIoMT2024_WiFi_and_MQTT_Multiclass                 (384848, 44)
# NIDS_NF-BoT-IoT-v3_Multiclass                        (136420, 46)
# ToN_IoT_IoT_Modbus_Multiclass                          (22567, 4)
# UNSW_NB15_Multiclass                                 (388953, 45)
# CICIoV2024_Decimal_Macro_Multiclass                      (715, 8)
# NIDS_NF-UNSW-NB15_Multiclass                          (85276, 10)
# CICEVSE2024_EVSE-B_Micro_Multiclass                   (57335, 68)
# ToN_IoT_IoT_Weather_Multiclass                        (114307, 3)
# ToN_IoT_IoT_Thermostat_Multiclass                       (8130, 2)
# CICAPT_IIoT_Phase2_Micro_Multiclass                 (1641886, 48)
# N_BaIoT_Ennio_Doorbell_Multiclass                    (29208, 115)
# KDD_Cup_1999_Multiclass                              (214999, 40)
# NIDS_CIC-BoT-IoT_Multiclass                          (300583, 79)
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                    (78204, 10)
# CIC_IOT_Dataset2023_Multiclass                       (897560, 39)
# NIDS_NF-UNSW-NB15-v2_Multiclass                       (29015, 38)
# N_BaIoT_Danmini_Doorbell_Multiclass                 (140974, 115)
# BoT_IoT_Macro_Multiclass                             (340813, 20)
# CICIoV2024_Decimal_Micro_Multiclass                      (717, 8)
# IoT_Network_Intrusion_Micro_Multiclass                (43129, 26)
# NIDS_NF-ToN-IoT_Multiclass                           (134461, 10)
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...   (89413, 115)
# ToN_IoT_Linux_Process_Multiclass                       (4183, 11)
# NIDS_NF-BoT-IoT_Multiclass                            (18833, 10)
# ToN_IoT_IoT_Fridge_Multiclass                            (211, 2)
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                   (30381, 41)
# N_BaIoT_Ecobee_Thermostat_Multiclass                (108194, 115)
# NIDS_NF-UQ-NIDS-v2_Multiclass                        (640938, 38)
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                (51711, 73)
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass             (58579, 73)
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass         (32875, 115)
# CICEVSE2024_EVSE-A_Macro_Multiclass                   (73304, 68)
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass              (348, 17)
# IoT_Network_Intrusion_Macro_Multiclass                (43129, 26)
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                 (321282, 45)
# NIDS_NF-UNSW-NB15-v3_Multiclass                      (235291, 46)
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...   (94672, 115)
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass             (142332, 71)
# IoT_23_Multiclass                                     (72779, 12)
# ToN_IoT_IoT_GPS_Tracker_Multiclass                       (127, 2)
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass              (66279, 69)
# CIC_IDS_2017_Multiclass                              (250013, 70)
# NIDS_NF-ToN-IoT-v3_Multiclass                        (842707, 46)
# BoT_IoT_Micro_Multiclass                             (341117, 20)
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                (360823, 37)
# ToN_IoT_Windows_7_Multiclass                          (5619, 104)
# NIDS_NF-UQ-NIDS_Multiclass                           (118561, 10)
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...    (35684, 71)
# ToN_IoT_Linux_Memory_Multiclass                        (16544, 9)
#
#                                                     model_size_abs  \
# filename
# CICEVSE2024_EVSE-B_Macro_Multiclass                           1.36
# NIDS_NF-ToN-IoT-v2_Multiclass                                10.85
# ToN_IoT_Network_Multiclass                                    6.51
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...            2.39
# NIDS_NF-BoT-IoT-v2_Multiclass                                 8.56
# NIDS_CIC-ToN-IoT_Multiclass                                   0.93
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass               2.32
# ToN_IoT_Linux_Disk_Multiclass                                 1.38
# CICAPT_IIoT_Phase2_Macro_Multiclass                           6.48
# NIDS_NF-CICIDS2018-v3_Multiclass                              5.15
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                   0.28
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                 5.17
# ToN_IoT_Windows_10_Multiclass                                 0.51
# CICEVSE2024_EVSE-A_Micro_Multiclass                           1.82
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...            2.27
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                    1.44
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                    0.24
# CICIoMT2024_WiFi_and_MQTT_Multiclass                          9.04
# NIDS_NF-BoT-IoT-v3_Multiclass                                 4.79
# ToN_IoT_IoT_Modbus_Multiclass                                 0.55
# UNSW_NB15_Multiclass                                          3.13
# CICIoV2024_Decimal_Macro_Multiclass                           0.13
# NIDS_NF-UNSW-NB15_Multiclass                                  4.28
# CICEVSE2024_EVSE-B_Micro_Multiclass                           1.55
# ToN_IoT_IoT_Weather_Multiclass                                7.41
# ToN_IoT_IoT_Thermostat_Multiclass                             0.41
# CICAPT_IIoT_Phase2_Micro_Multiclass                           2.74
# N_BaIoT_Ennio_Doorbell_Multiclass                             0.75
# KDD_Cup_1999_Multiclass                                       2.34
# NIDS_CIC-BoT-IoT_Multiclass                                   4.02
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                            1.00
# CIC_IOT_Dataset2023_Multiclass                               52.26
# NIDS_NF-UNSW-NB15-v2_Multiclass                               2.89
# N_BaIoT_Danmini_Doorbell_Multiclass                           3.02
# BoT_IoT_Macro_Multiclass                                      4.59
# CICIoV2024_Decimal_Micro_Multiclass                           0.30
# IoT_Network_Intrusion_Micro_Multiclass                      282.62
# NIDS_NF-ToN-IoT_Multiclass                                    1.34
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...            2.61
# ToN_IoT_Linux_Process_Multiclass                              2.41
# NIDS_NF-BoT-IoT_Multiclass                                    0.48
# ToN_IoT_IoT_Fridge_Multiclass                                 0.11
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                           1.58
# N_BaIoT_Ecobee_Thermostat_Multiclass                          1.83
# NIDS_NF-UQ-NIDS-v2_Multiclass                                21.64
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                        6.81
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                    10.69
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                  0.95
# CICEVSE2024_EVSE-A_Macro_Multiclass                           0.87
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                    0.26
# IoT_Network_Intrusion_Macro_Multiclass                      216.99
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                          3.18
# NIDS_NF-UNSW-NB15-v3_Multiclass                               3.62
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...            2.38
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                      1.87
# IoT_23_Multiclass                                             2.67
# ToN_IoT_IoT_GPS_Tracker_Multiclass                            0.20
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                      1.52
# CIC_IDS_2017_Multiclass                                       2.70
# NIDS_NF-ToN-IoT-v3_Multiclass                                10.62
# BoT_IoT_Micro_Multiclass                                     10.32
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                         4.12
# ToN_IoT_Windows_7_Multiclass                                  0.42
# NIDS_NF-UQ-NIDS_Multiclass                                    7.83
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...            4.20
# ToN_IoT_Linux_Memory_Multiclass                              58.14
#
#                                                     model_size_delta  \
# filename
# CICEVSE2024_EVSE-B_Macro_Multiclass                  -0.48 (-26.09%)
# NIDS_NF-ToN-IoT-v2_Multiclass                         +0.00 (+0.00%)
# ToN_IoT_Network_Multiclass                            +0.00 (+0.00%)
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...    +0.00 (+0.00%)
# NIDS_NF-BoT-IoT-v2_Multiclass                         +0.00 (+0.00%)
# NIDS_CIC-ToN-IoT_Multiclass                          -0.53 (-36.30%)
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass       +0.00 (+0.00%)
# ToN_IoT_Linux_Disk_Multiclass                        -2.80 (-66.99%)
# CICAPT_IIoT_Phase2_Macro_Multiclass                   +0.00 (+0.00%)
# NIDS_NF-CICIDS2018-v3_Multiclass                      +0.00 (+0.00%)
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass           +0.00 (+0.00%)
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass         +0.00 (+0.00%)
# ToN_IoT_Windows_10_Multiclass                         +0.00 (+0.00%)
# CICEVSE2024_EVSE-A_Micro_Multiclass                   +0.00 (+0.00%)
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...    +0.00 (+0.00%)
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass            +0.00 (+0.00%)
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass            +0.00 (+0.00%)
# CICIoMT2024_WiFi_and_MQTT_Multiclass                  +0.00 (+0.00%)
# NIDS_NF-BoT-IoT-v3_Multiclass                         +0.00 (+0.00%)
# ToN_IoT_IoT_Modbus_Multiclass                        -0.20 (-26.67%)
# UNSW_NB15_Multiclass                                  +0.00 (+0.00%)
# CICIoV2024_Decimal_Macro_Multiclass                   +0.00 (+0.00%)
# NIDS_NF-UNSW-NB15_Multiclass                          +0.00 (+0.00%)
# CICEVSE2024_EVSE-B_Micro_Multiclass                  -0.76 (-32.90%)
# ToN_IoT_IoT_Weather_Multiclass                        +0.00 (+0.00%)
# ToN_IoT_IoT_Thermostat_Multiclass                    -0.29 (-41.43%)
# CICAPT_IIoT_Phase2_Micro_Multiclass                   +0.00 (+0.00%)
# N_BaIoT_Ennio_Doorbell_Multiclass                     +0.00 (+0.00%)
# KDD_Cup_1999_Multiclass                               +0.00 (+0.00%)
# NIDS_CIC-BoT-IoT_Multiclass                         -14.13 (-77.85%)
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                   -1.02 (-50.50%)
# CIC_IOT_Dataset2023_Multiclass                        +0.00 (+0.00%)
# NIDS_NF-UNSW-NB15-v2_Multiclass                       +0.00 (+0.00%)
# N_BaIoT_Danmini_Doorbell_Multiclass                   +0.00 (+0.00%)
# BoT_IoT_Macro_Multiclass                              +0.00 (+0.00%)
# CICIoV2024_Decimal_Micro_Multiclass                   +0.00 (+0.00%)
# IoT_Network_Intrusion_Micro_Multiclass                +0.00 (+0.00%)
# NIDS_NF-ToN-IoT_Multiclass                           -2.04 (-60.36%)
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...    +0.00 (+0.00%)
# ToN_IoT_Linux_Process_Multiclass                     -2.46 (-50.51%)
# NIDS_NF-BoT-IoT_Multiclass                           -0.22 (-31.43%)
# ToN_IoT_IoT_Fridge_Multiclass                        -0.09 (-45.00%)
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                   +0.00 (+0.00%)
# N_BaIoT_Ecobee_Thermostat_Multiclass                  +0.00 (+0.00%)
# NIDS_NF-UQ-NIDS-v2_Multiclass                         +0.00 (+0.00%)
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                +0.00 (+0.00%)
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass             +0.00 (+0.00%)
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass          +0.00 (+0.00%)
# CICEVSE2024_EVSE-A_Macro_Multiclass                  -0.36 (-29.27%)
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass            +0.00 (+0.00%)
# IoT_Network_Intrusion_Macro_Multiclass                +0.00 (+0.00%)
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                  +0.00 (+0.00%)
# NIDS_NF-UNSW-NB15-v3_Multiclass                       +0.00 (+0.00%)
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...    +0.00 (+0.00%)
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass              +0.00 (+0.00%)
# IoT_23_Multiclass                                     +0.00 (+0.00%)
# ToN_IoT_IoT_GPS_Tracker_Multiclass                   -0.35 (-63.64%)
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass              +0.00 (+0.00%)
# CIC_IDS_2017_Multiclass                               +0.00 (+0.00%)
# NIDS_NF-ToN-IoT-v3_Multiclass                         +0.00 (+0.00%)
# BoT_IoT_Micro_Multiclass                              +0.00 (+0.00%)
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                 +0.00 (+0.00%)
# ToN_IoT_Windows_7_Multiclass                          +0.00 (+0.00%)
# NIDS_NF-UQ-NIDS_Multiclass                            +0.00 (+0.00%)
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...    +0.00 (+0.00%)
# ToN_IoT_Linux_Memory_Multiclass                       +0.00 (+0.00%)
#
#                                                     training_time_abs  \
# filename
# CICEVSE2024_EVSE-B_Macro_Multiclass                             3.851
# NIDS_NF-ToN-IoT-v2_Multiclass                                  33.318
# ToN_IoT_Network_Multiclass                                     20.285
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...             10.981
# NIDS_NF-BoT-IoT-v2_Multiclass                                  12.962
# NIDS_CIC-ToN-IoT_Multiclass                                     3.128
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                13.062
# ToN_IoT_Linux_Disk_Multiclass                                   1.187
# CICAPT_IIoT_Phase2_Macro_Multiclass                            92.517
# NIDS_NF-CICIDS2018-v3_Multiclass                             6107.806
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                     1.859
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                  10.947
# ToN_IoT_Windows_10_Multiclass                                   3.633
# CICEVSE2024_EVSE-A_Micro_Multiclass                            10.552
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...             10.081
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                      4.752
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                      1.572
# CICIoMT2024_WiFi_and_MQTT_Multiclass                           23.342
# NIDS_NF-BoT-IoT-v3_Multiclass                                  14.469
# ToN_IoT_IoT_Modbus_Multiclass                                   1.415
# UNSW_NB15_Multiclass                                            7.885
# CICIoV2024_Decimal_Macro_Multiclass                             0.755
# NIDS_NF-UNSW-NB15_Multiclass                                    9.141
# CICEVSE2024_EVSE-B_Micro_Multiclass                             3.846
# ToN_IoT_IoT_Weather_Multiclass                                 12.045
# ToN_IoT_IoT_Thermostat_Multiclass                               0.907
# CICAPT_IIoT_Phase2_Micro_Multiclass                            35.020
# N_BaIoT_Ennio_Doorbell_Multiclass                               2.609
# KDD_Cup_1999_Multiclass                                        15.210
# NIDS_CIC-BoT-IoT_Multiclass                                     3.009
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                              4.004
# CIC_IOT_Dataset2023_Multiclass                                169.606
# NIDS_NF-UNSW-NB15-v2_Multiclass                                12.888
# N_BaIoT_Danmini_Doorbell_Multiclass                            14.194
# BoT_IoT_Macro_Multiclass                                       15.602
# CICIoV2024_Decimal_Micro_Multiclass                             0.814
# IoT_Network_Intrusion_Micro_Multiclass                         24.907
# NIDS_NF-ToN-IoT_Multiclass                                      3.133
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...             11.311
# ToN_IoT_Linux_Process_Multiclass                                1.221
# NIDS_NF-BoT-IoT_Multiclass                                      2.144
# ToN_IoT_IoT_Fridge_Multiclass                                   0.565
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                             7.026
# N_BaIoT_Ecobee_Thermostat_Multiclass                            8.858
# NIDS_NF-UQ-NIDS-v2_Multiclass                                  83.481
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                          8.290
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                      20.965
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                    3.328
# CICEVSE2024_EVSE-A_Macro_Multiclass                             4.374
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                      1.349
# IoT_Network_Intrusion_Macro_Multiclass                         17.221
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                           17.169
# NIDS_NF-UNSW-NB15-v3_Multiclass                                13.812
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...              9.908
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                        6.715
# IoT_23_Multiclass                                              10.503
# ToN_IoT_IoT_GPS_Tracker_Multiclass                              1.175
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                        2.316
# CIC_IDS_2017_Multiclass                                        11.012
# NIDS_NF-ToN-IoT-v3_Multiclass                                  48.575
# BoT_IoT_Micro_Multiclass                                       34.805
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                          22.777
# ToN_IoT_Windows_7_Multiclass                                    2.344
# NIDS_NF-UQ-NIDS_Multiclass                                     23.688
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...              5.439
# ToN_IoT_Linux_Memory_Multiclass                                14.055
#
#                                                      training_time_delta  \
# filename
# CICEVSE2024_EVSE-B_Macro_Multiclass                  -2.049717 (-34.74%)
# NIDS_NF-ToN-IoT-v2_Multiclass                                         --
# ToN_IoT_Network_Multiclass                                            --
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                    --
# NIDS_NF-BoT-IoT-v2_Multiclass                                         --
# NIDS_CIC-ToN-IoT_Multiclass                           +0.009085 (+0.29%)
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                       --
# ToN_IoT_Linux_Disk_Multiclass                        -1.543635 (-56.53%)
# CICAPT_IIoT_Phase2_Macro_Multiclass                                   --
# NIDS_NF-CICIDS2018-v3_Multiclass                                      --
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                           --
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                         --
# ToN_IoT_Windows_10_Multiclass                                         --
# CICEVSE2024_EVSE-A_Micro_Multiclass                                   --
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                    --
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                            --
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                            --
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                  --
# NIDS_NF-BoT-IoT-v3_Multiclass                                         --
# ToN_IoT_IoT_Modbus_Multiclass                        -0.203849 (-12.59%)
# UNSW_NB15_Multiclass                                                  --
# CICIoV2024_Decimal_Macro_Multiclass                                   --
# NIDS_NF-UNSW-NB15_Multiclass                                          --
# CICEVSE2024_EVSE-B_Micro_Multiclass                  -4.674072 (-54.86%)
# ToN_IoT_IoT_Weather_Multiclass                                        --
# ToN_IoT_IoT_Thermostat_Multiclass                    -0.258822 (-22.20%)
# CICAPT_IIoT_Phase2_Micro_Multiclass                                   --
# N_BaIoT_Ennio_Doorbell_Multiclass                                     --
# KDD_Cup_1999_Multiclass                                               --
# NIDS_CIC-BoT-IoT_Multiclass                         -12.769216 (-80.93%)
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                   -2.559552 (-38.99%)
# CIC_IOT_Dataset2023_Multiclass                                        --
# NIDS_NF-UNSW-NB15-v2_Multiclass                                       --
# N_BaIoT_Danmini_Doorbell_Multiclass                                   --
# BoT_IoT_Macro_Multiclass                                              --
# CICIoV2024_Decimal_Micro_Multiclass                                   --
# IoT_Network_Intrusion_Micro_Multiclass                                --
# NIDS_NF-ToN-IoT_Multiclass                           -6.756249 (-68.32%)
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                    --
# ToN_IoT_Linux_Process_Multiclass                     -1.099207 (-47.37%)
# NIDS_NF-BoT-IoT_Multiclass                           +0.353084 (+19.71%)
# ToN_IoT_IoT_Fridge_Multiclass                         -0.034159 (-5.70%)
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                   --
# N_BaIoT_Ecobee_Thermostat_Multiclass                                  --
# NIDS_NF-UQ-NIDS-v2_Multiclass                                         --
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                --
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                             --
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                          --
# CICEVSE2024_EVSE-A_Macro_Multiclass                  -1.145281 (-20.75%)
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                            --
# IoT_Network_Intrusion_Macro_Multiclass                                --
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                  --
# NIDS_NF-UNSW-NB15-v3_Multiclass                                       --
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                    --
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                              --
# IoT_23_Multiclass                                                     --
# ToN_IoT_IoT_GPS_Tracker_Multiclass                    -0.043376 (-3.56%)
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                              --
# CIC_IDS_2017_Multiclass                                               --
# NIDS_NF-ToN-IoT-v3_Multiclass                                         --
# BoT_IoT_Micro_Multiclass                                              --
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                 --
# ToN_IoT_Windows_7_Multiclass                                          --
# NIDS_NF-UQ-NIDS_Multiclass                                            --
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                    --
# ToN_IoT_Linux_Memory_Multiclass                                       --
#
#                                                      latency_abs  \
# filename
# CICEVSE2024_EVSE-B_Macro_Multiclass                 3.865710e-07
# NIDS_NF-ToN-IoT-v2_Multiclass                       4.431470e-07
# ToN_IoT_Network_Multiclass                          6.354210e-07
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...  5.893960e-07
# NIDS_NF-BoT-IoT-v2_Multiclass                       2.923850e-06
# NIDS_CIC-ToN-IoT_Multiclass                         3.329400e-07
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass     4.514050e-07
# ToN_IoT_Linux_Disk_Multiclass                       1.860366e-06
# CICAPT_IIoT_Phase2_Macro_Multiclass                 6.500510e-07
# NIDS_NF-CICIDS2018-v3_Multiclass                    8.263530e-07
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass         5.066020e-07
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass       1.542230e-07
# ToN_IoT_Windows_10_Multiclass                       3.196678e-06
# CICEVSE2024_EVSE-A_Micro_Multiclass                 6.923620e-07
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...  3.893420e-07
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass          8.229520e-07
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass          8.569820e-07
# CICIoMT2024_WiFi_and_MQTT_Multiclass                5.163470e-07
# NIDS_NF-BoT-IoT-v3_Multiclass                       8.000060e-07
# ToN_IoT_IoT_Modbus_Multiclass                       7.476270e-07
# UNSW_NB15_Multiclass                                1.458650e-07
# CICIoV2024_Decimal_Macro_Multiclass                 7.546365e-06
# NIDS_NF-UNSW-NB15_Multiclass                        3.735000e-07
# CICEVSE2024_EVSE-B_Micro_Multiclass                 8.694890e-07
# ToN_IoT_IoT_Weather_Multiclass                      5.146290e-07
# ToN_IoT_IoT_Thermostat_Multiclass                   8.690110e-07
# CICAPT_IIoT_Phase2_Micro_Multiclass                 2.153390e-07
# N_BaIoT_Ennio_Doorbell_Multiclass                   4.152820e-07
# KDD_Cup_1999_Multiclass                             5.560210e-07
# NIDS_CIC-BoT-IoT_Multiclass                         1.046670e-07
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                  5.256190e-07
# CIC_IOT_Dataset2023_Multiclass                      1.402096e-06
# NIDS_NF-UNSW-NB15-v2_Multiclass                     8.402460e-07
# N_BaIoT_Danmini_Doorbell_Multiclass                 7.503080e-07
# BoT_IoT_Macro_Multiclass                            2.310280e-07
# CICIoV2024_Decimal_Micro_Multiclass                 1.290819e-05
# IoT_Network_Intrusion_Micro_Multiclass              2.333477e-06
# NIDS_NF-ToN-IoT_Multiclass                          2.865190e-07
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...  4.070550e-07
# ToN_IoT_Linux_Process_Multiclass                    3.034465e-06
# NIDS_NF-BoT-IoT_Multiclass                          3.869290e-07
# ToN_IoT_IoT_Fridge_Multiclass                       2.046106e-05
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                 8.212060e-07
# N_BaIoT_Ecobee_Thermostat_Multiclass                3.473700e-07
# NIDS_NF-UQ-NIDS-v2_Multiclass                       6.810880e-07
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass              6.121670e-07
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass           2.674412e-06
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass        3.539180e-07
# CICEVSE2024_EVSE-A_Macro_Multiclass                 8.606670e-07
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass          1.610764e-05
# IoT_Network_Intrusion_Macro_Multiclass              4.683520e-07
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                3.536770e-07
# NIDS_NF-UNSW-NB15-v3_Multiclass                     5.314030e-07
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...  4.343620e-07
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass            1.994190e-07
# IoT_23_Multiclass                                   1.020621e-06
# ToN_IoT_IoT_GPS_Tracker_Multiclass                  4.905791e-05
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass            1.797950e-07
# CIC_IDS_2017_Multiclass                             3.059430e-07
# NIDS_NF-ToN-IoT-v3_Multiclass                       3.451000e-07
# BoT_IoT_Micro_Multiclass                            4.102270e-07
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass               3.186930e-07
# ToN_IoT_Windows_7_Multiclass                        1.856135e-06
# NIDS_NF-UQ-NIDS_Multiclass                          6.573810e-07
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...  4.599200e-07
# ToN_IoT_Linux_Memory_Multiclass                     2.721523e-06
#
#                                                           latency_delta  \
# filename
# CICEVSE2024_EVSE-B_Macro_Multiclass                 -6.18e-07 (-61.51%)
# NIDS_NF-ToN-IoT-v2_Multiclass                                        --
# ToN_IoT_Network_Multiclass                                           --
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                   --
# NIDS_NF-BoT-IoT-v2_Multiclass                                        --
# NIDS_CIC-ToN-IoT_Multiclass                         -2.21e-07 (-39.86%)
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                      --
# ToN_IoT_Linux_Disk_Multiclass                        -2.00e-08 (-1.07%)
# CICAPT_IIoT_Phase2_Macro_Multiclass                                  --
# NIDS_NF-CICIDS2018-v3_Multiclass                                     --
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                          --
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                        --
# ToN_IoT_Windows_10_Multiclass                                        --
# CICEVSE2024_EVSE-A_Micro_Multiclass                                  --
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                   --
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                           --
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                           --
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                 --
# NIDS_NF-BoT-IoT-v3_Multiclass                                        --
# ToN_IoT_IoT_Modbus_Multiclass                       +2.93e-07 (+64.58%)
# UNSW_NB15_Multiclass                                                 --
# CICIoV2024_Decimal_Macro_Multiclass                                  --
# NIDS_NF-UNSW-NB15_Multiclass                                         --
# CICEVSE2024_EVSE-B_Micro_Multiclass                 -5.22e-07 (-37.51%)
# ToN_IoT_IoT_Weather_Multiclass                                       --
# ToN_IoT_IoT_Thermostat_Multiclass                   -2.59e-07 (-22.97%)
# CICAPT_IIoT_Phase2_Micro_Multiclass                                  --
# N_BaIoT_Ennio_Doorbell_Multiclass                                    --
# KDD_Cup_1999_Multiclass                                              --
# NIDS_CIC-BoT-IoT_Multiclass                         -1.64e-08 (-13.55%)
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                  +1.46e-07 (+38.44%)
# CIC_IOT_Dataset2023_Multiclass                                       --
# NIDS_NF-UNSW-NB15-v2_Multiclass                                      --
# N_BaIoT_Danmini_Doorbell_Multiclass                                  --
# BoT_IoT_Macro_Multiclass                                             --
# CICIoV2024_Decimal_Micro_Multiclass                                  --
# IoT_Network_Intrusion_Micro_Multiclass                               --
# NIDS_NF-ToN-IoT_Multiclass                           -2.98e-08 (-9.43%)
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                   --
# ToN_IoT_Linux_Process_Multiclass                     +5.53e-09 (+0.18%)
# NIDS_NF-BoT-IoT_Multiclass                           +1.92e-08 (+5.23%)
# ToN_IoT_IoT_Fridge_Multiclass                        -2.55e-07 (-1.23%)
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                  --
# N_BaIoT_Ecobee_Thermostat_Multiclass                                 --
# NIDS_NF-UQ-NIDS-v2_Multiclass                                        --
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                               --
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                            --
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                         --
# CICEVSE2024_EVSE-A_Macro_Multiclass                 +4.13e-07 (+92.39%)
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                           --
# IoT_Network_Intrusion_Macro_Multiclass                               --
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                 --
# NIDS_NF-UNSW-NB15-v3_Multiclass                                      --
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                   --
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                             --
# IoT_23_Multiclass                                                    --
# ToN_IoT_IoT_GPS_Tracker_Multiclass                   +1.91e-06 (+4.05%)
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                             --
# CIC_IDS_2017_Multiclass                                              --
# NIDS_NF-ToN-IoT-v3_Multiclass                                        --
# BoT_IoT_Micro_Multiclass                                             --
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                --
# ...
# CICAPT_IIoT_Phase2_Macro_Multiclass                            --
# NIDS_NF-CICIDS2018-v3_Multiclass                               --
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                    --
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                  --
# ToN_IoT_Windows_10_Multiclass                                  --
# CICEVSE2024_EVSE-A_Micro_Multiclass                            --
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...             --
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                     --
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                     --
# CICIoMT2024_WiFi_and_MQTT_Multiclass                           --
# NIDS_NF-BoT-IoT-v3_Multiclass                                  --
# ToN_IoT_IoT_Modbus_Multiclass                       100/100 (100)
# UNSW_NB15_Multiclass                                           --
# CICIoV2024_Decimal_Macro_Multiclass                            --
# NIDS_NF-UNSW-NB15_Multiclass                                   --
# CICEVSE2024_EVSE-B_Micro_Multiclass                            --
# ToN_IoT_IoT_Weather_Multiclass                                 --
# ToN_IoT_IoT_Thermostat_Multiclass                              --
# CICAPT_IIoT_Phase2_Micro_Multiclass                            --
# N_BaIoT_Ennio_Doorbell_Multiclass                              --
# KDD_Cup_1999_Multiclass                                        --
# NIDS_CIC-BoT-IoT_Multiclass                                    --
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                             --
# CIC_IOT_Dataset2023_Multiclass                                 --
# NIDS_NF-UNSW-NB15-v2_Multiclass                                --
# N_BaIoT_Danmini_Doorbell_Multiclass                            --
# BoT_IoT_Macro_Multiclass                                       --
# CICIoV2024_Decimal_Micro_Multiclass                            --
# IoT_Network_Intrusion_Micro_Multiclass                         --
# NIDS_NF-ToN-IoT_Multiclass                                     --
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...             --
# ToN_IoT_Linux_Process_Multiclass                               --
# NIDS_NF-BoT-IoT_Multiclass                                     --
# ToN_IoT_IoT_Fridge_Multiclass                                  --
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                            --
# N_BaIoT_Ecobee_Thermostat_Multiclass                           --
# NIDS_NF-UQ-NIDS-v2_Multiclass                                  --
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                         --
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                      --
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                   --
# CICEVSE2024_EVSE-A_Macro_Multiclass                            --
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                     --
# IoT_Network_Intrusion_Macro_Multiclass                         --
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                           --
# NIDS_NF-UNSW-NB15-v3_Multiclass                                --
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...             --
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                       --
# IoT_23_Multiclass                                              --
# ToN_IoT_IoT_GPS_Tracker_Multiclass                             --
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                       --
# CIC_IDS_2017_Multiclass                                        --
# NIDS_NF-ToN-IoT-v3_Multiclass                                  --
# BoT_IoT_Micro_Multiclass                                       --
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                          --
# ToN_IoT_Windows_7_Multiclass                                   --
# NIDS_NF-UQ-NIDS_Multiclass                                     --
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...             --
# ToN_IoT_Linux_Memory_Multiclass                                --
#
#                                                                                            hpo_params  \
# filename
# CICEVSE2024_EVSE-B_Macro_Multiclass                                                                --
# NIDS_NF-ToN-IoT-v2_Multiclass                                                                      --
# ToN_IoT_Network_Multiclass                                                                         --
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                                                 --
# NIDS_NF-BoT-IoT-v2_Multiclass                                                                      --
# NIDS_CIC-ToN-IoT_Multiclass                                                                        --
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                                                    --
# ToN_IoT_Linux_Disk_Multiclass                                                                      --
# CICAPT_IIoT_Phase2_Macro_Multiclass                                                                --
# NIDS_NF-CICIDS2018-v3_Multiclass                                                                   --
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                                                        --
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                                                      --
# ToN_IoT_Windows_10_Multiclass                                                                      --
# CICEVSE2024_EVSE-A_Micro_Multiclass                                                                --
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                                                 --
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                                                         --
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                                                         --
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                                               --
# NIDS_NF-BoT-IoT-v3_Multiclass                                                                      --
# ToN_IoT_IoT_Modbus_Multiclass                       {'balancing_mode': 'none', 'eta': 0.113, 'max_...
# UNSW_NB15_Multiclass                                                                               --
# CICIoV2024_Decimal_Macro_Multiclass                                                                --
# NIDS_NF-UNSW-NB15_Multiclass                                                                       --
# CICEVSE2024_EVSE-B_Micro_Multiclass                                                                --
# ToN_IoT_IoT_Weather_Multiclass                                                                     --
# ToN_IoT_IoT_Thermostat_Multiclass                                                                  --
# CICAPT_IIoT_Phase2_Micro_Multiclass                                                                --
# N_BaIoT_Ennio_Doorbell_Multiclass                                                                  --
# KDD_Cup_1999_Multiclass                                                                            --
# NIDS_CIC-BoT-IoT_Multiclass                                                                        --
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                                                 --
# CIC_IOT_Dataset2023_Multiclass                                                                     --
# NIDS_NF-UNSW-NB15-v2_Multiclass                                                                    --
# N_BaIoT_Danmini_Doorbell_Multiclass                                                                --
# BoT_IoT_Macro_Multiclass                                                                           --
# CICIoV2024_Decimal_Micro_Multiclass                                                                --
# IoT_Network_Intrusion_Micro_Multiclass                                                             --
# NIDS_NF-ToN-IoT_Multiclass                                                                         --
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                                                 --
# ToN_IoT_Linux_Process_Multiclass                                                                   --
# NIDS_NF-BoT-IoT_Multiclass                                                                         --
# ToN_IoT_IoT_Fridge_Multiclass                                                                      --
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                                                --
# N_BaIoT_Ecobee_Thermostat_Multiclass                                                               --
# NIDS_NF-UQ-NIDS-v2_Multiclass                                                                      --
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                                             --
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                                                          --
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                                                       --
# CICEVSE2024_EVSE-A_Macro_Multiclass                                                                --
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                                                         --
# IoT_Network_Intrusion_Macro_Multiclass                                                             --
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                                               --
# NIDS_NF-UNSW-NB15-v3_Multiclass                                                                    --
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                                                 --
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                                                           --
# IoT_23_Multiclass                                                                                  --
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                                                 --
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                                                           --
# CIC_IDS_2017_Multiclass                                                                            --
# NIDS_NF-ToN-IoT-v3_Multiclass                                                                      --
# BoT_IoT_Micro_Multiclass                                                                           --
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                                              --
# ToN_IoT_Windows_7_Multiclass                                                                       --
# NIDS_NF-UQ-NIDS_Multiclass                                                                         --
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                                                 --
# ToN_IoT_Linux_Memory_Multiclass                                                                    --
#
#                                                          best_config
# filename
# CICEVSE2024_EVSE-B_Macro_Multiclass                          sampled
# NIDS_NF-ToN-IoT-v2_Multiclass                                   full
# ToN_IoT_Network_Multiclass                                      full
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...              full
# NIDS_NF-BoT-IoT-v2_Multiclass                                   full
# NIDS_CIC-ToN-IoT_Multiclass                                  reduced
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                 full
# ToN_IoT_Linux_Disk_Multiclass                                sampled
# CICAPT_IIoT_Phase2_Macro_Multiclass                             full
# NIDS_NF-CICIDS2018-v3_Multiclass                                full
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                     full
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                   full
# ToN_IoT_Windows_10_Multiclass                                   full
# CICEVSE2024_EVSE-A_Micro_Multiclass                             full
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...              full
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                      full
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                      full
# CICIoMT2024_WiFi_and_MQTT_Multiclass                            full
# NIDS_NF-BoT-IoT-v3_Multiclass                                   full
# ToN_IoT_IoT_Modbus_Multiclass                       hpo_best_latency
# UNSW_NB15_Multiclass                                            full
# CICIoV2024_Decimal_Macro_Multiclass                             full
# NIDS_NF-UNSW-NB15_Multiclass                                    full
# CICEVSE2024_EVSE-B_Micro_Multiclass                          sampled
# ToN_IoT_IoT_Weather_Multiclass                                  full
# ToN_IoT_IoT_Thermostat_Multiclass                            sampled
# CICAPT_IIoT_Phase2_Micro_Multiclass                             full
# N_BaIoT_Ennio_Doorbell_Multiclass                               full
# KDD_Cup_1999_Multiclass                                         full
# NIDS_CIC-BoT-IoT_Multiclass                                  sampled
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                           sampled
# CIC_IOT_Dataset2023_Multiclass                                  full
# NIDS_NF-UNSW-NB15-v2_Multiclass                                 full
# N_BaIoT_Danmini_Doorbell_Multiclass                             full
# BoT_IoT_Macro_Multiclass                                        full
# CICIoV2024_Decimal_Micro_Multiclass                             full
# IoT_Network_Intrusion_Micro_Multiclass                          full
# NIDS_NF-ToN-IoT_Multiclass                                   sampled
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...              full
# ToN_IoT_Linux_Process_Multiclass                             reduced
# NIDS_NF-BoT-IoT_Multiclass                                   sampled
# ToN_IoT_IoT_Fridge_Multiclass                                sampled
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                             full
# N_BaIoT_Ecobee_Thermostat_Multiclass                            full
# NIDS_NF-UQ-NIDS-v2_Multiclass                                   full
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                          full
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                       full
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                    full
# CICEVSE2024_EVSE-A_Macro_Multiclass                          sampled
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                      full
# IoT_Network_Intrusion_Macro_Multiclass                          full
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                            full
# NIDS_NF-UNSW-NB15-v3_Multiclass                                 full
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...              full
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                        full
# IoT_23_Multiclass                                               full
# ToN_IoT_IoT_GPS_Tracker_Multiclass                           sampled
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                        full
# CIC_IDS_2017_Multiclass                                         full
# NIDS_NF-ToN-IoT-v3_Multiclass                                   full
# BoT_IoT_Micro_Multiclass                                        full
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                           full
# ToN_IoT_Windows_7_Multiclass                                    full
# NIDS_NF-UQ-NIDS_Multiclass                                      full
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...              full
# ToN_IoT_Linux_Memory_Multiclass                                 full

# %%
summary_df = input_df.data.join(output_df, how='left')

summary_df
# Out:
#                                                        size_mb   samples  \
# filename
# CIC_IDS_2017_Multiclass                              48.120055   1250066
# CIC_IOT_Dataset2023_Multiclass                      103.467662   4487800
# IoT_23_Multiclass                                     1.983605    363889
# IoT_Network_Intrusion_Macro_Multiclass                0.388587     78938
# IoT_Network_Intrusion_Micro_Multiclass                0.388876     78963
# KDD_Cup_1999_Multiclass                               6.023224   1074992
# UNSW_NB15_Multiclass                                 46.291736   1944769
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass            12.335672    292898
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass       22.411199   1175500
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass               10.502277    258558
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                 6.598314     91787
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...    4.680937    178424
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass            3.740628     89209
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass        65.460896   1966383
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass             26.159936    711664
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass              4.585804    331398
# BoT_IoT_Macro_Multiclass                             17.777126   1704066
# BoT_IoT_Micro_Multiclass                             17.797062   1705588
# CICAPT_IIoT_Phase1_Macro_Multiclass                 101.821614  10260159
# CICAPT_IIoT_Phase1_Micro_Multiclass                 101.821614  10260159
# CICAPT_IIoT_Phase2_Macro_Multiclass                  84.906780   8209431
# CICAPT_IIoT_Phase2_Micro_Multiclass                  84.903109   8209431
# CICEVSE2024_EVSE-A_Macro_Multiclass                   4.610124    366517
# CICEVSE2024_EVSE-A_Micro_Multiclass                   4.610253    366517
# CICEVSE2024_EVSE-B_Macro_Multiclass                   4.410861    286645
# CICEVSE2024_EVSE-B_Micro_Multiclass                   4.413218    286675
# CICIoMT2024_Bluetooth_Multiclass                      0.008513       747
# CICIoMT2024_WiFi_and_MQTT_Multiclass                 30.757688   1924242
# CICIoV2024_Decimal_Macro_Multiclass                   0.024112      3577
# CICIoV2024_Decimal_Micro_Multiclass                   0.024212      3579
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                  8.417033   1606411
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                   1.589944    151908
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass            1.109440     39418
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass            0.020308      1744
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass           1.051911     63600
# NIDS_CIC-BoT-IoT_Multiclass                          61.999312   1502919
# NIDS_CIC-ToN-IoT_Multiclass                           4.263942    169545
# NIDS_NF-BoT-IoT_Multiclass                            0.417006     94169
# NIDS_NF-BoT-IoT-v2_Multiclass                         3.597679    143087
# NIDS_NF-BoT-IoT-v3_Multiclass                        13.185802    682102
# NIDS_NF-CICIDS2018-v3_Multiclass                    285.462099   8184198
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                    2.454939    391022
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                53.016284   1804117
# NIDS_NF-ToN-IoT_Multiclass                            4.489354    672305
# NIDS_NF-ToN-IoT-v2_Multiclass                        22.917208   1165794
# NIDS_NF-ToN-IoT-v3_Multiclass                       107.593317   4213539
# NIDS_NF-UNSW-NB15_Multiclass                          4.414413    426380
# NIDS_NF-UNSW-NB15-v2_Multiclass                       5.349347    145077
# NIDS_NF-UNSW-NB15-v3_Multiclass                      44.653432   1176457
# NIDS_NF-UQ-NIDS_Multiclass                            3.747316    592809
# NIDS_NF-UQ-NIDS-v2_Multiclass                        99.582510   3204691
# N_BaIoT_Danmini_Doorbell_Multiclass                  15.857973    704874
# N_BaIoT_Ecobee_Thermostat_Multiclass                 14.239863    540971
# N_BaIoT_Ennio_Doorbell_Multiclass                     8.824686    146043
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass      30.525715    786204
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...   16.217406    447068
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...   21.432671    473360
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass         13.794062    164375
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...   12.884947    510556
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...   12.543195    548938
# ToN_IoT_IoT_Fridge_Multiclass                         0.004266      1057
# ToN_IoT_IoT_GPS_Tracker_Multiclass                    0.004370       639
# ToN_IoT_IoT_Garage_Door_Multiclass                    0.002548        18
# ToN_IoT_IoT_Modbus_Multiclass                         1.686697    112839
# ToN_IoT_IoT_Motion_Light_Multiclass                   0.002620        16
# ToN_IoT_IoT_Thermostat_Multiclass                     0.114014     40651
# ToN_IoT_IoT_Weather_Multiclass                        3.038954    571535
# ToN_IoT_Linux_Disk_Multiclass                         0.101537     24158
# ToN_IoT_Linux_Memory_Multiclass                       0.766092     82722
# ToN_IoT_Linux_Process_Multiclass                      0.106198     20919
# ToN_IoT_Network_Multiclass                            5.614008    470405
# ToN_IoT_Windows_10_Multiclass                        10.298632     35214
# ToN_IoT_Windows_7_Multiclass                          6.385379     28097
#
#                                                     features  classes  \
# filename
# CIC_IDS_2017_Multiclass                                   70       15
# CIC_IOT_Dataset2023_Multiclass                            39       35
# IoT_23_Multiclass                                         12       16
# IoT_Network_Intrusion_Macro_Multiclass                    24        5
# IoT_Network_Intrusion_Micro_Multiclass                    24       11
# KDD_Cup_1999_Multiclass                                   40       23
# UNSW_NB15_Multiclass                                      45       11
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                 73       12
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass            69       12
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                    73       15
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                     72        2
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...        71        5
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                73        9
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass             69        5
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                  71        4
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                  69        5
# BoT_IoT_Macro_Multiclass                                  20        5
# BoT_IoT_Micro_Multiclass                                  20       11
# CICAPT_IIoT_Phase1_Macro_Multiclass                       48        1
# CICAPT_IIoT_Phase1_Micro_Multiclass                       48        1
# CICAPT_IIoT_Phase2_Macro_Multiclass                       48       26
# CICAPT_IIoT_Phase2_Micro_Multiclass                       48        9
# CICEVSE2024_EVSE-A_Macro_Multiclass                       68       16
# CICEVSE2024_EVSE-A_Micro_Multiclass                       68       28
# CICEVSE2024_EVSE-B_Macro_Multiclass                       68       21
# CICEVSE2024_EVSE-B_Micro_Multiclass                       68       31
# CICIoMT2024_Bluetooth_Multiclass                           7        2
# CICIoMT2024_WiFi_and_MQTT_Multiclass                      44       19
# CICIoV2024_Decimal_Macro_Multiclass                        8        3
# CICIoV2024_Decimal_Micro_Multiclass                        8        6
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                      45       15
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                       41       15
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                28        5
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                17        5
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass               16        5
# NIDS_CIC-BoT-IoT_Multiclass                               79        5
# NIDS_CIC-ToN-IoT_Multiclass                               71       10
# NIDS_NF-BoT-IoT_Multiclass                                10        5
# NIDS_NF-BoT-IoT-v2_Multiclass                             38        5
# NIDS_NF-BoT-IoT-v3_Multiclass                             46        5
# NIDS_NF-CICIDS2018-v3_Multiclass                          45       15
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                        10       15
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                     37       15
# NIDS_NF-ToN-IoT_Multiclass                                10       10
# NIDS_NF-ToN-IoT-v2_Multiclass                             38       10
# NIDS_NF-ToN-IoT-v3_Multiclass                             46       10
# NIDS_NF-UNSW-NB15_Multiclass                              10       10
# NIDS_NF-UNSW-NB15-v2_Multiclass                           38       10
# NIDS_NF-UNSW-NB15-v3_Multiclass                           46       10
# NIDS_NF-UQ-NIDS_Multiclass                                10       21
# NIDS_NF-UQ-NIDS-v2_Multiclass                             38       21
# N_BaIoT_Danmini_Doorbell_Multiclass                      115       11
# N_BaIoT_Ecobee_Thermostat_Multiclass                     115       11
# N_BaIoT_Ennio_Doorbell_Multiclass                        115        6
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass          115       11
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...       115       11
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...       115       11
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass             115        6
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...       115       11
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...       115       11
# ToN_IoT_IoT_Fridge_Multiclass                              2        7
# ToN_IoT_IoT_GPS_Tracker_Multiclass                         2        8
# ToN_IoT_IoT_Garage_Door_Multiclass                         2        8
# ToN_IoT_IoT_Modbus_Multiclass                              4        6
# ToN_IoT_IoT_Motion_Light_Multiclass                        2        8
# ToN_IoT_IoT_Thermostat_Multiclass                          2        7
# ToN_IoT_IoT_Weather_Multiclass                             3        8
# ToN_IoT_Linux_Disk_Multiclass                              5        8
# ToN_IoT_Linux_Memory_Multiclass                            9        6
# ToN_IoT_Linux_Process_Multiclass                          12        8
# ToN_IoT_Network_Multiclass                                40       10
# ToN_IoT_Windows_10_Multiclass                            113        8
# ToN_IoT_Windows_7_Multiclass                             104        8
#
#                                                                                         dtypes  \
# filename
# CIC_IDS_2017_Multiclass                                               {int32, int64, category}
# CIC_IOT_Dataset2023_Multiclass                      {int64, category, float32, int32, float64}
# IoT_23_Multiclass                                                   {float32, int32, category}
# IoT_Network_Intrusion_Macro_Multiclass                              {int32, float64, category}
# IoT_Network_Intrusion_Micro_Multiclass                              {int32, float64, category}
# KDD_Cup_1999_Multiclass                                      {int32, int64, float32, category}
# UNSW_NB15_Multiclass                                {int64, category, float32, int32, float64}
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass           {int64, category, float32, int32, float64}
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass      {int64, category, float32, int32, float64}
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                       {int32, int64, float32, category}
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                        {int32, int64, float32, category}
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...  {int64, category, float32, int32, float64}
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass          {int64, category, float32, int32, float64}
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass       {int64, category, float32, int32, float64}
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass            {int64, category, float32, int32, float64}
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass            {int64, category, float32, int32, float64}
# BoT_IoT_Macro_Multiclass                                            {int32, float32, category}
# BoT_IoT_Micro_Multiclass                                            {int32, float32, category}
# CICAPT_IIoT_Phase1_Macro_Multiclass                 {int64, category, float32, int32, float64}
# CICAPT_IIoT_Phase1_Micro_Multiclass                 {int64, category, float32, int32, float64}
# CICAPT_IIoT_Phase2_Macro_Multiclass                 {int64, category, float32, int32, float64}
# CICAPT_IIoT_Phase2_Micro_Multiclass                 {int64, category, float32, int32, float64}
# CICEVSE2024_EVSE-A_Macro_Multiclass                          {int32, int64, float32, category}
# CICEVSE2024_EVSE-A_Micro_Multiclass                          {int32, int64, float32, category}
# CICEVSE2024_EVSE-B_Macro_Multiclass                 {int64, category, float32, int32, float64}
# CICEVSE2024_EVSE-B_Micro_Multiclass                 {int64, category, float32, int32, float64}
# CICIoMT2024_Bluetooth_Multiclass                                     {int32, float64, float32}
# CICIoMT2024_WiFi_and_MQTT_Multiclass                              {float32, float64, category}
# CICIoV2024_Decimal_Macro_Multiclass                                                    {int32}
# CICIoV2024_Decimal_Micro_Multiclass                                                    {int32}
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                       {int32, float64, float32, category}
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                        {int32, float64, float32, category}
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                   {int32, int64, float32, category}
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                          {int32, float64, category}
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                  {int32, int64, float32, category}
# NIDS_CIC-BoT-IoT_Multiclass                                       {float32, float64, category}
# NIDS_CIC-ToN-IoT_Multiclass                                  {int32, int64, float32, category}
# NIDS_NF-BoT-IoT_Multiclass                                   {float32, int64, int32, category}
# NIDS_NF-BoT-IoT-v2_Multiclass                                         {int32, int64, category}
# NIDS_NF-BoT-IoT-v3_Multiclass                                {float32, int64, int32, category}
# NIDS_NF-CICIDS2018-v3_Multiclass                                      {int32, int64, category}
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                           {float32, int64, int32, category}
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                        {float32, int64, int32, category}
# NIDS_NF-ToN-IoT_Multiclass                                   {float32, int64, int32, category}
# NIDS_NF-ToN-IoT-v2_Multiclass                                {float32, int64, int32, category}
# NIDS_NF-ToN-IoT-v3_Multiclass                                         {int32, int64, category}
# NIDS_NF-UNSW-NB15_Multiclass                                        {int32, float32, category}
# NIDS_NF-UNSW-NB15-v2_Multiclass                              {int32, int64, float32, category}
# NIDS_NF-UNSW-NB15-v3_Multiclass                              {int32, int64, float32, category}
# NIDS_NF-UQ-NIDS_Multiclass                                          {int32, float32, category}
# NIDS_NF-UQ-NIDS-v2_Multiclass                       {int64, category, float32, int32, float64}
# N_BaIoT_Danmini_Doorbell_Multiclass                                        {float32, category}
# N_BaIoT_Ecobee_Thermostat_Multiclass                                       {float32, category}
# N_BaIoT_Ennio_Doorbell_Multiclass                                          {float32, category}
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                            {float32, category}
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                         {float32, category}
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                         {float32, category}
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                               {float32, category}
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                         {float32, category}
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                         {float32, category}
# ToN_IoT_IoT_Fridge_Multiclass                                              {float32, category}
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                                  {category}
# ToN_IoT_IoT_Garage_Door_Multiclass                                                  {category}
# ToN_IoT_IoT_Modbus_Multiclass                                                          {int32}
# ToN_IoT_IoT_Motion_Light_Multiclass                                          {int64, category}
# ToN_IoT_IoT_Thermostat_Multiclass                                             {float32, int64}
# ToN_IoT_IoT_Weather_Multiclass                                                       {float32}
# ToN_IoT_Linux_Disk_Multiclass                                     {float32, float64, category}
# ToN_IoT_Linux_Memory_Multiclass                                     {int32, float32, category}
# ToN_IoT_Linux_Process_Multiclass                             {int32, int64, float32, category}
# ToN_IoT_Network_Multiclass                                        {float32, float64, category}
# ToN_IoT_Windows_10_Multiclass                                {int32, int64, float32, category}
# ToN_IoT_Windows_7_Multiclass                                 {int32, int64, float32, category}
#
#                                                    feature_types  \
# filename
# CIC_IDS_2017_Multiclass                                    mixed
# CIC_IOT_Dataset2023_Multiclass                             mixed
# IoT_23_Multiclass                                          mixed
# IoT_Network_Intrusion_Macro_Multiclass                     mixed
# IoT_Network_Intrusion_Micro_Multiclass                     mixed
# KDD_Cup_1999_Multiclass                                    mixed
# UNSW_NB15_Multiclass                                       mixed
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                  mixed
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass             mixed
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                     mixed
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                      mixed
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...         mixed
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                 mixed
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass              mixed
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                   mixed
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                   mixed
# BoT_IoT_Macro_Multiclass                                   mixed
# BoT_IoT_Micro_Multiclass                                   mixed
# CICAPT_IIoT_Phase1_Macro_Multiclass                        mixed
# CICAPT_IIoT_Phase1_Micro_Multiclass                        mixed
# CICAPT_IIoT_Phase2_Macro_Multiclass                        mixed
# CICAPT_IIoT_Phase2_Micro_Multiclass                        mixed
# CICEVSE2024_EVSE-A_Macro_Multiclass                        mixed
# CICEVSE2024_EVSE-A_Micro_Multiclass                        mixed
# CICEVSE2024_EVSE-B_Macro_Multiclass                        mixed
# CICEVSE2024_EVSE-B_Micro_Multiclass                        mixed
# CICIoMT2024_Bluetooth_Multiclass                       numerical
# CICIoMT2024_WiFi_and_MQTT_Multiclass                       mixed
# CICIoV2024_Decimal_Macro_Multiclass                    numerical
# CICIoV2024_Decimal_Micro_Multiclass                    numerical
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                       mixed
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                        mixed
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                 mixed
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                 mixed
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                mixed
# NIDS_CIC-BoT-IoT_Multiclass                                mixed
# NIDS_CIC-ToN-IoT_Multiclass                                mixed
# NIDS_NF-BoT-IoT_Multiclass                                 mixed
# NIDS_NF-BoT-IoT-v2_Multiclass                              mixed
# NIDS_NF-BoT-IoT-v3_Multiclass                              mixed
# NIDS_NF-CICIDS2018-v3_Multiclass                           mixed
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                         mixed
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                      mixed
# NIDS_NF-ToN-IoT_Multiclass                                 mixed
# NIDS_NF-ToN-IoT-v2_Multiclass                              mixed
# NIDS_NF-ToN-IoT-v3_Multiclass                              mixed
# NIDS_NF-UNSW-NB15_Multiclass                               mixed
# NIDS_NF-UNSW-NB15-v2_Multiclass                            mixed
# NIDS_NF-UNSW-NB15-v3_Multiclass                            mixed
# NIDS_NF-UQ-NIDS_Multiclass                                 mixed
# NIDS_NF-UQ-NIDS-v2_Multiclass                              mixed
# N_BaIoT_Danmini_Doorbell_Multiclass                        mixed
# N_BaIoT_Ecobee_Thermostat_Multiclass                       mixed
# N_BaIoT_Ennio_Doorbell_Multiclass                          mixed
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass            mixed
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...         mixed
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...         mixed
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass               mixed
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...         mixed
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...         mixed
# ToN_IoT_IoT_Fridge_Multiclass                              mixed
# ToN_IoT_IoT_GPS_Tracker_Multiclass                   categorical
# ToN_IoT_IoT_Garage_Door_Multiclass                   categorical
# ToN_IoT_IoT_Modbus_Multiclass                          numerical
# ToN_IoT_IoT_Motion_Light_Multiclass                        mixed
# ToN_IoT_IoT_Thermostat_Multiclass                      numerical
# ToN_IoT_IoT_Weather_Multiclass                         numerical
# ToN_IoT_Linux_Disk_Multiclass                              mixed
# ToN_IoT_Linux_Memory_Multiclass                            mixed
# ToN_IoT_Linux_Process_Multiclass                           mixed
# ToN_IoT_Network_Multiclass                                 mixed
# ToN_IoT_Windows_10_Multiclass                              mixed
# ToN_IoT_Windows_7_Multiclass                               mixed
#
#                                                     overall_difficulty  \
# filename
# CIC_IDS_2017_Multiclass                                       0.516218
# CIC_IOT_Dataset2023_Multiclass                                0.463669
# IoT_23_Multiclass                                             0.654002
# IoT_Network_Intrusion_Macro_Multiclass                        0.581516
# IoT_Network_Intrusion_Micro_Multiclass                        0.578433
# KDD_Cup_1999_Multiclass                                       0.533156
# UNSW_NB15_Multiclass                                          0.597476
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                     0.572254
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                0.519524
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                        0.546486
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                         0.460704
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...            0.491843
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                    0.593863
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                 0.360607
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                      0.548461
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                      0.569529
# BoT_IoT_Macro_Multiclass                                      0.619307
# BoT_IoT_Micro_Multiclass                                      0.566537
# CICAPT_IIoT_Phase1_Macro_Multiclass                                NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                                NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                           0.517063
# CICAPT_IIoT_Phase2_Micro_Multiclass                           0.518205
# CICEVSE2024_EVSE-A_Macro_Multiclass                           0.570154
# CICEVSE2024_EVSE-A_Micro_Multiclass                           0.418905
# CICEVSE2024_EVSE-B_Macro_Multiclass                           0.503855
# CICEVSE2024_EVSE-B_Micro_Multiclass                           0.479447
# CICIoMT2024_Bluetooth_Multiclass                              0.538772
# CICIoMT2024_WiFi_and_MQTT_Multiclass                          0.397739
# CICIoV2024_Decimal_Macro_Multiclass                           0.589875
# CICIoV2024_Decimal_Micro_Multiclass                           0.580870
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                          0.526111
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                           0.536483
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                    0.429059
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                    0.507469
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                   0.467393
# NIDS_CIC-BoT-IoT_Multiclass                                   0.595285
# NIDS_CIC-ToN-IoT_Multiclass                                   0.465092
# NIDS_NF-BoT-IoT_Multiclass                                    0.640908
# NIDS_NF-BoT-IoT-v2_Multiclass                                 0.536886
# NIDS_NF-BoT-IoT-v3_Multiclass                                 0.576319
# NIDS_NF-CICIDS2018-v3_Multiclass                              0.527313
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                            0.550265
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                         0.517460
# NIDS_NF-ToN-IoT_Multiclass                                    0.636013
# NIDS_NF-ToN-IoT-v2_Multiclass                                 0.583370
# NIDS_NF-ToN-IoT-v3_Multiclass                                 0.551168
# NIDS_NF-UNSW-NB15_Multiclass                                  0.627604
# NIDS_NF-UNSW-NB15-v2_Multiclass                               0.599331
# NIDS_NF-UNSW-NB15-v3_Multiclass                               0.544359
# NIDS_NF-UQ-NIDS_Multiclass                                    0.620050
# NIDS_NF-UQ-NIDS-v2_Multiclass                                 0.595760
# N_BaIoT_Danmini_Doorbell_Multiclass                           0.371364
# N_BaIoT_Ecobee_Thermostat_Multiclass                          0.394711
# N_BaIoT_Ennio_Doorbell_Multiclass                             0.488680
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass               0.385541
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...            0.396969
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...            0.388816
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                  0.438475
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...            0.396316
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...            0.405885
# ToN_IoT_IoT_Fridge_Multiclass                                 0.668529
# ToN_IoT_IoT_GPS_Tracker_Multiclass                            0.544818
# ToN_IoT_IoT_Garage_Door_Multiclass                            0.725050
# ToN_IoT_IoT_Modbus_Multiclass                                 0.662900
# ToN_IoT_IoT_Motion_Light_Multiclass                                NaN
# ToN_IoT_IoT_Thermostat_Multiclass                             0.639772
# ToN_IoT_IoT_Weather_Multiclass                                0.665726
# ToN_IoT_Linux_Disk_Multiclass                                 0.631321
# ToN_IoT_Linux_Memory_Multiclass                               0.631639
# ToN_IoT_Linux_Process_Multiclass                              0.589587
# ToN_IoT_Network_Multiclass                                    0.610578
# ToN_IoT_Windows_10_Multiclass                                 0.426004
# ToN_IoT_Windows_7_Multiclass                                  0.469112
#
#                                                             shape  \
# filename
# CIC_IDS_2017_Multiclass                              (750040, 70)
# CIC_IOT_Dataset2023_Multiclass                      (2692680, 39)
# IoT_23_Multiclass                                    (218338, 12)
# IoT_Network_Intrusion_Macro_Multiclass               (129388, 26)
# IoT_Network_Intrusion_Micro_Multiclass               (129388, 26)
# KDD_Cup_1999_Multiclass                              (645000, 40)
# UNSW_NB15_Multiclass                                (1166862, 45)
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass            (175739, 73)
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                NaN
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass               (155135, 73)
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                         NaN
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...   (107055, 71)
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass            (53526, 73)
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass       (1179830, 69)
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass             (426999, 71)
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass             (198839, 69)
# BoT_IoT_Macro_Multiclass                            (1022440, 20)
# BoT_IoT_Micro_Multiclass                            (1023353, 20)
# CICAPT_IIoT_Phase1_Macro_Multiclass                           NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                           NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                 (4925659, 48)
# CICAPT_IIoT_Phase2_Micro_Multiclass                 (4925659, 48)
# CICEVSE2024_EVSE-A_Macro_Multiclass                  (219912, 68)
# CICEVSE2024_EVSE-A_Micro_Multiclass                  (219912, 68)
# CICEVSE2024_EVSE-B_Macro_Multiclass                  (171987, 68)
# CICEVSE2024_EVSE-B_Micro_Multiclass                  (172005, 68)
# CICIoMT2024_Bluetooth_Multiclass                              NaN
# CICIoMT2024_WiFi_and_MQTT_Multiclass                (1154546, 44)
# CICIoV2024_Decimal_Macro_Multiclass                     (2147, 8)
# CICIoV2024_Decimal_Micro_Multiclass                     (2152, 8)
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                 (963847, 45)
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                   (91145, 41)
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass            (23651, 28)
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass             (1047, 17)
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass           (38160, 16)
# NIDS_CIC-BoT-IoT_Multiclass                          (901752, 79)
# NIDS_CIC-ToN-IoT_Multiclass                          (101735, 71)
# NIDS_NF-BoT-IoT_Multiclass                            (56502, 10)
# NIDS_NF-BoT-IoT-v2_Multiclass                         (85853, 38)
# NIDS_NF-BoT-IoT-v3_Multiclass                        (409262, 46)
# NIDS_NF-CICIDS2018-v3_Multiclass                    (4910519, 45)
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                   (234614, 10)
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass               (1082471, 37)
# NIDS_NF-ToN-IoT_Multiclass                           (403383, 10)
# NIDS_NF-ToN-IoT-v2_Multiclass                        (699477, 38)
# NIDS_NF-ToN-IoT-v3_Multiclass                       (2528124, 46)
# NIDS_NF-UNSW-NB15_Multiclass                         (255828, 10)
# NIDS_NF-UNSW-NB15-v2_Multiclass                       (87047, 38)
# NIDS_NF-UNSW-NB15-v3_Multiclass                      (705875, 46)
# NIDS_NF-UQ-NIDS_Multiclass                           (355686, 10)
# NIDS_NF-UQ-NIDS-v2_Multiclass                       (1922815, 38)
# N_BaIoT_Danmini_Doorbell_Multiclass                 (422925, 115)
# N_BaIoT_Ecobee_Thermostat_Multiclass                (324583, 115)
# N_BaIoT_Ennio_Doorbell_Multiclass                    (87626, 115)
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass     (471723, 115)
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...  (268241, 115)
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...  (284016, 115)
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass         (98625, 115)
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...  (306334, 115)
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...  (329363, 115)
# ToN_IoT_IoT_Fridge_Multiclass                            (635, 2)
# ToN_IoT_IoT_GPS_Tracker_Multiclass                       (384, 2)
# ToN_IoT_IoT_Garage_Door_Multiclass                            NaN
# ToN_IoT_IoT_Modbus_Multiclass                          (67704, 4)
# ToN_IoT_IoT_Motion_Light_Multiclass                           NaN
# ToN_IoT_IoT_Thermostat_Multiclass                      (24391, 2)
# ToN_IoT_IoT_Weather_Multiclass                        (342921, 3)
# ToN_IoT_Linux_Disk_Multiclass                          (14495, 5)
# ToN_IoT_Linux_Memory_Multiclass                        (49634, 9)
# ToN_IoT_Linux_Process_Multiclass                      (12552, 12)
# ToN_IoT_Network_Multiclass                           (282243, 40)
# ToN_IoT_Windows_10_Multiclass                        (21129, 113)
# ToN_IoT_Windows_7_Multiclass                         (16859, 104)
#
#                                                     X_train_shape  \
# filename
# CIC_IDS_2017_Multiclass                              (750040, 70)
# CIC_IOT_Dataset2023_Multiclass                      (2692680, 39)
# IoT_23_Multiclass                                    (218338, 12)
# IoT_Network_Intrusion_Macro_Multiclass               (129388, 26)
# IoT_Network_Intrusion_Micro_Multiclass               (129388, 26)
# KDD_Cup_1999_Multiclass                              (645000, 40)
# UNSW_NB15_Multiclass                                (1166862, 45)
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass            (175739, 73)
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                NaN
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass               (155135, 73)
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                         NaN
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...   (107055, 71)
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass            (53526, 73)
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass       (1179830, 69)
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass             (426999, 71)
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass             (198839, 69)
# BoT_IoT_Macro_Multiclass                            (1022440, 20)
# BoT_IoT_Micro_Multiclass                            (1023353, 20)
# CICAPT_IIoT_Phase1_Macro_Multiclass                           NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                           NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                 (4925659, 48)
# CICAPT_IIoT_Phase2_Micro_Multiclass                 (4925659, 48)
# CICEVSE2024_EVSE-A_Macro_Multiclass                   (21990, 68)
# CICEVSE2024_EVSE-A_Micro_Multiclass                  (219912, 68)
# CICEVSE2024_EVSE-B_Macro_Multiclass                   (17190, 68)
# CICEVSE2024_EVSE-B_Micro_Multiclass                   (17187, 68)
# CICIoMT2024_Bluetooth_Multiclass                              NaN
# CICIoMT2024_WiFi_and_MQTT_Multiclass                (1154546, 44)
# CICIoV2024_Decimal_Macro_Multiclass                     (2147, 8)
# CICIoV2024_Decimal_Micro_Multiclass                     (2152, 8)
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                 (963847, 45)
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                   (91145, 41)
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass            (23651, 28)
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass             (1047, 17)
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass           (38160, 16)
# NIDS_CIC-BoT-IoT_Multiclass                           (90173, 79)
# NIDS_CIC-ToN-IoT_Multiclass                           (10176, 31)
# NIDS_NF-BoT-IoT_Multiclass                             (5647, 10)
# NIDS_NF-BoT-IoT-v2_Multiclass                         (85853, 38)
# NIDS_NF-BoT-IoT-v3_Multiclass                        (409262, 46)
# NIDS_NF-CICIDS2018-v3_Multiclass                    (4910519, 45)
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                    (23456, 10)
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass               (1082471, 37)
# NIDS_NF-ToN-IoT_Multiclass                            (40334, 10)
# NIDS_NF-ToN-IoT-v2_Multiclass                        (699477, 38)
# NIDS_NF-ToN-IoT-v3_Multiclass                       (2528124, 46)
# NIDS_NF-UNSW-NB15_Multiclass                         (255828, 10)
# NIDS_NF-UNSW-NB15-v2_Multiclass                       (87047, 38)
# NIDS_NF-UNSW-NB15-v3_Multiclass                      (705875, 46)
# NIDS_NF-UQ-NIDS_Multiclass                           (355686, 10)
# NIDS_NF-UQ-NIDS-v2_Multiclass                       (1922815, 38)
# N_BaIoT_Danmini_Doorbell_Multiclass                 (422925, 115)
# N_BaIoT_Ecobee_Thermostat_Multiclass                (324583, 115)
# N_BaIoT_Ennio_Doorbell_Multiclass                    (87626, 115)
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass     (471723, 115)
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...  (268241, 115)
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...  (284016, 115)
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass         (98625, 115)
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...  (306334, 115)
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...  (329363, 115)
# ToN_IoT_IoT_Fridge_Multiclass                             (63, 2)
# ToN_IoT_IoT_GPS_Tracker_Multiclass                        (38, 2)
# ToN_IoT_IoT_Garage_Door_Multiclass                            NaN
# ToN_IoT_IoT_Modbus_Multiclass                           (6087, 4)
# ToN_IoT_IoT_Motion_Light_Multiclass                           NaN
# ToN_IoT_IoT_Thermostat_Multiclass                       (2436, 2)
# ToN_IoT_IoT_Weather_Multiclass                        (342921, 3)
# ToN_IoT_Linux_Disk_Multiclass                           (1445, 5)
# ToN_IoT_Linux_Memory_Multiclass                        (49634, 9)
# ToN_IoT_Linux_Process_Multiclass                       (1251, 11)
# ToN_IoT_Network_Multiclass                           (282243, 40)
# ToN_IoT_Windows_10_Multiclass                        (21129, 113)
# ToN_IoT_Windows_7_Multiclass                         (16859, 104)
#
#                                                       X_val_shape  \
# filename
# CIC_IDS_2017_Multiclass                              (250013, 70)
# CIC_IOT_Dataset2023_Multiclass                       (897560, 39)
# IoT_23_Multiclass                                     (72779, 12)
# IoT_Network_Intrusion_Macro_Multiclass                (43129, 26)
# IoT_Network_Intrusion_Micro_Multiclass                (43129, 26)
# KDD_Cup_1999_Multiclass                              (215000, 40)
# UNSW_NB15_Multiclass                                 (388954, 45)
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass             (58580, 73)
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                NaN
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                (51712, 73)
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                         NaN
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...    (35685, 71)
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass            (17842, 73)
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass        (393277, 69)
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass             (142333, 71)
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass              (66280, 69)
# BoT_IoT_Macro_Multiclass                             (340813, 20)
# BoT_IoT_Micro_Multiclass                             (341118, 20)
# CICAPT_IIoT_Phase1_Macro_Multiclass                           NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                           NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                 (1641886, 48)
# CICAPT_IIoT_Phase2_Micro_Multiclass                 (1641886, 48)
# CICEVSE2024_EVSE-A_Macro_Multiclass                   (73304, 68)
# CICEVSE2024_EVSE-A_Micro_Multiclass                   (73304, 68)
# CICEVSE2024_EVSE-B_Macro_Multiclass                   (57329, 68)
# CICEVSE2024_EVSE-B_Micro_Multiclass                   (57335, 68)
# CICIoMT2024_Bluetooth_Multiclass                              NaN
# CICIoMT2024_WiFi_and_MQTT_Multiclass                 (384848, 44)
# CICIoV2024_Decimal_Macro_Multiclass                      (715, 8)
# CICIoV2024_Decimal_Micro_Multiclass                      (717, 8)
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                 (321282, 45)
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                   (30382, 41)
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass             (7884, 28)
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass              (349, 17)
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass           (12720, 16)
# NIDS_CIC-BoT-IoT_Multiclass                          (300584, 79)
# NIDS_CIC-ToN-IoT_Multiclass                           (33911, 31)
# NIDS_NF-BoT-IoT_Multiclass                            (18834, 10)
# NIDS_NF-BoT-IoT-v2_Multiclass                         (28617, 38)
# NIDS_NF-BoT-IoT-v3_Multiclass                        (136420, 46)
# NIDS_NF-CICIDS2018-v3_Multiclass                    (1636840, 45)
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                    (78204, 10)
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                (360823, 37)
# NIDS_NF-ToN-IoT_Multiclass                           (134461, 10)
# NIDS_NF-ToN-IoT-v2_Multiclass                        (233159, 38)
# NIDS_NF-ToN-IoT-v3_Multiclass                        (842708, 46)
# NIDS_NF-UNSW-NB15_Multiclass                          (85276, 10)
# NIDS_NF-UNSW-NB15-v2_Multiclass                       (29015, 38)
# NIDS_NF-UNSW-NB15-v3_Multiclass                      (235291, 46)
# NIDS_NF-UQ-NIDS_Multiclass                           (118562, 10)
# NIDS_NF-UQ-NIDS-v2_Multiclass                        (640938, 38)
# N_BaIoT_Danmini_Doorbell_Multiclass                 (140975, 115)
# N_BaIoT_Ecobee_Thermostat_Multiclass                (108194, 115)
# N_BaIoT_Ennio_Doorbell_Multiclass                    (29209, 115)
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass     (157241, 115)
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...   (89414, 115)
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...   (94672, 115)
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass         (32875, 115)
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...  (102111, 115)
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...  (109788, 115)
# ToN_IoT_IoT_Fridge_Multiclass                            (211, 2)
# ToN_IoT_IoT_GPS_Tracker_Multiclass                       (128, 2)
# ToN_IoT_IoT_Garage_Door_Multiclass                            NaN
# ToN_IoT_IoT_Modbus_Multiclass                          (22568, 4)
# ToN_IoT_IoT_Motion_Light_Multiclass                           NaN
# ToN_IoT_IoT_Thermostat_Multiclass                       (8130, 2)
# ToN_IoT_IoT_Weather_Multiclass                        (114307, 3)
# ToN_IoT_Linux_Disk_Multiclass                           (4832, 5)
# ToN_IoT_Linux_Memory_Multiclass                        (16544, 9)
# ToN_IoT_Linux_Process_Multiclass                       (4184, 11)
# ToN_IoT_Network_Multiclass                            (94081, 40)
# ToN_IoT_Windows_10_Multiclass                         (7043, 113)
# ToN_IoT_Windows_7_Multiclass                          (5619, 104)
#
#                                                      X_test_shape  \
# filename
# CIC_IDS_2017_Multiclass                              (250013, 70)
# CIC_IOT_Dataset2023_Multiclass                       (897560, 39)
# IoT_23_Multiclass                                     (72779, 12)
# IoT_Network_Intrusion_Macro_Multiclass                (43129, 26)
# IoT_Network_Intrusion_Micro_Multiclass                (43129, 26)
# KDD_Cup_1999_Multiclass                              (214999, 40)
# UNSW_NB15_Multiclass                                 (388953, 45)
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass             (58579, 73)
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                NaN
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                (51711, 73)
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                         NaN
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...    (35684, 71)
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass            (17841, 73)
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass        (393276, 69)
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass             (142332, 71)
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass              (66279, 69)
# BoT_IoT_Macro_Multiclass                             (340813, 20)
# BoT_IoT_Micro_Multiclass                             (341117, 20)
# CICAPT_IIoT_Phase1_Macro_Multiclass                           NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                           NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                 (1641886, 48)
# CICAPT_IIoT_Phase2_Micro_Multiclass                 (1641886, 48)
# CICEVSE2024_EVSE-A_Macro_Multiclass                   (73304, 68)
# CICEVSE2024_EVSE-A_Micro_Multiclass                   (73304, 68)
# CICEVSE2024_EVSE-B_Macro_Multiclass                   (57329, 68)
# CICEVSE2024_EVSE-B_Micro_Multiclass                   (57335, 68)
# CICIoMT2024_Bluetooth_Multiclass                              NaN
# CICIoMT2024_WiFi_and_MQTT_Multiclass                 (384848, 44)
# CICIoV2024_Decimal_Macro_Multiclass                      (715, 8)
# CICIoV2024_Decimal_Micro_Multiclass                      (717, 8)
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                 (321282, 45)
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                   (30381, 41)
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass             (7883, 28)
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass              (348, 17)
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass           (12720, 16)
# NIDS_CIC-BoT-IoT_Multiclass                          (300583, 79)
# NIDS_CIC-ToN-IoT_Multiclass                           (33911, 31)
# NIDS_NF-BoT-IoT_Multiclass                            (18833, 10)
# NIDS_NF-BoT-IoT-v2_Multiclass                         (28617, 38)
# NIDS_NF-BoT-IoT-v3_Multiclass                        (136420, 46)
# NIDS_NF-CICIDS2018-v3_Multiclass                    (1636839, 45)
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                    (78204, 10)
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                (360823, 37)
# NIDS_NF-ToN-IoT_Multiclass                           (134461, 10)
# NIDS_NF-ToN-IoT-v2_Multiclass                        (233158, 38)
# ...
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                     --
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                    --
# NIDS_CIC-BoT-IoT_Multiclass                                    --
# NIDS_CIC-ToN-IoT_Multiclass                                    --
# NIDS_NF-BoT-IoT_Multiclass                                     --
# NIDS_NF-BoT-IoT-v2_Multiclass                                  --
# NIDS_NF-BoT-IoT-v3_Multiclass                                  --
# NIDS_NF-CICIDS2018-v3_Multiclass                               --
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                             --
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                          --
# NIDS_NF-ToN-IoT_Multiclass                                     --
# NIDS_NF-ToN-IoT-v2_Multiclass                                  --
# NIDS_NF-ToN-IoT-v3_Multiclass                                  --
# NIDS_NF-UNSW-NB15_Multiclass                                   --
# NIDS_NF-UNSW-NB15-v2_Multiclass                                --
# NIDS_NF-UNSW-NB15-v3_Multiclass                                --
# NIDS_NF-UQ-NIDS_Multiclass                                     --
# NIDS_NF-UQ-NIDS-v2_Multiclass                                  --
# N_BaIoT_Danmini_Doorbell_Multiclass                            --
# N_BaIoT_Ecobee_Thermostat_Multiclass                           --
# N_BaIoT_Ennio_Doorbell_Multiclass                              --
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                --
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...             --
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...             --
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                   --
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...             --
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...             --
# ToN_IoT_IoT_Fridge_Multiclass                                  --
# ToN_IoT_IoT_GPS_Tracker_Multiclass                             --
# ToN_IoT_IoT_Garage_Door_Multiclass                            NaN
# ToN_IoT_IoT_Modbus_Multiclass                       100/100 (100)
# ToN_IoT_IoT_Motion_Light_Multiclass                           NaN
# ToN_IoT_IoT_Thermostat_Multiclass                              --
# ToN_IoT_IoT_Weather_Multiclass                                 --
# ToN_IoT_Linux_Disk_Multiclass                                  --
# ToN_IoT_Linux_Memory_Multiclass                                --
# ToN_IoT_Linux_Process_Multiclass                               --
# ToN_IoT_Network_Multiclass                                     --
# ToN_IoT_Windows_10_Multiclass                                  --
# ToN_IoT_Windows_7_Multiclass                                   --
#
#                                                                                            hpo_params  \
# filename
# CIC_IDS_2017_Multiclass                                                                            --
# CIC_IOT_Dataset2023_Multiclass                                                                     --
# IoT_23_Multiclass                                                                                  --
# IoT_Network_Intrusion_Macro_Multiclass                                                             --
# IoT_Network_Intrusion_Micro_Multiclass                                                             --
# KDD_Cup_1999_Multiclass                                                                            --
# UNSW_NB15_Multiclass                                                                               --
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                                                          --
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                                                    NaN
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                                             --
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                                                             NaN
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                                                 --
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                                                         --
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                                                      --
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                                                           --
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                                                           --
# BoT_IoT_Macro_Multiclass                                                                           --
# BoT_IoT_Micro_Multiclass                                                                           --
# CICAPT_IIoT_Phase1_Macro_Multiclass                                                               NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                                                               NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                                                                --
# CICAPT_IIoT_Phase2_Micro_Multiclass                                                                --
# CICEVSE2024_EVSE-A_Macro_Multiclass                                                                --
# CICEVSE2024_EVSE-A_Micro_Multiclass                                                                --
# CICEVSE2024_EVSE-B_Macro_Multiclass                                                                --
# CICEVSE2024_EVSE-B_Micro_Multiclass                                                                --
# CICIoMT2024_Bluetooth_Multiclass                                                                  NaN
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                                               --
# CICIoV2024_Decimal_Macro_Multiclass                                                                --
# CICIoV2024_Decimal_Micro_Multiclass                                                                --
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                                               --
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                                                --
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                                                         --
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                                                         --
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                                                        --
# NIDS_CIC-BoT-IoT_Multiclass                                                                        --
# NIDS_CIC-ToN-IoT_Multiclass                                                                        --
# NIDS_NF-BoT-IoT_Multiclass                                                                         --
# NIDS_NF-BoT-IoT-v2_Multiclass                                                                      --
# NIDS_NF-BoT-IoT-v3_Multiclass                                                                      --
# NIDS_NF-CICIDS2018-v3_Multiclass                                                                   --
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                                                 --
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                                              --
# NIDS_NF-ToN-IoT_Multiclass                                                                         --
# NIDS_NF-ToN-IoT-v2_Multiclass                                                                      --
# NIDS_NF-ToN-IoT-v3_Multiclass                                                                      --
# NIDS_NF-UNSW-NB15_Multiclass                                                                       --
# NIDS_NF-UNSW-NB15-v2_Multiclass                                                                    --
# NIDS_NF-UNSW-NB15-v3_Multiclass                                                                    --
# NIDS_NF-UQ-NIDS_Multiclass                                                                         --
# NIDS_NF-UQ-NIDS-v2_Multiclass                                                                      --
# N_BaIoT_Danmini_Doorbell_Multiclass                                                                --
# N_BaIoT_Ecobee_Thermostat_Multiclass                                                               --
# N_BaIoT_Ennio_Doorbell_Multiclass                                                                  --
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                                                    --
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                                                 --
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                                                 --
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                                                       --
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                                                 --
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                                                 --
# ToN_IoT_IoT_Fridge_Multiclass                                                                      --
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                                                 --
# ToN_IoT_IoT_Garage_Door_Multiclass                                                                NaN
# ToN_IoT_IoT_Modbus_Multiclass                       {'balancing_mode': 'none', 'eta': 0.113, 'max_...
# ToN_IoT_IoT_Motion_Light_Multiclass                                                               NaN
# ToN_IoT_IoT_Thermostat_Multiclass                                                                  --
# ToN_IoT_IoT_Weather_Multiclass                                                                     --
# ToN_IoT_Linux_Disk_Multiclass                                                                      --
# ToN_IoT_Linux_Memory_Multiclass                                                                    --
# ToN_IoT_Linux_Process_Multiclass                                                                   --
# ToN_IoT_Network_Multiclass                                                                         --
# ToN_IoT_Windows_10_Multiclass                                                                      --
# ToN_IoT_Windows_7_Multiclass                                                                       --
#
#                                                          best_config
# filename
# CIC_IDS_2017_Multiclass                                         full
# CIC_IOT_Dataset2023_Multiclass                                  full
# IoT_23_Multiclass                                               full
# IoT_Network_Intrusion_Macro_Multiclass                          full
# IoT_Network_Intrusion_Micro_Multiclass                          full
# KDD_Cup_1999_Multiclass                                         full
# UNSW_NB15_Multiclass                                            full
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                       full
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                   NaN
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                          full
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                            NaN
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...              full
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                      full
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                   full
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                        full
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                        full
# BoT_IoT_Macro_Multiclass                                        full
# BoT_IoT_Micro_Multiclass                                        full
# CICAPT_IIoT_Phase1_Macro_Multiclass                              NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                              NaN
# CICAPT_IIoT_Phase2_Macro_Multiclass                             full
# CICAPT_IIoT_Phase2_Micro_Multiclass                             full
# CICEVSE2024_EVSE-A_Macro_Multiclass                          sampled
# CICEVSE2024_EVSE-A_Micro_Multiclass                             full
# CICEVSE2024_EVSE-B_Macro_Multiclass                          sampled
# CICEVSE2024_EVSE-B_Micro_Multiclass                          sampled
# CICIoMT2024_Bluetooth_Multiclass                                 NaN
# CICIoMT2024_WiFi_and_MQTT_Multiclass                            full
# CICIoV2024_Decimal_Macro_Multiclass                             full
# CICIoV2024_Decimal_Micro_Multiclass                             full
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                            full
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                             full
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                      full
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                      full
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                     full
# NIDS_CIC-BoT-IoT_Multiclass                                  sampled
# NIDS_CIC-ToN-IoT_Multiclass                                  reduced
# NIDS_NF-BoT-IoT_Multiclass                                   sampled
# NIDS_NF-BoT-IoT-v2_Multiclass                                   full
# NIDS_NF-BoT-IoT-v3_Multiclass                                   full
# NIDS_NF-CICIDS2018-v3_Multiclass                                full
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                           sampled
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                           full
# NIDS_NF-ToN-IoT_Multiclass                                   sampled
# NIDS_NF-ToN-IoT-v2_Multiclass                                   full
# NIDS_NF-ToN-IoT-v3_Multiclass                                   full
# NIDS_NF-UNSW-NB15_Multiclass                                    full
# NIDS_NF-UNSW-NB15-v2_Multiclass                                 full
# NIDS_NF-UNSW-NB15-v3_Multiclass                                 full
# NIDS_NF-UQ-NIDS_Multiclass                                      full
# NIDS_NF-UQ-NIDS-v2_Multiclass                                   full
# N_BaIoT_Danmini_Doorbell_Multiclass                             full
# N_BaIoT_Ecobee_Thermostat_Multiclass                            full
# N_BaIoT_Ennio_Doorbell_Multiclass                               full
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                 full
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...              full
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...              full
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                    full
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...              full
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...              full
# ToN_IoT_IoT_Fridge_Multiclass                                sampled
# ToN_IoT_IoT_GPS_Tracker_Multiclass                           sampled
# ToN_IoT_IoT_Garage_Door_Multiclass                               NaN
# ToN_IoT_IoT_Modbus_Multiclass                       hpo_best_latency
# ToN_IoT_IoT_Motion_Light_Multiclass                              NaN
# ToN_IoT_IoT_Thermostat_Multiclass                            sampled
# ToN_IoT_IoT_Weather_Multiclass                                  full
# ToN_IoT_Linux_Disk_Multiclass                                sampled
# ToN_IoT_Linux_Memory_Multiclass                                 full
# ToN_IoT_Linux_Process_Multiclass                             reduced
# ToN_IoT_Network_Multiclass                                      full
# ToN_IoT_Windows_10_Multiclass                                   full
# ToN_IoT_Windows_7_Multiclass                                    full

# %%
summary_df.to_excel("/home/automl/git/iot-threat-classifier/2025-06-28/summary.xlsx")

# %%
summary_df[summary_df.isna().any(axis=1)]
# Out:
#                                                    size_mb   samples  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass   22.411199   1175500
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass             6.598314     91787
# CICAPT_IIoT_Phase1_Macro_Multiclass             101.821614  10260159
# CICAPT_IIoT_Phase1_Micro_Multiclass             101.821614  10260159
# CICIoMT2024_Bluetooth_Multiclass                  0.008513       747
# ToN_IoT_IoT_Garage_Door_Multiclass                0.002548        18
# ToN_IoT_IoT_Motion_Light_Multiclass               0.002620        16
#
#                                                 features  classes  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass        69       12
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                 72        2
# CICAPT_IIoT_Phase1_Macro_Multiclass                   48        1
# CICAPT_IIoT_Phase1_Micro_Multiclass                   48        1
# CICIoMT2024_Bluetooth_Multiclass                       7        2
# ToN_IoT_IoT_Garage_Door_Multiclass                     2        8
# ToN_IoT_IoT_Motion_Light_Multiclass                    2        8
#
#                                                                                     dtypes  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass  {int64, category, float32, int32, float64}
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                    {int32, int64, float32, category}
# CICAPT_IIoT_Phase1_Macro_Multiclass             {int64, category, float32, int32, float64}
# CICAPT_IIoT_Phase1_Micro_Multiclass             {int64, category, float32, int32, float64}
# CICIoMT2024_Bluetooth_Multiclass                                 {int32, float64, float32}
# ToN_IoT_IoT_Garage_Door_Multiclass                                              {category}
# ToN_IoT_IoT_Motion_Light_Multiclass                                      {int64, category}
#
#                                                feature_types  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass         mixed
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                  mixed
# CICAPT_IIoT_Phase1_Macro_Multiclass                    mixed
# CICAPT_IIoT_Phase1_Micro_Multiclass                    mixed
# CICIoMT2024_Bluetooth_Multiclass                   numerical
# ToN_IoT_IoT_Garage_Door_Multiclass               categorical
# ToN_IoT_IoT_Motion_Light_Multiclass                    mixed
#
#                                                 overall_difficulty shape  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass            0.519524   NaN
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                     0.460704   NaN
# CICAPT_IIoT_Phase1_Macro_Multiclass                            NaN   NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                            NaN   NaN
# CICIoMT2024_Bluetooth_Multiclass                          0.538772   NaN
# ToN_IoT_IoT_Garage_Door_Multiclass                        0.725050   NaN
# ToN_IoT_IoT_Motion_Light_Multiclass                            NaN   NaN
#
#                                                X_train_shape X_val_shape  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass           NaN         NaN
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                    NaN         NaN
# CICAPT_IIoT_Phase1_Macro_Multiclass                      NaN         NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                      NaN         NaN
# CICIoMT2024_Bluetooth_Multiclass                         NaN         NaN
# ToN_IoT_IoT_Garage_Door_Multiclass                       NaN         NaN
# ToN_IoT_IoT_Motion_Light_Multiclass                      NaN         NaN
#
#                                                X_test_shape  model_size_abs  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass          NaN             NaN
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                   NaN             NaN
# CICAPT_IIoT_Phase1_Macro_Multiclass                     NaN             NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                     NaN             NaN
# CICIoMT2024_Bluetooth_Multiclass                        NaN             NaN
# ToN_IoT_IoT_Garage_Door_Multiclass                      NaN             NaN
# ToN_IoT_IoT_Motion_Light_Multiclass                     NaN             NaN
#
#                                                model_size_delta  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass              NaN
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                       NaN
# CICAPT_IIoT_Phase1_Macro_Multiclass                         NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                         NaN
# CICIoMT2024_Bluetooth_Multiclass                            NaN
# ToN_IoT_IoT_Garage_Door_Multiclass                          NaN
# ToN_IoT_IoT_Motion_Light_Multiclass                         NaN
#
#                                                 training_time_abs  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                NaN
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                         NaN
# CICAPT_IIoT_Phase1_Macro_Multiclass                           NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                           NaN
# CICIoMT2024_Bluetooth_Multiclass                              NaN
# ToN_IoT_IoT_Garage_Door_Multiclass                            NaN
# ToN_IoT_IoT_Motion_Light_Multiclass                           NaN
#
#                                                training_time_delta  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                 NaN
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                          NaN
# CICAPT_IIoT_Phase1_Macro_Multiclass                            NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                            NaN
# CICIoMT2024_Bluetooth_Multiclass                               NaN
# ToN_IoT_IoT_Garage_Door_Multiclass                             NaN
# ToN_IoT_IoT_Motion_Light_Multiclass                            NaN
#
#                                                 latency_abs latency_delta  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass          NaN           NaN
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                   NaN           NaN
# CICAPT_IIoT_Phase1_Macro_Multiclass                     NaN           NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                     NaN           NaN
# CICIoMT2024_Bluetooth_Multiclass                        NaN           NaN
# ToN_IoT_IoT_Garage_Door_Multiclass                      NaN           NaN
# ToN_IoT_IoT_Motion_Light_Multiclass                     NaN           NaN
#
#                                                 f1_score_abs f1_score_delta  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass           NaN            NaN
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                    NaN            NaN
# CICAPT_IIoT_Phase1_Macro_Multiclass                      NaN            NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                      NaN            NaN
# CICIoMT2024_Bluetooth_Multiclass                         NaN            NaN
# ToN_IoT_IoT_Garage_Door_Multiclass                       NaN            NaN
# ToN_IoT_IoT_Motion_Light_Multiclass                      NaN            NaN
#
#                                                hpo_n_trials hpo_params  \
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass          NaN        NaN
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                   NaN        NaN
# CICAPT_IIoT_Phase1_Macro_Multiclass                     NaN        NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                     NaN        NaN
# CICIoMT2024_Bluetooth_Multiclass                        NaN        NaN
# ToN_IoT_IoT_Garage_Door_Multiclass                      NaN        NaN
# ToN_IoT_IoT_Motion_Light_Multiclass                     NaN        NaN
#
#                                                best_config
# filename
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass         NaN
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                  NaN
# CICAPT_IIoT_Phase1_Macro_Multiclass                    NaN
# CICAPT_IIoT_Phase1_Micro_Multiclass                    NaN
# CICIoMT2024_Bluetooth_Multiclass                       NaN
# ToN_IoT_IoT_Garage_Door_Multiclass                     NaN
# ToN_IoT_IoT_Motion_Light_Multiclass                    NaN

# %%
summary_df[summary_df.isna().any(axis=1)].to_excel("/home/automl/git/iot-threat-classifier/2025-06-28/errors.xlsx")

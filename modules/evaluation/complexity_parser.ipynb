# %%
# Standard library
import json
import os
import warnings
from pathlib import Path

# Third-party libraries
import numpy as np
import pandas as pd
from matplotlib import colormaps
from matplotlib.colors import Normalize
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm

# Show all rows and prevent column truncation
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 0)  # Auto-detect width

# %%
metric_groups = {
    "Feature_Relevance": [
        "anova_f_mean", 
        "mutual_info_mean"
    ],
    "Local_Overlap": [
        "pca_centroid_distance_pca_centroid_score", 
        "mahalanobis_class_distance_mean"
    ],
    "Boundary_Hardness": [
        "svm_margin_mean", 
        "class_proba_entropy_mean"
    ],
    "Global_Structure": [
        "intrinsic_dimensionality_intrinsic_dimensionality_percent", 
        "calinski_harabasz_calinski_harabasz_score"
    ],
    "Class_Distribution_Separation": [
        "class_confusion_entropy_confusion_entropy", 
        "class_imbalance_normalized_entropy"
    ]
}

# %%
# Invert selected metrics (where higher = easier)
metrics_to_invert = {
    "anova_f_mean",
    "mutual_info_mean",
    "svm_margin_mean",
    "pca_centroid_score",
    "mahalanobis_class_distance_mean",
    "calinski_harabasz_calinski_harabasz_score",
    "class_imbalance_normalized_entropy"
}

# %%
row_order = [
    "CIC_IDS_2017_Multiclass",
    "CIC_IOT_Dataset2023_Multiclass",
    "IoT_23_Multiclass",
    "IoT_Network_Intrusion_Macro_Multiclass",
    "IoT_Network_Intrusion_Micro_Multiclass",
    "KDD_Cup_1999_Multiclass",
    "UNSW_NB15_Multiclass",
    "BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass",
    "BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass",
    "BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass",
    "BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass",
    "BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_and_Testing_Multiclass",
    "BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass",
    "BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass",
    "BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass",
    "BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass",
    "BoT_IoT_Macro_Multiclass",
    "BoT_IoT_Micro_Multiclass",
    "CICAPT_IIoT_Phase1_Macro_Multiclass", # nok (single-class)
    "CICAPT_IIoT_Phase1_Micro_Multiclass", # nok (single-class)
    "CICAPT_IIoT_Phase2_Macro_Multiclass",
    "CICAPT_IIoT_Phase2_Micro_Multiclass",
    "CICEVSE2024_EVSE-A_Macro_Multiclass",
    "CICEVSE2024_EVSE-A_Micro_Multiclass",
    "CICEVSE2024_EVSE-B_Macro_Multiclass",
    "CICEVSE2024_EVSE-B_Micro_Multiclass",
    "CICIoMT2024_Bluetooth_Multiclass",
    "CICIoMT2024_WiFi_and_MQTT_Multiclass",
    "CICIoV2024_Decimal_Macro_Multiclass",
    "CICIoV2024_Decimal_Micro_Multiclass",
    "EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass",
    "EDGE-IIOTSET_ML-EdgeIIoT_Multiclass",
    "MQTT_IoT_IDS2020_BiflowFeatures_Multiclass",
    "MQTT_IoT_IDS2020_PacketFeatures_Multiclass",
    "MQTT_IoT_IDS2020_UniflowFeatures_Multiclass",
    "NIDS_CIC-BoT-IoT_Multiclass",
    "NIDS_CIC-ToN-IoT_Multiclass",
    "NIDS_NF-BoT-IoT_Multiclass",
    "NIDS_NF-BoT-IoT-v2_Multiclass",
    "NIDS_NF-BoT-IoT-v3_Multiclass",
    "NIDS_NF-CICIDS2018-v3_Multiclass",
    "NIDS_NF-CSE-CIC-IDS2018_Multiclass",
    "NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass",
    "NIDS_NF-ToN-IoT_Multiclass",
    "NIDS_NF-ToN-IoT-v2_Multiclass",
    "NIDS_NF-ToN-IoT-v3_Multiclass",
    "NIDS_NF-UNSW-NB15_Multiclass",
    "NIDS_NF-UNSW-NB15-v2_Multiclass",
    "NIDS_NF-UNSW-NB15-v3_Multiclass",
    "NIDS_NF-UQ-NIDS_Multiclass",
    "NIDS_NF-UQ-NIDS-v2_Multiclass",
    "N_BaIoT_Danmini_Doorbell_Multiclass",
    "N_BaIoT_Ecobee_Thermostat_Multiclass",
    "N_BaIoT_Ennio_Doorbell_Multiclass",
    "N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass",
    "N_BaIoT_Provision_PT_737E_Security_Camera_Multiclass",
    "N_BaIoT_Provision_PT_838_Security_Camera_Multiclass",
    "N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass",
    "N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camera_Multiclass",
    "N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camera_Multiclass",
    "ToN_IoT_IoT_Fridge_Multiclass",
    "ToN_IoT_IoT_GPS_Tracker_Multiclass",
    "ToN_IoT_IoT_Garage_Door_Multiclass",
    "ToN_IoT_IoT_Modbus_Multiclass",
    "ToN_IoT_IoT_Motion_Light_Multiclass",
    "ToN_IoT_IoT_Thermostat_Multiclass",
    "ToN_IoT_IoT_Weather_Multiclass",
    "ToN_IoT_Linux_Disk_Multiclass",
    "ToN_IoT_Linux_Memory_Multiclass",
    "ToN_IoT_Linux_Process_Multiclass",
    "ToN_IoT_Network_Multiclass",
    "ToN_IoT_Windows_10_Multiclass",
    "ToN_IoT_Windows_7_Multiclass"
]

# %%
def blend_with_white(rgb, alpha):
    return [1 - alpha * (1 - c) for c in rgb]

def format_and_color_columns(df, color_map_dict={}, alpha=0.0):
    df_colored = df.copy()

    for col in df.columns:
        col_data = df[col]

        # === Step 1: Apply your custom formatting ===
        if pd.api.types.is_float_dtype(col_data):
            if 'time' in col:
                formatted = col_data.map(lambda x: f"{x:,.1f}")
            elif 'size' in col:
                formatted = col_data.map(lambda x: f"{x:,.2f}")
            else:
                formatted = col_data.map(lambda x: f"{x:,.3f}")
        elif pd.api.types.is_integer_dtype(col_data):
            formatted = col_data.map(lambda x: f"{x:,}")
        else:
            formatted = col_data.astype(str)

        # === Step 2: Apply LaTeX color using colormap if specified ===
        if col in color_map_dict and pd.api.types.is_numeric_dtype(col_data):
            cmap = colormaps[color_map_dict[col]]
            valid_mask = col_data.notna()
            norm = Normalize(vmin=col_data[valid_mask].min(), vmax=col_data[valid_mask].max())
    
            # Start with string-typed formatted column
            colored_column = formatted.astype(str).copy()
    
            # Compute blended RGB
            rgba_colors = cmap(norm(col_data[valid_mask]))[:, :3]
            blended_colors = [blend_with_white(rgb, alpha=alpha) for rgb in rgba_colors]
    
            for i, (r, g, b) in zip(col_data[valid_mask].index, blended_colors):
                df_colored.loc[i, col] = (
                    f"\\cellcolor[rgb]{{{r:.3f}, {g:.3f}, {b:.3f}}} {formatted[i]}"
                )
        else:
            df_colored[col] = formatted

    return df_colored

# %%
def flatten_metrics_dict(metrics_dict: dict, dataset_id: str, keys_to_include=None) -> dict:
    flat = {"dataset_id": dataset_id}
    for top_key, subdict in metrics_dict.items():
        if isinstance(subdict, dict):
            for sub_key, value in subdict.items():
                flat_key = f"{top_key}_{sub_key}"
                if keys_to_include is None or flat_key in keys_to_include:
                    flat[flat_key] = value
        else:
            if keys_to_include is None or top_key in keys_to_include:
                flat[top_key] = subdict
    return flat

def compute_composite_difficulty_from_dict(metrics_dict: dict, dataset_id: str, min_metrics_per_group=1) -> pd.DataFrame | None:
    all_metrics = [m for group in metric_groups.values() for m in group]
    
    flat_dict = flatten_metrics_dict(metrics_dict, dataset_id, keys_to_include=all_metrics)
    df = pd.DataFrame([flat_dict])
    
    available_metrics = []
    missing_metrics = []

    for metric in all_metrics:
        if metric in df.columns and not pd.isna(df.loc[0, metric]):
            available_metrics.append(metric)
        else:
            missing_metrics.append(metric)

    if missing_metrics:
        print(f"[INFO] {dataset_id}: Missing metrics: {missing_metrics}")
    
    valid_groups = {}
    for group_name, metric_list in metric_groups.items():
        valid_metrics_in_group = [m for m in metric_list if m in available_metrics]
        if len(valid_metrics_in_group) >= min_metrics_per_group:
            valid_groups[group_name] = valid_metrics_in_group
        else:
            print(f"[WARN] {dataset_id}: Group '{group_name}' has only {len(valid_metrics_in_group)} valid metrics")
    
    if len(valid_groups) < 3:
        print(f"[SKIP] {dataset_id}: Only {len(valid_groups)} valid groups, need at least 3")
        return None

    for metric in metrics_to_invert:
        if metric in available_metrics:
            df[metric] = -df[metric]

    # print(f"[INFO] {dataset_id}: Skipping normalization for single dataset")

    for group_name, metric_list in valid_groups.items():
        df[f"{group_name}_difficulty"] = df[metric_list].mean(axis=1)

    group_cols = [f"{g}_difficulty" for g in valid_groups.keys()]
    df["overall_difficulty"] = df[group_cols].mean(axis=1)
    df["metrics_used"] = len(available_metrics)
    df["groups_used"] = len(valid_groups)

    return df

def compute_all_composite_difficulties(root_dir: str, suffix: str = "_complexity_cuml.json", min_metrics_per_group=1) -> pd.DataFrame:
    """
    Loads all complexity metric JSONs from a folder and computes composite difficulty scores.
    More flexible version that handles missing metrics gracefully.
    """
    
    exclude_substrings = {
        "CICAPT_IIoT_Phase1_Macro_Multiclass",
        "CICAPT_IIoT_Phase1_Micro_Multiclass",
        # "ToN_IoT_IoT_Motion_Light_Multiclass"
    }
    
    all_json_paths = [
        path for path in Path(root_dir).rglob(f"*{suffix}")
        if not any(substr in path.stem for substr in exclude_substrings)
    ]

    rows = []

    print(f"Found {len(all_json_paths)} JSON files to process")

    for path in tqdm(all_json_paths, desc="Computing composite difficulties"):
        try:
            with open(path, 'r') as f:
                metrics_dict = json.load(f)

            # Remove metadata keys
            metrics_dict.pop('label_mappings', None)
            metrics_dict.pop('errors', None)

            filename = path.stem
            dataset_id = filename.replace("Output_Multiclass__100_pct__", "").replace("_complexity_cuml", "")

            composite_df = compute_composite_difficulty_from_dict(
                metrics_dict, dataset_id, min_metrics_per_group
            )
            # display(composite_df)
            
            if composite_df is not None:
                rows.append(composite_df)

        except Exception as e:
            print(f"[ERROR] Failed to process {path}: {e}")

    if not rows:
        print("No datasets could be processed")
        return pd.DataFrame()

    result_df = pd.concat(rows, ignore_index=True)
    # display(result_df)

    # Normalize across datasets
    print(f"\nNormalizing metrics across {len(result_df)} datasets...")

    # Determine metrics to normalize
    metric_cols = []
    for group_name, metric_list in metric_groups.items():
        metric_cols.extend(metric_list)

    available_metric_cols = [col for col in metric_cols if col in result_df.columns]

    # Fill NaNs before normalization if needed
    if result_df[available_metric_cols].isnull().values.any():
        print("[WARN] NaNs detected before normalization – filling with 0")
        result_df[available_metric_cols] = result_df[available_metric_cols].fillna(0)

    # Normalize
    if available_metric_cols:
        scaler = MinMaxScaler()
        result_df[available_metric_cols] = scaler.fit_transform(result_df[available_metric_cols])

    # Recompute group difficulties
    for group_name, metric_list in metric_groups.items():
        available_group_metrics = [m for m in metric_list if m in result_df.columns]
        if available_group_metrics:
            result_df[f"{group_name}_difficulty"] = result_df[available_group_metrics].mean(axis=1)

    # Recompute overall difficulty
    group_cols = [f"{group_name}_difficulty" for group_name in metric_groups.keys()
                  if f"{group_name}_difficulty" in result_df.columns]
    if group_cols:
        result_df["overall_difficulty"] = result_df[group_cols].mean(axis=1)

    print(f"Successfully processed {len(result_df)} datasets")
    print(f"Average metrics used per dataset: {result_df['metrics_used'].mean():.1f}")
    print(f"Average groups used per dataset: {result_df['groups_used'].mean():.1f}")

    return result_df

# %%
ROOT_DIR = "../../2025-07-05/cuml_v2-20250705T065915Z-1-001"

df_composite = compute_all_composite_difficulties(ROOT_DIR, min_metrics_per_group=1)

display(df_composite)
# Out:
# Found 73 JSON files to process
# Computing composite difficulties: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 73/73 [00:00<00:00, 238.88it/s]
# [INFO] ToN_IoT_IoT_Motion_Light_Multiclass: Missing metrics: ['intrinsic_dimensionality_intrinsic_dimensionality_percent', 'calinski_harabasz_calinski_harabasz_score']
# [WARN] ToN_IoT_IoT_Motion_Light_Multiclass: Group 'Global_Structure' has only 0 valid metrics
#
# Normalizing metrics across 73 datasets...
# [WARN] NaNs detected before normalization – filling with 0
# Successfully processed 73 datasets
# Average metrics used per dataset: 10.0
# Average groups used per dataset: 5.0
#                                            dataset_id  anova_f_mean  \
# 0          BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass      0.999925
# 1                N_BaIoT_Ecobee_Thermostat_Multiclass      0.986693
# 2                         NIDS_CIC-BoT-IoT_Multiclass      0.999401
# 3                CICIoMT2024_WiFi_and_MQTT_Multiclass      0.990342
# 4   N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Came...      0.997953
# 5                                UNSW_NB15_Multiclass      0.999396
# 6                       ToN_IoT_IoT_Fridge_Multiclass      1.000000
# 7                            BoT_IoT_Macro_Multiclass      0.999060
# 8            BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass      0.997722
# 9                  CICIoV2024_Binary_Macro_Multiclass      0.999999
# 10                      NIDS_NF-ToN-IoT-v2_Multiclass      0.999455
# 11  N_BaIoT_Provision_PT_737E_Security_Camera_Mult...      0.999091
# 12                CICEVSE2024_EVSE-B_Macro_Multiclass      0.997430
# 13                      NIDS_NF-UQ-NIDS-v2_Multiclass      0.999564
# 14                   ToN_IoT_Linux_Process_Multiclass      0.999999
# 15                CICAPT_IIoT_Phase2_Macro_Multiclass      1.000000
# 16             IoT_Network_Intrusion_Macro_Multiclass      0.999991
# 17         MQTT_IoT_IDS2020_PacketFeatures_Multiclass      0.999987
# 18                         NIDS_NF-UQ-NIDS_Multiclass      0.999901
# 19                      NIDS_NF-BoT-IoT-v2_Multiclass      0.999801
# 20                        NIDS_CIC-ToN-IoT_Multiclass      0.999743
# 21                N_BaIoT_Danmini_Doorbell_Multiclass      0.807956
# 22              BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass      0.999986
# 23    N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass      0.992685
# 24                  ToN_IoT_IoT_Thermostat_Multiclass      0.999986
# 25           BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass      0.999709
# 26                         ToN_IoT_Network_Multiclass      0.999695
# 27                 CICIoV2024_Binary_Micro_Multiclass      0.999999
# 28                CICEVSE2024_EVSE-B_Micro_Multiclass      0.990048
# 29             BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass      0.999880
# 30                    ToN_IoT_Linux_Memory_Multiclass      0.999992
# 31                CICEVSE2024_EVSE-A_Macro_Multiclass      0.994427
# 32                   CICIoMT2024_Bluetooth_Multiclass      1.000000
# 33                CICEVSE2024_EVSE-A_Micro_Multiclass      0.000000
# 34         MQTT_IoT_IDS2020_BiflowFeatures_Multiclass      0.967390
# 35          BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass      0.999927
# 36                    NIDS_NF-UNSW-NB15-v3_Multiclass      0.997127
# 37               EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass      0.958161
# 38                   NIDS_NF-CICIDS2018-v3_Multiclass      0.997950
# 39                     ToN_IoT_IoT_Weather_Multiclass      0.999984
# 40                           BoT_IoT_Micro_Multiclass      0.998319
# 41                      ToN_IoT_IoT_Modbus_Multiclass      1.000000
# 42                CICIoV2024_Decimal_Micro_Multiclass      0.999999
# 43                CICAPT_IIoT_Phase2_Micro_Multiclass      0.999999
# 44       N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass      0.991237
# 45     BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass      0.995763
# 46                CICIoV2024_Decimal_Macro_Multiclass      0.999999
# 47                       NIDS_NF-UNSW-NB15_Multiclass      0.999937
# 48                       ToN_IoT_Windows_7_Multiclass      0.999994
# 49                 ToN_IoT_IoT_Garage_Door_Multiclass      1.000000
# 50             IoT_Network_Intrusion_Micro_Multiclass      0.999995
# 51                    NIDS_NF-UNSW-NB15-v2_Multiclass      0.999966
# 52  N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Came...      0.980419
# 53                 ToN_IoT_IoT_GPS_Tracker_Multiclass      0.999998
# 54                ToN_IoT_IoT_Motion_Light_Multiclass      1.000000
# 55                            CIC_IDS_2017_Multiclass      0.999762
# 56                            KDD_Cup_1999_Multiclass      0.990049
# 57      BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass      0.991364
# 58                      ToN_IoT_Windows_10_Multiclass      0.999989
# 59                         NIDS_NF-BoT-IoT_Multiclass      0.999914
# 60                      ToN_IoT_Linux_Disk_Multiclass      0.999999
# 61  BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_a...      0.999223
# 62              NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass      0.994952
# 63                                  IoT_23_Multiclass      0.999792
# 64        MQTT_IoT_IDS2020_UniflowFeatures_Multiclass      0.999743
# 65                      NIDS_NF-ToN-IoT-v3_Multiclass      0.997994
# 66  N_BaIoT_Provision_PT_838_Security_Camera_Multi...      0.998810
# 67                 NIDS_NF-CSE-CIC-IDS2018_Multiclass      0.999154
# 68                         NIDS_NF-ToN-IoT_Multiclass      0.999649
# 69                  N_BaIoT_Ennio_Doorbell_Multiclass      0.994372
# 70                      NIDS_NF-BoT-IoT-v3_Multiclass      0.999269
# 71                     CIC_IOT_Dataset2023_Multiclass      0.995851
# 72                EDGE-IIOTSET_ML-EdgeIIoT_Multiclass      0.990526
#
#     mutual_info_mean  pca_centroid_distance_pca_centroid_score  \
# 0           0.743596                              1.929483e-01
# 1           0.112068                              2.999188e-01
# 2           0.928500                              3.691828e-01
# 3           0.280217                              1.468645e-01
# 4           0.015408                              2.077155e-01
# 5           0.936991                              6.551139e-02
# 6           1.000000                              1.513208e-11
# 7           0.908076                              1.865326e-01
# 8           0.900322                              9.828803e-01
# 9           0.991835                              4.213136e-02
# 10          0.752698                              9.641178e-02
# 11          0.138784                              1.941222e-01
# 12          0.332393                              2.808473e-01
# 13          0.672048                              1.452279e-01
# 14          0.907751                              1.678940e-02
# 15          0.999905                              2.895442e-02
# 16          0.957805                              4.064557e-02
# 17          0.310235                              2.555200e-02
# 18          0.649949                              6.769254e-02
# 19          0.653389                              8.521581e-02
# 20          0.482678                              1.425665e-01
# 21          0.029194                              3.668155e-01
# 22          0.983122                              9.554309e-02
# 23          0.056063                              1.914947e-01
# 24          0.883484                              5.796649e-03
# 25          0.907149                              8.406273e-02
# 26          0.835798                              3.659148e-02
# 27          0.982870                              5.301293e-02
# 28          0.119588                              2.322385e-01
# 29          0.672539                              1.681540e-01
# 30          0.929908                              3.366018e-02
# 31          0.346404                              1.000000e+00
# 32          0.871652                              2.295736e-03
# 33          0.164354                              8.110526e-01
# 34          0.321244                              7.833560e-02
# 35          0.813675                              5.126640e-02
# 36          0.865106                              5.627354e-02
# 37          0.710804                              2.460802e-01
# 38          0.826276                              5.106081e-01
# 39          0.933835                              2.805662e-02
# 40          0.468656                              2.051900e-01
# 41          0.996961                              2.022557e-03
# 42          0.918171                              2.246175e-02
# 43          0.999914                              4.105605e-02
# 44          0.213781                              2.816876e-01
# 45          0.787151                              2.272014e-01
# 46          0.958900                              2.583079e-02
# 47          0.888458                              6.299714e-02
# 48          0.705176                              2.344568e-01
# 49          0.874973                              1.496181e-03
# 50          0.952512                              4.898892e-02
# 51          0.717332                              6.211326e-02
# 52          0.112328                              3.058301e-01
# 53          0.000000                              3.826002e-04
# 54          1.000000                              0.000000e+00
# 55          0.820646                              2.242812e-01
# 56          0.735637                              1.072754e-01
# 57          0.228970                              6.704039e-02
# 58          0.612377                              1.811965e-01
# 59          0.847886                              5.727974e-02
# 60          0.881156                              1.202052e-02
# 61          0.541932                              1.115481e-01
# 62          0.590116                              3.188145e-01
# 63          0.814665                              2.374696e-01
# 64          0.411281                              5.566987e-02
# 65          0.738914                              1.091492e-01
# 66          0.134657                              1.956952e-01
# 67          0.667580                              1.313349e-01
# 68          0.835984                              2.337921e-02
# 69          0.350222                              6.364338e-01
# 70          0.839819                              3.287958e-01
# 71          0.267017                              1.279018e-01
# 72          0.579698                              9.395839e-02
#
#     mahalanobis_class_distance_mean  svm_margin_mean  \
# 0                          0.565707         0.782820
# 1                          0.375063         0.743313
# 2                          0.259836         0.961606
# 3                          0.474082         0.872058
# 4                          0.357016         0.751340
# 5                          0.305389         0.616350
# 6                          0.824563         0.805200
# 7                          0.576269         0.928730
# 8                          0.438227         0.665533
# 9                          0.000000         0.665714
# 10                         0.398432         0.893778
# 11                         0.328591         0.724311
# 12                         0.494558         0.673240
# 13                         0.433219         0.840179
# 14                         0.602827         0.977646
# 15                         0.321436         0.651597
# 16                         0.576206         0.798489
# 17                         0.704571         0.774005
# 18                         0.702590         0.868355
# 19                         0.456384         0.845033
# 20                         0.281561         0.773510
# 21                         0.405805         0.703093
# 22                         0.298424         0.000000
# 23                         0.387945         0.733115
# 24                         0.829815         0.895860
# 25                         0.317965         0.623079
# 26                         0.634821         0.899031
# 27                         0.008296         0.692914
# 28                         0.541133         0.762608
# 29                         0.231405         0.800357
# 30                         0.719500         0.848177
# 31                         0.684422         0.709683
# 32                         0.704624         0.929661
# 33                         0.722265         0.729495
# 34                         0.646521         0.658612
# 35                         0.357712         0.922194
# 36                         0.324564         0.539022
# 37                         0.524539         0.730767
# 38                         0.362893         0.736927
# 39                         0.784701         0.811934
# 40                         0.621375         0.913636
# 41                         0.738486         0.841114
# 42                         0.679055         0.726842
# 43                         0.321430         0.651339
# 44                         0.415438         0.713037
# 45                         0.503501         0.680949
# 46                         0.677100         0.711629
# 47                         0.665660         0.784512
# 48                         0.099033         0.639495
# 49                         0.875420         0.815708
# 50                         0.578248         0.803452
# 51                         0.347677         0.799868
# 52                         0.370677         0.754736
# 53                         0.863353         1.000000
# 54                         1.000000         0.795142
# 55                         0.178211         0.706356
# 56                         0.548558         0.693825
# 57                         0.423439         0.668791
# 58                         0.003074         0.543334
# 59                         0.710901         0.938285
# 60                         0.847659         0.921797
# 61                         0.416575         0.737709
# 62                         0.468243         0.743528
# 63                         0.733892         0.768897
# 64                         0.638872         0.631458
# 65                         0.396902         0.885338
# 66                         0.307224         0.696892
# 67                         0.702489         0.799632
# 68                         0.740245         0.960299
# 69                         0.365346         0.757459
# 70                         0.442515         0.881273
# 71                         0.391022         0.924679
# 72                         0.665909         0.820158
#
#     class_proba_entropy_mean  \
# 0                   0.139039
# 1                   0.050307
# 2                   0.402545
# 3                   0.205602
# 4                   0.085651
# 5                   0.030661
# 6                   0.935759
# 7                   0.282183
# 8                   0.013105
# 9                   0.010560
# 10                  0.317032
# 11                  0.093179
# 12                  0.106584
# 13                  0.218082
# 14                  0.667839
# 15                  0.000068
# 16                  0.177656
# 17                  0.194609
# 18                  0.390785
# 19                  0.232785
# 20                  0.131772
# 21                  0.029961
# 22                  0.003018
# 23                  0.048300
# 24                  0.645120
# 25                  0.053226
# 26                  0.394511
# 27                  0.019505
# 28                  0.149141
# 29                  0.173779
# 30                  0.370597
# 31                  0.098256
# 32                  0.307124
# 33                  0.095943
# 34                  0.006582
# 35                  0.506687
# 36                  0.044684
# 37                  0.104360
# 38                  0.015807
# 39                  0.305217
# 40                  0.255616
# 41                  0.345073
# 42                  0.037558
# 43                  0.000000
# 44                  0.128619
# 45                  0.012546
# 46                  0.017508
# 47                  0.177832
# 48                  0.031701
# 49                  0.997420
# 50                  0.180365
# 51                  0.238778
# 52                  0.046558
# 53                  0.738961
# 54                  1.000000
# 55                  0.011386
# 56                  0.008441
# 57                  0.042958
# 58                  0.039639
# 59                  0.457807
# 60                  0.562816
# 61                  0.058332
# 62                  0.027786
# 63                  0.102997
# 64                  0.008782
# 65                  0.236699
# 66                  0.078696
# 67                  0.130228
# 68                  0.515850
# 69                  0.114318
# 70                  0.223599
# 71                  0.420760
# 72                  0.338012
#
#     intrinsic_dimensionality_intrinsic_dimensionality_percent  \
# 0                                            0.260274
# 1                                            0.095652
# 2                                            0.139241
# 3                                            0.295455
# 4                                            0.113043
# 5                                            0.200000
# 6                                            1.000000
# 7                                            0.400000
# 8                                            0.188406
# 9                                            0.440000
# 10                                           0.500000
# 11                                           0.086957
# 12                                           0.073529
# 13                                           0.500000
# 14                                           0.333333
# 15                                           0.187500
# 16                                           0.208333
# 17                                           0.411765
# 18                                           0.500000
# 19                                           0.421053
# 20                                           0.140845
# 21                                           0.113043
# 22                                           0.250000
# 23                                           0.121739
# 24                                           0.500000
# 25                                           0.239437
# 26                                           0.225000
# 27                                           0.453333
# 28                                           0.073529
# 29                                           0.191781
# 30                                           0.777778
# 31                                           0.161765
# 32                                           0.428571
# 33                                           0.161765
# 34                                           0.142857
# 35                                           0.232877
# 36                                           0.239130
# 37                                           0.244444
# 38                                           0.311111
# 39                                           1.000000
# 40                                           0.400000
# 41                                           1.000000
# 42                                           0.375000
# 43                                           0.187500
# 44                                           0.147826
# 45                                           0.159420
# 46                                           0.375000
# 47                                           0.500000
# 48                                           0.259615
# 49                                           1.000000
# 50                                           0.208333
# 51                                           0.315789
# 52                                           0.130435
# 53                                           0.500000
# 54                                           0.000000
# 55                                           0.171429
# 56                                           0.200000
# 57                                           0.101449
# 58                                           0.309735
# 59                                           0.500000
# 60                                           0.600000
# 61                                           0.239437
# 62                                           0.432432
# 63                                           0.500000
# 64                                           0.250000
# 65                                           0.413043
# 66                                           0.086957
# 67                                           0.400000
# 68                                           0.500000
# 69                                           0.173913
# 70                                           0.347826
# 71                                           0.333333
# 72                                           0.219512
#
#     calinski_harabasz_calinski_harabasz_score  \
# 0                                    0.984747
# 1                                    0.819578
# 2                                    0.816073
# 3                                    0.000000
# 4                                    0.900813
# 5                                    0.950832
# 6                                    1.000000
# 7                                    0.826635
# 8                                    0.759662
# 9                                    0.999847
# 10                                   0.937623
# 11                                   0.916393
# 12                                   0.918689
# 13                                   0.932784
# 14                                   0.999011
# 15                                   0.999911
# 16                                   0.998048
# 17                                   0.996974
# 18                                   0.984076
# 19                                   0.972520
# 20                                   0.959879
# 21                                   0.841406
# 22                                   0.998288
# 23                                   0.825180
# 24                                   0.998688
# 25                                   0.950215
# 26                                   0.965055
# 27                                   0.999871
# 28                                   0.937954
# 29                                   0.959133
# 30                                   0.996914
# 31                                   0.880517
# 32                                   0.999951
# 33                                   0.873823
# 34                                   0.975986
# 35                                   0.990906
# 36                                   0.978206
# 37                                   0.553819
# 38                                   0.443007
# 39                                   0.994203
# 40                                   0.799045
# 41                                   0.999994
# 42                                   0.999887
# 43                                   0.999726
# 44                                   0.901297
# 45                                   0.743152
# 46                                   0.999844
# 47                                   0.989987
# 48                                   0.997636
# 49                                   0.999994
# 50                                   0.999078
# 51                                   0.994717
# 52                                   0.883783
# 53                                   0.999448
# 54                                   1.000000
# 55                                   0.947096
# 56                                   0.848160
# 57                                   0.146641
# 58                                   0.996436
# 59                                   0.983142
# 60                                   0.999559
# 61                                   0.924820
# 62                                   0.710491
# 63                                   0.994567
# 64                                   0.963923
# 65                                   0.804543
# 66                                   0.905092
# 67                                   0.847583
# 68                                   0.985645
# 69                                   0.970891
# 70                                   0.832330
# 71                                   0.267942
# 72                                   0.946010
#
#     class_confusion_entropy_confusion_entropy  \
# 0                                8.150677e-01
# 1                                2.742764e-01
# 2                                7.950975e-01
# 3                                4.873885e-01
# 4                                3.609745e-01
# 5                                1.000000e+00
# 6                                5.560120e-13
# 7                                5.760841e-01
# 8                                2.838177e-01
# 9                                2.081362e-01
# 10                               6.619750e-01
# 11                               3.453877e-01
# 12                               6.200894e-01
# 13                               7.189132e-01
# 14                               7.853457e-02
# 15                               4.541197e-12
# 16                               3.325125e-01
# 17                               4.483696e-01
# 18                               4.580051e-01
# 19                               5.012887e-01
# 20                               2.252810e-01
# 21                               2.274668e-01
# 22                               9.459749e-02
# 23                               3.242337e-01
# 24                               2.965131e-01
# 25                               6.561830e-01
# 26                               7.394962e-01
# 27                               3.379984e-01
# 28                               5.806224e-01
# 29                               8.410433e-01
# 30                               1.360585e-02
# 31                               4.949437e-01
# 32                               3.197315e-02
# 33                               3.390547e-01
# 34                               1.601864e-01
# 35                               6.163875e-01
# 36                               5.848301e-01
# 37                               6.267159e-01
# 38                               2.462341e-01
# 39                               0.000000e+00
# 40                               6.396668e-01
# 41                               8.246492e-14
# 42                               7.396813e-02
# 43                               2.067077e-07
# 44                               3.486031e-01
# 45                               3.279459e-01
# 46                               1.472635e-01
# 47                               3.928593e-01
# 48                               1.664431e-01
# 49                               5.583314e-01
# 50                               1.982160e-01
# 51                               9.671470e-01
# 52                               2.888909e-01
# 53                               3.087901e-12
# 54                               8.983667e-12
# 55                               3.273388e-01
# 56                               3.947905e-01
# 57                               5.046617e-01
# 58                               1.375493e-01
# 59                               6.169412e-01
# 60                               1.500599e-03
# 61                               5.316593e-01
# 62                               2.008342e-01
# 63                               5.581450e-01
# 64                               2.923525e-01
# 65                               6.155635e-01
# 66                               3.337247e-01
# 67                               4.457207e-02
# 68                               3.686426e-01
# 69                               2.970586e-01
# 70                               4.253642e-01
# 71                               7.607051e-01
# 72                               6.185179e-01
#
#     class_imbalance_normalized_entropy  Feature_Relevance_difficulty  \
# 0                             0.432349                      0.871760
# 1                             0.208510                      0.549380
# 2                             0.311668                      0.963950
# 3                             0.213296                      0.635280
# 4                             0.192608                      0.506680
# 5                             0.889582                      0.968193
# 6                             0.000000                      1.000000
# 7                             0.474378                      0.953568
# 8                             0.467635                      0.949022
# 9                             0.936382                      0.995917
# 10                            0.258459                      0.876077
# 11                            0.168332                      0.568938
# 12                            0.544064                      0.664911
# 13                            0.475056                      0.835806
# 14                            0.277530                      0.953875
# 15                            1.000000                      0.999953
# 16                            0.705845                      0.978898
# 17                            0.154541                      0.655111
# 18                            0.517833                      0.824925
# 19                            0.181791                      0.826595
# 20                            0.540865                      0.741210
# 21                            0.201465                      0.418575
# 22                            0.901109                      0.991554
# 23                            0.189020                      0.524374
# 24                            0.262383                      0.941735
# 25                            0.668563                      0.953429
# 26                            0.345932                      0.917747
# 27                            0.928776                      0.991435
# 28                            0.403747                      0.554818
# 29                            0.457552                      0.836210
# 30                            0.540543                      0.964950
# 31                            0.299998                      0.670415
# 32                            0.056150                      0.935826
# 33                            0.254796                      0.082177
# 34                            0.308877                      0.644317
# 35                            0.239575                      0.906801
# 36                            0.828733                      0.931117
# 37                            0.546467                      0.834482
# 38                            0.825312                      0.912113
# 39                            0.686868                      0.966909
# 40                            0.322395                      0.733488
# 41                            0.599361                      0.998480
# 42                            0.928624                      0.959085
# 43                            0.999826                      0.999957
# 44                            0.251408                      0.602509
# 45                            0.752633                      0.891457
# 46                            0.938879                      0.979449
# 47                            0.758292                      0.944197
# 48                            0.602156                      0.852585
# 49                            0.000000                      0.937486
# 50                            0.795218                      0.976253
# 51                            0.554126                      0.858649
# 52                            0.201339                      0.546373
# 53                            0.260945                      0.499999
# 54                            0.000000                      1.000000
# 55                            0.816046                      0.910204
# 56                            0.790225                      0.862843
# 57                            0.441694                      0.610167
# 58                            0.490955                      0.806183
# 59                            0.234257                      0.923900
# 60                            0.396364                      0.940577
# 61                            0.358126                      0.770578
# 62                            0.665741                      0.792534
# 63                            0.764568                      0.907228
# 64                            0.390436                      0.705512
# 65                            0.303024                      0.868454
# 66                            0.178954                      0.566733
# 67                            0.727386                      0.833367
# 68                            0.363439                      0.917816
# 69                            0.240061                      0.672297
# 70                            0.430605                      0.919544
# 71                            0.143655                      0.631434
# 72                            0.058832                      0.785112
#
#     Local_Overlap_difficulty  Boundary_Hardness_difficulty  \
# 0                   0.379328                      0.460930
# 1                   0.337491                      0.396810
# 2                   0.314509                      0.682075
# 3                   0.310473                      0.538830
# 4                   0.282366                      0.418496
# 5                   0.185450                      0.323505
# 6                   0.412282                      0.870480
# 7                   0.381401                      0.605456
# 8                   0.710554                      0.339319
# 9                   0.021066                      0.338137
# 10                  0.247422                      0.605405
# 11                  0.261356                      0.408745
# 12                  0.387703                      0.389912
# 13                  0.289223                      0.529130
# 14                  0.309808                      0.822743
# 15                  0.175195                      0.325833
# 16                  0.308426                      0.488073
# 17                  0.365062                      0.484307
# 18                  0.385141                      0.629570
# 19                  0.270800                      0.538909
# 20                  0.212064                      0.452641
# 21                  0.386310                      0.366527
# 22                  0.196983                      0.001509
# 23                  0.289720                      0.390707
# 24                  0.417806                      0.770490
# 25                  0.201014                      0.338153
# 26                  0.335706                      0.646771
# 27                  0.030655                      0.356210
# 28                  0.386686                      0.455875
# 29                  0.199779                      0.487068
# 30                  0.376580                      0.609387
# 31                  0.842211                      0.403969
# 32                  0.353460                      0.618393
# 33                  0.766659                      0.412719
# 34                  0.362428                      0.332597
# 35                  0.204489                      0.714440
# 36                  0.190419                      0.291853
# 37                  0.385310                      0.417564
# 38                  0.436750                      0.376367
# 39                  0.406379                      0.558575
# 40                  0.413282                      0.584626
# 41                  0.370254                      0.593093
# 42                  0.350758                      0.382200
# 43                  0.181243                      0.325669
# 44                  0.348563                      0.420828
# 45                  0.365351                      0.346748
# 46                  0.351465                      0.364568
# 47                  0.364329                      0.481172
# 48                  0.166745                      0.335598
# 49                  0.438458                      0.906564
# 50                  0.313619                      0.491909
# 51                  0.204895                      0.519323
# 52                  0.338254                      0.400647
# 53                  0.431868                      0.869480
# 54                  0.500000                      0.897571
# 55                  0.201246                      0.358871
# 56                  0.327917                      0.351133
# 57                  0.245240                      0.355874
# 58                  0.092135                      0.291486
# 59                  0.384090                      0.698046
# 60                  0.429840                      0.742307
# 61                  0.264061                      0.398020
# 62                  0.393529                      0.385657
# 63                  0.485681                      0.435947
# 64                  0.347271                      0.320120
# 65                  0.253026                      0.561018
# 66                  0.251460                      0.387794
# 67                  0.416912                      0.464930
# 68                  0.381812                      0.738075
# 69                  0.500890                      0.435888
# 70                  0.385656                      0.552436
# 71                  0.259462                      0.672720
# 72                  0.379934                      0.579085
#
#     Global_Structure_difficulty  Class_Distribution_Separation_difficulty  \
# 0                      0.622510                              6.237083e-01
# 1                      0.457615                              2.413933e-01
# 2                      0.477657                              5.533826e-01
# 3                      0.147727                              3.503420e-01
# 4                      0.506928                              2.767913e-01
# 5                      0.575416                              9.447912e-01
# 6                      1.000000                              2.780060e-13
# 7                      0.613318                              5.252310e-01
# 8                      0.474034                              3.757263e-01
# 9                      0.719924                              5.722590e-01
# 10                     0.718812                              4.602170e-01
# 11                     0.501675                              2.568599e-01
# 12                     0.496109                              5.820766e-01
# 13                     0.716392                              5.969848e-01
# 14                     0.666172                              1.780324e-01
# 15                     0.593706                              5.000000e-01
# 16                     0.603191                              5.191785e-01
# 17                     0.704369                              3.014553e-01
# 18                     0.742038                              4.879188e-01
# 19                     0.696786                              3.415399e-01
# 20                     0.550362                              3.830728e-01
# 21                     0.477225                              2.144657e-01
# 22                     0.624144                              4.978531e-01
# 23                     0.473460                              2.566270e-01
# 24                     0.749344                              2.794482e-01
# 25                     0.594826                              6.623728e-01
# 26                     0.595027                              5.427143e-01
# 27                     0.726602                              6.333871e-01
# 28                     0.505742                              4.921849e-01
# 29                     0.575457                              6.492975e-01
# 30                     0.887346                              2.770744e-01
# 31                     0.521141                              3.974707e-01
# 32                     0.714261                              4.406146e-02
# 33                     0.517794                              2.969256e-01
# 34                     0.559422                              2.345317e-01
# 35                     0.611892                              4.279812e-01
# 36                     0.608668                              7.067816e-01
# 37                     0.399132                              5.865915e-01
# 38                     0.377059                              5.357732e-01
# 39                     0.997102                              3.434340e-01
# 40                     0.599523                              4.810310e-01
# 41                     0.999997                              2.996803e-01
# 42                     0.687443                              5.012959e-01
# 43                     0.593613                              4.999131e-01
# 44                     0.524561                              3.000056e-01
# 45                     0.451286                              5.402897e-01
# 46                     0.687422                              5.430710e-01
# 47                     0.744993                              5.755755e-01
# 48                     0.628626                              3.842997e-01
# 49                     0.999997                              2.791657e-01
# 50                     0.603706                              4.967170e-01
# 51                     0.655253                              7.606363e-01
# 52                     0.507109                              2.451150e-01
# 53                     0.749724                              1.304726e-01
# 54                     0.500000                              4.491833e-12
# 55                     0.559262                              5.716924e-01
# 56                     0.524080                              5.925079e-01
# 57                     0.124045                              4.731778e-01
# 58                     0.653085                              3.142523e-01
# 59                     0.741571                              4.255993e-01
# 60                     0.799780                              1.989322e-01
# 61                     0.582128                              4.448928e-01
# 62                     0.571462                              4.332875e-01
# 63                     0.747283                              6.613566e-01
# 64                     0.606962                              3.413942e-01
# 65                     0.608793                              4.592937e-01
# 66                     0.496024                              2.563391e-01
# 67                     0.623791                              3.859791e-01
# 68                     0.742822                              3.660410e-01
# 69                     0.572402                              2.685597e-01
# 70                     0.590078                              4.279846e-01
# 71                     0.300638                              4.521801e-01
# 72                     0.582761                              3.386748e-01
#
#     overall_difficulty  metrics_used  groups_used
# 0             0.591647            10            5
# 1             0.396538            10            5
# 2             0.598315            10            5
# 3             0.396530            10            5
# 4             0.398252            10            5
# 5             0.599471            10            5
# 6             0.656552            10            5
# 7             0.615795            10            5
# 8             0.569731            10            5
# 9             0.529460            10            5
# 10            0.581586            10            5
# 11            0.399515            10            5
# 12            0.504142            10            5
# 13            0.593507            10            5
# 14            0.586126            10            5
# 15            0.518937            10            5
# 16            0.579553            10            5
# 17            0.502061            10            5
# 18            0.613918            10            5
# 19            0.534926            10            5
# 20            0.467870            10            5
# 21            0.372621            10            5
# 22            0.462409            10            5
# 23            0.386978            10            5
# 24            0.631765            10            5
# 25            0.549959            10            5
# 26            0.607593            10            5
# 27            0.547658            10            5
# 28            0.479061            10            5
# 29            0.549562            10            5
# 30            0.623067            10            5
# 31            0.567041            10            5
# 32            0.533200            10            5
# 33            0.415255            10            5
# 34            0.426659            10            5
# 35            0.573121            10            5
# 36            0.545768            10            5
# 37            0.524616            10            5
# 38            0.527612            10            5
# 39            0.654480            10            5
# 40            0.562390            10            5
# 41            0.652301            10            5
# 42            0.576157            10            5
# 43            0.520079            10            5
# 44            0.439293            10            5
# 45            0.519026            10            5
# 46            0.585195            10            5
# 47            0.622053            10            5
# 48            0.473571            10            5
# 49            0.712334            10            5
# 50            0.576441            10            5
# 51            0.599751            10            5
# 52            0.407500            10            5
# 53            0.536309            10            5
# 54            0.579514             8            4
# 55            0.520255            10            5
# 56            0.531696            10            5
# 57            0.361701            10            5
# 58            0.431428            10            5
# 59            0.634641            10            5
# 60            0.622287            10            5
# 61            0.491936            10            5
# 62            0.515294            10            5
# 63            0.647499            10            5
# 64            0.464252            10            5
# 65            0.550117            10            5
# 66            0.391670            10            5
# 67            0.544996            10            5
# 68            0.629313            10            5
# 69            0.490007            10            5
# 70            0.575140            10            5
# 71            0.463287            10            5
# 72            0.533113            10            5

# %%
# Set index to dataset_id
df_composite_indexed = df_composite.set_index('dataset_id')

# Filter row_order to only include datasets that exist in the DataFrame
valid_order = [d for d in row_order if d in df_composite_indexed.index]

# Reorder using the filtered list
df_ordered = df_composite_indexed.loc[valid_order]

# Export to LaTeX with thousands separator
df_ordered.style.format(thousands=",").to_latex("tables/complexity_metrics.tex")

df_ordered.to_excel('tables/complexity_metrics.xlsx')
df_ordered.to_json('tables/complexity_metrics.json', orient='index')

# %%
df_ordered
# Out:
#                                                     anova_f_mean  \
# dataset_id
# CIC_IDS_2017_Multiclass                                 0.999762
# CIC_IOT_Dataset2023_Multiclass                          0.995851
# IoT_23_Multiclass                                       0.999792
# IoT_Network_Intrusion_Macro_Multiclass                  0.999991
# IoT_Network_Intrusion_Micro_Multiclass                  0.999995
# KDD_Cup_1999_Multiclass                                 0.990049
# UNSW_NB15_Multiclass                                    0.999396
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass               0.999927
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass          0.995763
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                  0.999880
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                   0.999986
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...      0.999223
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass              0.999925
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass           0.991364
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                0.999709
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                0.997722
# BoT_IoT_Macro_Multiclass                                0.999060
# BoT_IoT_Micro_Multiclass                                0.998319
# CICAPT_IIoT_Phase2_Macro_Multiclass                     1.000000
# CICAPT_IIoT_Phase2_Micro_Multiclass                     0.999999
# CICEVSE2024_EVSE-A_Macro_Multiclass                     0.994427
# CICEVSE2024_EVSE-A_Micro_Multiclass                     0.000000
# CICEVSE2024_EVSE-B_Macro_Multiclass                     0.997430
# CICEVSE2024_EVSE-B_Micro_Multiclass                     0.990048
# CICIoMT2024_Bluetooth_Multiclass                        1.000000
# CICIoMT2024_WiFi_and_MQTT_Multiclass                    0.990342
# CICIoV2024_Decimal_Macro_Multiclass                     0.999999
# CICIoV2024_Decimal_Micro_Multiclass                     0.999999
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                    0.958161
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                     0.990526
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass              0.967390
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass              0.999987
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass             0.999743
# NIDS_CIC-BoT-IoT_Multiclass                             0.999401
# NIDS_CIC-ToN-IoT_Multiclass                             0.999743
# NIDS_NF-BoT-IoT_Multiclass                              0.999914
# NIDS_NF-BoT-IoT-v2_Multiclass                           0.999801
# NIDS_NF-BoT-IoT-v3_Multiclass                           0.999269
# NIDS_NF-CICIDS2018-v3_Multiclass                        0.997950
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                      0.999154
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                   0.994952
# NIDS_NF-ToN-IoT_Multiclass                              0.999649
# NIDS_NF-ToN-IoT-v2_Multiclass                           0.999455
# NIDS_NF-ToN-IoT-v3_Multiclass                           0.997994
# NIDS_NF-UNSW-NB15_Multiclass                            0.999937
# NIDS_NF-UNSW-NB15-v2_Multiclass                         0.999966
# NIDS_NF-UNSW-NB15-v3_Multiclass                         0.997127
# NIDS_NF-UQ-NIDS_Multiclass                              0.999901
# NIDS_NF-UQ-NIDS-v2_Multiclass                           0.999564
# N_BaIoT_Danmini_Doorbell_Multiclass                     0.807956
# N_BaIoT_Ecobee_Thermostat_Multiclass                    0.986693
# N_BaIoT_Ennio_Doorbell_Multiclass                       0.994372
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass         0.992685
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...      0.999091
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...      0.998810
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass            0.991237
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...      0.997953
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...      0.980419
# ToN_IoT_IoT_Fridge_Multiclass                           1.000000
# ToN_IoT_IoT_GPS_Tracker_Multiclass                      0.999998
# ToN_IoT_IoT_Garage_Door_Multiclass                      1.000000
# ToN_IoT_IoT_Modbus_Multiclass                           1.000000
# ToN_IoT_IoT_Motion_Light_Multiclass                     1.000000
# ToN_IoT_IoT_Thermostat_Multiclass                       0.999986
# ToN_IoT_IoT_Weather_Multiclass                          0.999984
# ToN_IoT_Linux_Disk_Multiclass                           0.999999
# ToN_IoT_Linux_Memory_Multiclass                         0.999992
# ToN_IoT_Linux_Process_Multiclass                        0.999999
# ToN_IoT_Network_Multiclass                              0.999695
# ToN_IoT_Windows_10_Multiclass                           0.999989
# ToN_IoT_Windows_7_Multiclass                            0.999994
#
#                                                     mutual_info_mean  \
# dataset_id
# CIC_IDS_2017_Multiclass                                     0.820646
# CIC_IOT_Dataset2023_Multiclass                              0.267017
# IoT_23_Multiclass                                           0.814665
# IoT_Network_Intrusion_Macro_Multiclass                      0.957805
# IoT_Network_Intrusion_Micro_Multiclass                      0.952512
# KDD_Cup_1999_Multiclass                                     0.735637
# UNSW_NB15_Multiclass                                        0.936991
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                   0.813675
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass              0.787151
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                      0.672539
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                       0.983122
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...          0.541932
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                  0.743596
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass               0.228970
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                    0.907149
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                    0.900322
# BoT_IoT_Macro_Multiclass                                    0.908076
# BoT_IoT_Micro_Multiclass                                    0.468656
# CICAPT_IIoT_Phase2_Macro_Multiclass                         0.999905
# CICAPT_IIoT_Phase2_Micro_Multiclass                         0.999914
# CICEVSE2024_EVSE-A_Macro_Multiclass                         0.346404
# CICEVSE2024_EVSE-A_Micro_Multiclass                         0.164354
# CICEVSE2024_EVSE-B_Macro_Multiclass                         0.332393
# CICEVSE2024_EVSE-B_Micro_Multiclass                         0.119588
# CICIoMT2024_Bluetooth_Multiclass                            0.871652
# CICIoMT2024_WiFi_and_MQTT_Multiclass                        0.280217
# CICIoV2024_Decimal_Macro_Multiclass                         0.958900
# CICIoV2024_Decimal_Micro_Multiclass                         0.918171
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                        0.710804
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                         0.579698
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                  0.321244
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                  0.310235
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                 0.411281
# NIDS_CIC-BoT-IoT_Multiclass                                 0.928500
# NIDS_CIC-ToN-IoT_Multiclass                                 0.482678
# NIDS_NF-BoT-IoT_Multiclass                                  0.847886
# NIDS_NF-BoT-IoT-v2_Multiclass                               0.653389
# NIDS_NF-BoT-IoT-v3_Multiclass                               0.839819
# NIDS_NF-CICIDS2018-v3_Multiclass                            0.826276
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                          0.667580
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                       0.590116
# NIDS_NF-ToN-IoT_Multiclass                                  0.835984
# NIDS_NF-ToN-IoT-v2_Multiclass                               0.752698
# NIDS_NF-ToN-IoT-v3_Multiclass                               0.738914
# NIDS_NF-UNSW-NB15_Multiclass                                0.888458
# NIDS_NF-UNSW-NB15-v2_Multiclass                             0.717332
# NIDS_NF-UNSW-NB15-v3_Multiclass                             0.865106
# NIDS_NF-UQ-NIDS_Multiclass                                  0.649949
# NIDS_NF-UQ-NIDS-v2_Multiclass                               0.672048
# N_BaIoT_Danmini_Doorbell_Multiclass                         0.029194
# N_BaIoT_Ecobee_Thermostat_Multiclass                        0.112068
# N_BaIoT_Ennio_Doorbell_Multiclass                           0.350222
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass             0.056063
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...          0.138784
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...          0.134657
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                0.213781
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...          0.015408
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...          0.112328
# ToN_IoT_IoT_Fridge_Multiclass                               1.000000
# ToN_IoT_IoT_GPS_Tracker_Multiclass                          0.000000
# ToN_IoT_IoT_Garage_Door_Multiclass                          0.874973
# ToN_IoT_IoT_Modbus_Multiclass                               0.996961
# ToN_IoT_IoT_Motion_Light_Multiclass                         1.000000
# ToN_IoT_IoT_Thermostat_Multiclass                           0.883484
# ToN_IoT_IoT_Weather_Multiclass                              0.933835
# ToN_IoT_Linux_Disk_Multiclass                               0.881156
# ToN_IoT_Linux_Memory_Multiclass                             0.929908
# ToN_IoT_Linux_Process_Multiclass                            0.907751
# ToN_IoT_Network_Multiclass                                  0.835798
# ToN_IoT_Windows_10_Multiclass                               0.612377
# ToN_IoT_Windows_7_Multiclass                                0.705176
#
#                                                     pca_centroid_distance_pca_centroid_score  \
# dataset_id
# CIC_IDS_2017_Multiclass                                                         2.242812e-01
# CIC_IOT_Dataset2023_Multiclass                                                  1.279018e-01
# IoT_23_Multiclass                                                               2.374696e-01
# IoT_Network_Intrusion_Macro_Multiclass                                          4.064557e-02
# IoT_Network_Intrusion_Micro_Multiclass                                          4.898892e-02
# KDD_Cup_1999_Multiclass                                                         1.072754e-01
# UNSW_NB15_Multiclass                                                            6.551139e-02
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                                       5.126640e-02
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                                  2.272014e-01
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                          1.681540e-01
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                                           9.554309e-02
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                              1.115481e-01
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                                      1.929483e-01
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                                   6.704039e-02
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                                        8.406273e-02
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                                        9.828803e-01
# BoT_IoT_Macro_Multiclass                                                        1.865326e-01
# BoT_IoT_Micro_Multiclass                                                        2.051900e-01
# CICAPT_IIoT_Phase2_Macro_Multiclass                                             2.895442e-02
# CICAPT_IIoT_Phase2_Micro_Multiclass                                             4.105605e-02
# CICEVSE2024_EVSE-A_Macro_Multiclass                                             1.000000e+00
# CICEVSE2024_EVSE-A_Micro_Multiclass                                             8.110526e-01
# CICEVSE2024_EVSE-B_Macro_Multiclass                                             2.808473e-01
# CICEVSE2024_EVSE-B_Micro_Multiclass                                             2.322385e-01
# CICIoMT2024_Bluetooth_Multiclass                                                2.295736e-03
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                            1.468645e-01
# CICIoV2024_Decimal_Macro_Multiclass                                             2.583079e-02
# CICIoV2024_Decimal_Micro_Multiclass                                             2.246175e-02
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                            2.460802e-01
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                             9.395839e-02
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                                      7.833560e-02
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                                      2.555200e-02
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                                     5.566987e-02
# NIDS_CIC-BoT-IoT_Multiclass                                                     3.691828e-01
# NIDS_CIC-ToN-IoT_Multiclass                                                     1.425665e-01
# NIDS_NF-BoT-IoT_Multiclass                                                      5.727974e-02
# NIDS_NF-BoT-IoT-v2_Multiclass                                                   8.521581e-02
# NIDS_NF-BoT-IoT-v3_Multiclass                                                   3.287958e-01
# NIDS_NF-CICIDS2018-v3_Multiclass                                                5.106081e-01
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                              1.313349e-01
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                           3.188145e-01
# NIDS_NF-ToN-IoT_Multiclass                                                      2.337921e-02
# NIDS_NF-ToN-IoT-v2_Multiclass                                                   9.641178e-02
# NIDS_NF-ToN-IoT-v3_Multiclass                                                   1.091492e-01
# NIDS_NF-UNSW-NB15_Multiclass                                                    6.299714e-02
# NIDS_NF-UNSW-NB15-v2_Multiclass                                                 6.211326e-02
# NIDS_NF-UNSW-NB15-v3_Multiclass                                                 5.627354e-02
# NIDS_NF-UQ-NIDS_Multiclass                                                      6.769254e-02
# NIDS_NF-UQ-NIDS-v2_Multiclass                                                   1.452279e-01
# N_BaIoT_Danmini_Doorbell_Multiclass                                             3.668155e-01
# N_BaIoT_Ecobee_Thermostat_Multiclass                                            2.999188e-01
# N_BaIoT_Ennio_Doorbell_Multiclass                                               6.364338e-01
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                                 1.914947e-01
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                              1.941222e-01
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                              1.956952e-01
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                                    2.816876e-01
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                              2.077155e-01
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                              3.058301e-01
# ToN_IoT_IoT_Fridge_Multiclass                                                   1.513208e-11
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                              3.826002e-04
# ToN_IoT_IoT_Garage_Door_Multiclass                                              1.496181e-03
# ToN_IoT_IoT_Modbus_Multiclass                                                   2.022557e-03
# ToN_IoT_IoT_Motion_Light_Multiclass                                             0.000000e+00
# ToN_IoT_IoT_Thermostat_Multiclass                                               5.796649e-03
# ToN_IoT_IoT_Weather_Multiclass                                                  2.805662e-02
# ToN_IoT_Linux_Disk_Multiclass                                                   1.202052e-02
# ToN_IoT_Linux_Memory_Multiclass                                                 3.366018e-02
# ToN_IoT_Linux_Process_Multiclass                                                1.678940e-02
# ToN_IoT_Network_Multiclass                                                      3.659148e-02
# ToN_IoT_Windows_10_Multiclass                                                   1.811965e-01
# ToN_IoT_Windows_7_Multiclass                                                    2.344568e-01
#
#                                                     mahalanobis_class_distance_mean  \
# dataset_id
# CIC_IDS_2017_Multiclass                                                    0.178211
# CIC_IOT_Dataset2023_Multiclass                                             0.391022
# IoT_23_Multiclass                                                          0.733892
# IoT_Network_Intrusion_Macro_Multiclass                                     0.576206
# IoT_Network_Intrusion_Micro_Multiclass                                     0.578248
# KDD_Cup_1999_Multiclass                                                    0.548558
# UNSW_NB15_Multiclass                                                       0.305389
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                                  0.357712
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                             0.503501
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                     0.231405
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                                      0.298424
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                         0.416575
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                                 0.565707
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                              0.423439
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                                   0.317965
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                                   0.438227
# BoT_IoT_Macro_Multiclass                                                   0.576269
# BoT_IoT_Micro_Multiclass                                                   0.621375
# CICAPT_IIoT_Phase2_Macro_Multiclass                                        0.321436
# CICAPT_IIoT_Phase2_Micro_Multiclass                                        0.321430
# CICEVSE2024_EVSE-A_Macro_Multiclass                                        0.684422
# CICEVSE2024_EVSE-A_Micro_Multiclass                                        0.722265
# CICEVSE2024_EVSE-B_Macro_Multiclass                                        0.494558
# CICEVSE2024_EVSE-B_Micro_Multiclass                                        0.541133
# CICIoMT2024_Bluetooth_Multiclass                                           0.704624
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                       0.474082
# CICIoV2024_Decimal_Macro_Multiclass                                        0.677100
# CICIoV2024_Decimal_Micro_Multiclass                                        0.679055
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                       0.524539
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                        0.665909
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                                 0.646521
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                                 0.704571
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                                0.638872
# NIDS_CIC-BoT-IoT_Multiclass                                                0.259836
# NIDS_CIC-ToN-IoT_Multiclass                                                0.281561
# NIDS_NF-BoT-IoT_Multiclass                                                 0.710901
# NIDS_NF-BoT-IoT-v2_Multiclass                                              0.456384
# NIDS_NF-BoT-IoT-v3_Multiclass                                              0.442515
# NIDS_NF-CICIDS2018-v3_Multiclass                                           0.362893
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                         0.702489
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                      0.468243
# NIDS_NF-ToN-IoT_Multiclass                                                 0.740245
# NIDS_NF-ToN-IoT-v2_Multiclass                                              0.398432
# NIDS_NF-ToN-IoT-v3_Multiclass                                              0.396902
# NIDS_NF-UNSW-NB15_Multiclass                                               0.665660
# NIDS_NF-UNSW-NB15-v2_Multiclass                                            0.347677
# NIDS_NF-UNSW-NB15-v3_Multiclass                                            0.324564
# NIDS_NF-UQ-NIDS_Multiclass                                                 0.702590
# NIDS_NF-UQ-NIDS-v2_Multiclass                                              0.433219
# N_BaIoT_Danmini_Doorbell_Multiclass                                        0.405805
# N_BaIoT_Ecobee_Thermostat_Multiclass                                       0.375063
# N_BaIoT_Ennio_Doorbell_Multiclass                                          0.365346
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                            0.387945
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                         0.328591
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                         0.307224
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                               0.415438
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                         0.357016
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                         0.370677
# ToN_IoT_IoT_Fridge_Multiclass                                              0.824563
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                         0.863353
# ToN_IoT_IoT_Garage_Door_Multiclass                                         0.875420
# ToN_IoT_IoT_Modbus_Multiclass                                              0.738486
# ToN_IoT_IoT_Motion_Light_Multiclass                                        1.000000
# ToN_IoT_IoT_Thermostat_Multiclass                                          0.829815
# ToN_IoT_IoT_Weather_Multiclass                                             0.784701
# ToN_IoT_Linux_Disk_Multiclass                                              0.847659
# ToN_IoT_Linux_Memory_Multiclass                                            0.719500
# ToN_IoT_Linux_Process_Multiclass                                           0.602827
# ToN_IoT_Network_Multiclass                                                 0.634821
# ToN_IoT_Windows_10_Multiclass                                              0.003074
# ToN_IoT_Windows_7_Multiclass                                               0.099033
#
#                                                     svm_margin_mean  \
# dataset_id
# CIC_IDS_2017_Multiclass                                    0.706356
# CIC_IOT_Dataset2023_Multiclass                             0.924679
# IoT_23_Multiclass                                          0.768897
# IoT_Network_Intrusion_Macro_Multiclass                     0.798489
# IoT_Network_Intrusion_Micro_Multiclass                     0.803452
# KDD_Cup_1999_Multiclass                                    0.693825
# UNSW_NB15_Multiclass                                       0.616350
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                  0.922194
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass             0.680949
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                     0.800357
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                      0.000000
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...         0.737709
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                 0.782820
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass              0.668791
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                   0.623079
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                   0.665533
# BoT_IoT_Macro_Multiclass                                   0.928730
# BoT_IoT_Micro_Multiclass                                   0.913636
# CICAPT_IIoT_Phase2_Macro_Multiclass                        0.651597
# CICAPT_IIoT_Phase2_Micro_Multiclass                        0.651339
# CICEVSE2024_EVSE-A_Macro_Multiclass                        0.709683
# CICEVSE2024_EVSE-A_Micro_Multiclass                        0.729495
# CICEVSE2024_EVSE-B_Macro_Multiclass                        0.673240
# CICEVSE2024_EVSE-B_Micro_Multiclass                        0.762608
# CICIoMT2024_Bluetooth_Multiclass                           0.929661
# CICIoMT2024_WiFi_and_MQTT_Multiclass                       0.872058
# CICIoV2024_Decimal_Macro_Multiclass                        0.711629
# CICIoV2024_Decimal_Micro_Multiclass                        0.726842
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                       0.730767
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                        0.820158
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                 0.658612
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                 0.774005
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                0.631458
# NIDS_CIC-BoT-IoT_Multiclass                                0.961606
# NIDS_CIC-ToN-IoT_Multiclass                                0.773510
# NIDS_NF-BoT-IoT_Multiclass                                 0.938285
# NIDS_NF-BoT-IoT-v2_Multiclass                              0.845033
# NIDS_NF-BoT-IoT-v3_Multiclass                              0.881273
# NIDS_NF-CICIDS2018-v3_Multiclass                           0.736927
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                         0.799632
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                      0.743528
# NIDS_NF-ToN-IoT_Multiclass                                 0.960299
# NIDS_NF-ToN-IoT-v2_Multiclass                              0.893778
# NIDS_NF-ToN-IoT-v3_Multiclass                              0.885338
# NIDS_NF-UNSW-NB15_Multiclass                               0.784512
# NIDS_NF-UNSW-NB15-v2_Multiclass                            0.799868
# NIDS_NF-UNSW-NB15-v3_Multiclass                            0.539022
# NIDS_NF-UQ-NIDS_Multiclass                                 0.868355
# NIDS_NF-UQ-NIDS-v2_Multiclass                              0.840179
# N_BaIoT_Danmini_Doorbell_Multiclass                        0.703093
# N_BaIoT_Ecobee_Thermostat_Multiclass                       0.743313
# N_BaIoT_Ennio_Doorbell_Multiclass                          0.757459
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass            0.733115
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...         0.724311
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...         0.696892
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass               0.713037
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...         0.751340
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...         0.754736
# ToN_IoT_IoT_Fridge_Multiclass                              0.805200
# ToN_IoT_IoT_GPS_Tracker_Multiclass                         1.000000
# ToN_IoT_IoT_Garage_Door_Multiclass                         0.815708
# ToN_IoT_IoT_Modbus_Multiclass                              0.841114
# ToN_IoT_IoT_Motion_Light_Multiclass                        0.795142
# ToN_IoT_IoT_Thermostat_Multiclass                          0.895860
# ToN_IoT_IoT_Weather_Multiclass                             0.811934
# ToN_IoT_Linux_Disk_Multiclass                              0.921797
# ToN_IoT_Linux_Memory_Multiclass                            0.848177
# ToN_IoT_Linux_Process_Multiclass                           0.977646
# ToN_IoT_Network_Multiclass                                 0.899031
# ToN_IoT_Windows_10_Multiclass                              0.543334
# ToN_IoT_Windows_7_Multiclass                               0.639495
#
#                                                     class_proba_entropy_mean  \
# dataset_id
# CIC_IDS_2017_Multiclass                                             0.011386
# CIC_IOT_Dataset2023_Multiclass                                      0.420760
# IoT_23_Multiclass                                                   0.102997
# IoT_Network_Intrusion_Macro_Multiclass                              0.177656
# IoT_Network_Intrusion_Micro_Multiclass                              0.180365
# KDD_Cup_1999_Multiclass                                             0.008441
# UNSW_NB15_Multiclass                                                0.030661
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                           0.506687
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                      0.012546
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                              0.173779
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                               0.003018
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                  0.058332
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                          0.139039
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                       0.042958
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                            0.053226
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                            0.013105
# BoT_IoT_Macro_Multiclass                                            0.282183
# BoT_IoT_Micro_Multiclass                                            0.255616
# CICAPT_IIoT_Phase2_Macro_Multiclass                                 0.000068
# CICAPT_IIoT_Phase2_Micro_Multiclass                                 0.000000
# CICEVSE2024_EVSE-A_Macro_Multiclass                                 0.098256
# CICEVSE2024_EVSE-A_Micro_Multiclass                                 0.095943
# CICEVSE2024_EVSE-B_Macro_Multiclass                                 0.106584
# CICEVSE2024_EVSE-B_Micro_Multiclass                                 0.149141
# CICIoMT2024_Bluetooth_Multiclass                                    0.307124
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                0.205602
# CICIoV2024_Decimal_Macro_Multiclass                                 0.017508
# CICIoV2024_Decimal_Micro_Multiclass                                 0.037558
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                0.104360
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                 0.338012
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                          0.006582
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                          0.194609
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                         0.008782
# NIDS_CIC-BoT-IoT_Multiclass                                         0.402545
# NIDS_CIC-ToN-IoT_Multiclass                                         0.131772
# NIDS_NF-BoT-IoT_Multiclass                                          0.457807
# NIDS_NF-BoT-IoT-v2_Multiclass                                       0.232785
# NIDS_NF-BoT-IoT-v3_Multiclass                                       0.223599
# NIDS_NF-CICIDS2018-v3_Multiclass                                    0.015807
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                  0.130228
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                               0.027786
# NIDS_NF-ToN-IoT_Multiclass                                          0.515850
# NIDS_NF-ToN-IoT-v2_Multiclass                                       0.317032
# NIDS_NF-ToN-IoT-v3_Multiclass                                       0.236699
# NIDS_NF-UNSW-NB15_Multiclass                                        0.177832
# NIDS_NF-UNSW-NB15-v2_Multiclass                                     0.238778
# NIDS_NF-UNSW-NB15-v3_Multiclass                                     0.044684
# NIDS_NF-UQ-NIDS_Multiclass                                          0.390785
# NIDS_NF-UQ-NIDS-v2_Multiclass                                       0.218082
# N_BaIoT_Danmini_Doorbell_Multiclass                                 0.029961
# N_BaIoT_Ecobee_Thermostat_Multiclass                                0.050307
# N_BaIoT_Ennio_Doorbell_Multiclass                                   0.114318
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                     0.048300
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                  0.093179
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                  0.078696
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                        0.128619
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                  0.085651
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                  0.046558
# ToN_IoT_IoT_Fridge_Multiclass                                       0.935759
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                  0.738961
# ToN_IoT_IoT_Garage_Door_Multiclass                                  0.997420
# ToN_IoT_IoT_Modbus_Multiclass                                       0.345073
# ToN_IoT_IoT_Motion_Light_Multiclass                                 1.000000
# ToN_IoT_IoT_Thermostat_Multiclass                                   0.645120
# ToN_IoT_IoT_Weather_Multiclass                                      0.305217
# ToN_IoT_Linux_Disk_Multiclass                                       0.562816
# ToN_IoT_Linux_Memory_Multiclass                                     0.370597
# ToN_IoT_Linux_Process_Multiclass                                    0.667839
# ToN_IoT_Network_Multiclass                                          0.394511
# ToN_IoT_Windows_10_Multiclass                                       0.039639
# ToN_IoT_Windows_7_Multiclass                                        0.031701
#
#                                                     intrinsic_dimensionality_intrinsic_dimensionality_percent  \
# dataset_id
# CIC_IDS_2017_Multiclass                                                                      0.171429
# CIC_IOT_Dataset2023_Multiclass                                                               0.333333
# IoT_23_Multiclass                                                                            0.500000
# IoT_Network_Intrusion_Macro_Multiclass                                                       0.208333
# IoT_Network_Intrusion_Micro_Multiclass                                                       0.208333
# KDD_Cup_1999_Multiclass                                                                      0.200000
# UNSW_NB15_Multiclass                                                                         0.200000
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                                                    0.232877
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                                               0.159420
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                                       0.191781
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                                                        0.250000
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                                           0.239437
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                                                   0.260274
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                                                0.101449
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                                                     0.239437
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                                                     0.188406
# BoT_IoT_Macro_Multiclass                                                                     0.400000
# BoT_IoT_Micro_Multiclass                                                                     0.400000
# CICAPT_IIoT_Phase2_Macro_Multiclass                                                          0.187500
# CICAPT_IIoT_Phase2_Micro_Multiclass                                                          0.187500
# CICEVSE2024_EVSE-A_Macro_Multiclass                                                          0.161765
# CICEVSE2024_EVSE-A_Micro_Multiclass                                                          0.161765
# CICEVSE2024_EVSE-B_Macro_Multiclass                                                          0.073529
# CICEVSE2024_EVSE-B_Micro_Multiclass                                                          0.073529
# CICIoMT2024_Bluetooth_Multiclass                                                             0.428571
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                                         0.295455
# CICIoV2024_Decimal_Macro_Multiclass                                                          0.375000
# CICIoV2024_Decimal_Micro_Multiclass                                                          0.375000
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                                         0.244444
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                                          0.219512
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                                                   0.142857
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                                                   0.411765
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                                                  0.250000
# NIDS_CIC-BoT-IoT_Multiclass                                                                  0.139241
# NIDS_CIC-ToN-IoT_Multiclass                                                                  0.140845
# NIDS_NF-BoT-IoT_Multiclass                                                                   0.500000
# NIDS_NF-BoT-IoT-v2_Multiclass                                                                0.421053
# NIDS_NF-BoT-IoT-v3_Multiclass                                                                0.347826
# NIDS_NF-CICIDS2018-v3_Multiclass                                                             0.311111
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                                           0.400000
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                                        0.432432
# NIDS_NF-ToN-IoT_Multiclass                                                                   0.500000
# NIDS_NF-ToN-IoT-v2_Multiclass                                                                0.500000
# NIDS_NF-ToN-IoT-v3_Multiclass                                                                0.413043
# NIDS_NF-UNSW-NB15_Multiclass                                                                 0.500000
# NIDS_NF-UNSW-NB15-v2_Multiclass                                                              0.315789
# NIDS_NF-UNSW-NB15-v3_Multiclass                                                              0.239130
# NIDS_NF-UQ-NIDS_Multiclass                                                                   0.500000
# NIDS_NF-UQ-NIDS-v2_Multiclass                                                                0.500000
# N_BaIoT_Danmini_Doorbell_Multiclass                                                          0.113043
# N_BaIoT_Ecobee_Thermostat_Multiclass                                                         0.095652
# N_BaIoT_Ennio_Doorbell_Multiclass                                                            0.173913
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                                              0.121739
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                                           0.086957
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                                           0.086957
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                                                 0.147826
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                                           0.113043
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                                           0.130435
# ToN_IoT_IoT_Fridge_Multiclass                                                                1.000000
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                                           0.500000
# ToN_IoT_IoT_Garage_Door_Multiclass                                                           1.000000
# ToN_IoT_IoT_Modbus_Multiclass                                                                1.000000
# ToN_IoT_IoT_Motion_Light_Multiclass                                                          0.000000
# ToN_IoT_IoT_Thermostat_Multiclass                                                            0.500000
# ToN_IoT_IoT_Weather_Multiclass                                                               1.000000
# ToN_IoT_Linux_Disk_Multiclass                                                                0.600000
# ToN_IoT_Linux_Memory_Multiclass                                                              0.777778
# ToN_IoT_Linux_Process_Multiclass                                                             0.333333
# ToN_IoT_Network_Multiclass                                                                   0.225000
# ToN_IoT_Windows_10_Multiclass                                                                0.309735
# ToN_IoT_Windows_7_Multiclass                                                                 0.259615
#
#                                                     calinski_harabasz_calinski_harabasz_score  \
# dataset_id
# CIC_IDS_2017_Multiclass                                                              0.947096
# CIC_IOT_Dataset2023_Multiclass                                                       0.267942
# IoT_23_Multiclass                                                                    0.994567
# IoT_Network_Intrusion_Macro_Multiclass                                               0.998048
# IoT_Network_Intrusion_Micro_Multiclass                                               0.999078
# KDD_Cup_1999_Multiclass                                                              0.848160
# UNSW_NB15_Multiclass                                                                 0.950832
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                                            0.990906
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                                       0.743152
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                               0.959133
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                                                0.998288
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                                   0.924820
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                                           0.984747
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                                        0.146641
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                                             0.950215
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                                             0.759662
# BoT_IoT_Macro_Multiclass                                                             0.826635
# BoT_IoT_Micro_Multiclass                                                             0.799045
# CICAPT_IIoT_Phase2_Macro_Multiclass                                                  0.999911
# CICAPT_IIoT_Phase2_Micro_Multiclass                                                  0.999726
# CICEVSE2024_EVSE-A_Macro_Multiclass                                                  0.880517
# CICEVSE2024_EVSE-A_Micro_Multiclass                                                  0.873823
# CICEVSE2024_EVSE-B_Macro_Multiclass                                                  0.918689
# CICEVSE2024_EVSE-B_Micro_Multiclass                                                  0.937954
# CICIoMT2024_Bluetooth_Multiclass                                                     0.999951
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                                 0.000000
# CICIoV2024_Decimal_Macro_Multiclass                                                  0.999844
# CICIoV2024_Decimal_Micro_Multiclass                                                  0.999887
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                                 0.553819
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                                  0.946010
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                                           0.975986
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                                           0.996974
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                                          0.963923
# NIDS_CIC-BoT-IoT_Multiclass                                                          0.816073
# NIDS_CIC-ToN-IoT_Multiclass                                                          0.959879
# NIDS_NF-BoT-IoT_Multiclass                                                           0.983142
# NIDS_NF-BoT-IoT-v2_Multiclass                                                        0.972520
# NIDS_NF-BoT-IoT-v3_Multiclass                                                        0.832330
# NIDS_NF-CICIDS2018-v3_Multiclass                                                     0.443007
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                                   0.847583
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                                0.710491
# NIDS_NF-ToN-IoT_Multiclass                                                           0.985645
# NIDS_NF-ToN-IoT-v2_Multiclass                                                        0.937623
# NIDS_NF-ToN-IoT-v3_Multiclass                                                        0.804543
# NIDS_NF-UNSW-NB15_Multiclass                                                         0.989987
# NIDS_NF-UNSW-NB15-v2_Multiclass                                                      0.994717
# NIDS_NF-UNSW-NB15-v3_Multiclass                                                      0.978206
# NIDS_NF-UQ-NIDS_Multiclass                                                           0.984076
# NIDS_NF-UQ-NIDS-v2_Multiclass                                                        0.932784
# N_BaIoT_Danmini_Doorbell_Multiclass                                                  0.841406
# N_BaIoT_Ecobee_Thermostat_Multiclass                                                 0.819578
# ...
# CICEVSE2024_EVSE-B_Macro_Multiclass                                             5.820766e-01
# CICEVSE2024_EVSE-B_Micro_Multiclass                                             4.921849e-01
# CICIoMT2024_Bluetooth_Multiclass                                                4.406146e-02
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                            3.503420e-01
# CICIoV2024_Decimal_Macro_Multiclass                                             5.430710e-01
# CICIoV2024_Decimal_Micro_Multiclass                                             5.012959e-01
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                            5.865915e-01
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                             3.386748e-01
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                                      2.345317e-01
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                                      3.014553e-01
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                                     3.413942e-01
# NIDS_CIC-BoT-IoT_Multiclass                                                     5.533826e-01
# NIDS_CIC-ToN-IoT_Multiclass                                                     3.830728e-01
# NIDS_NF-BoT-IoT_Multiclass                                                      4.255993e-01
# NIDS_NF-BoT-IoT-v2_Multiclass                                                   3.415399e-01
# NIDS_NF-BoT-IoT-v3_Multiclass                                                   4.279846e-01
# NIDS_NF-CICIDS2018-v3_Multiclass                                                5.357732e-01
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                              3.859791e-01
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                           4.332875e-01
# NIDS_NF-ToN-IoT_Multiclass                                                      3.660410e-01
# NIDS_NF-ToN-IoT-v2_Multiclass                                                   4.602170e-01
# NIDS_NF-ToN-IoT-v3_Multiclass                                                   4.592937e-01
# NIDS_NF-UNSW-NB15_Multiclass                                                    5.755755e-01
# NIDS_NF-UNSW-NB15-v2_Multiclass                                                 7.606363e-01
# NIDS_NF-UNSW-NB15-v3_Multiclass                                                 7.067816e-01
# NIDS_NF-UQ-NIDS_Multiclass                                                      4.879188e-01
# NIDS_NF-UQ-NIDS-v2_Multiclass                                                   5.969848e-01
# N_BaIoT_Danmini_Doorbell_Multiclass                                             2.144657e-01
# N_BaIoT_Ecobee_Thermostat_Multiclass                                            2.413933e-01
# N_BaIoT_Ennio_Doorbell_Multiclass                                               2.685597e-01
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                                 2.566270e-01
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                              2.568599e-01
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                              2.563391e-01
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                                    3.000056e-01
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                              2.767913e-01
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                              2.451150e-01
# ToN_IoT_IoT_Fridge_Multiclass                                                   2.780060e-13
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                              1.304726e-01
# ToN_IoT_IoT_Garage_Door_Multiclass                                              2.791657e-01
# ToN_IoT_IoT_Modbus_Multiclass                                                   2.996803e-01
# ToN_IoT_IoT_Motion_Light_Multiclass                                             4.491833e-12
# ToN_IoT_IoT_Thermostat_Multiclass                                               2.794482e-01
# ToN_IoT_IoT_Weather_Multiclass                                                  3.434340e-01
# ToN_IoT_Linux_Disk_Multiclass                                                   1.989322e-01
# ToN_IoT_Linux_Memory_Multiclass                                                 2.770744e-01
# ToN_IoT_Linux_Process_Multiclass                                                1.780324e-01
# ToN_IoT_Network_Multiclass                                                      5.427143e-01
# ToN_IoT_Windows_10_Multiclass                                                   3.142523e-01
# ToN_IoT_Windows_7_Multiclass                                                    3.842997e-01
#
#                                                     overall_difficulty  \
# dataset_id
# CIC_IDS_2017_Multiclass                                       0.520255
# CIC_IOT_Dataset2023_Multiclass                                0.463287
# IoT_23_Multiclass                                             0.647499
# IoT_Network_Intrusion_Macro_Multiclass                        0.579553
# IoT_Network_Intrusion_Micro_Multiclass                        0.576441
# KDD_Cup_1999_Multiclass                                       0.531696
# UNSW_NB15_Multiclass                                          0.599471
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                     0.573121
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                0.519026
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                        0.549562
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                         0.462409
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...            0.491936
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                    0.591647
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                 0.361701
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                      0.549959
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                      0.569731
# BoT_IoT_Macro_Multiclass                                      0.615795
# BoT_IoT_Micro_Multiclass                                      0.562390
# CICAPT_IIoT_Phase2_Macro_Multiclass                           0.518937
# CICAPT_IIoT_Phase2_Micro_Multiclass                           0.520079
# CICEVSE2024_EVSE-A_Macro_Multiclass                           0.567041
# CICEVSE2024_EVSE-A_Micro_Multiclass                           0.415255
# CICEVSE2024_EVSE-B_Macro_Multiclass                           0.504142
# CICEVSE2024_EVSE-B_Micro_Multiclass                           0.479061
# CICIoMT2024_Bluetooth_Multiclass                              0.533200
# CICIoMT2024_WiFi_and_MQTT_Multiclass                          0.396530
# CICIoV2024_Decimal_Macro_Multiclass                           0.585195
# CICIoV2024_Decimal_Micro_Multiclass                           0.576157
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                          0.524616
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                           0.533113
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                    0.426659
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                    0.502061
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                   0.464252
# NIDS_CIC-BoT-IoT_Multiclass                                   0.598315
# NIDS_CIC-ToN-IoT_Multiclass                                   0.467870
# NIDS_NF-BoT-IoT_Multiclass                                    0.634641
# NIDS_NF-BoT-IoT-v2_Multiclass                                 0.534926
# NIDS_NF-BoT-IoT-v3_Multiclass                                 0.575140
# NIDS_NF-CICIDS2018-v3_Multiclass                              0.527612
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                            0.544996
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                         0.515294
# NIDS_NF-ToN-IoT_Multiclass                                    0.629313
# NIDS_NF-ToN-IoT-v2_Multiclass                                 0.581586
# NIDS_NF-ToN-IoT-v3_Multiclass                                 0.550117
# NIDS_NF-UNSW-NB15_Multiclass                                  0.622053
# NIDS_NF-UNSW-NB15-v2_Multiclass                               0.599751
# NIDS_NF-UNSW-NB15-v3_Multiclass                               0.545768
# NIDS_NF-UQ-NIDS_Multiclass                                    0.613918
# NIDS_NF-UQ-NIDS-v2_Multiclass                                 0.593507
# N_BaIoT_Danmini_Doorbell_Multiclass                           0.372621
# N_BaIoT_Ecobee_Thermostat_Multiclass                          0.396538
# N_BaIoT_Ennio_Doorbell_Multiclass                             0.490007
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass               0.386978
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...            0.399515
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...            0.391670
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                  0.439293
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...            0.398252
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...            0.407500
# ToN_IoT_IoT_Fridge_Multiclass                                 0.656552
# ToN_IoT_IoT_GPS_Tracker_Multiclass                            0.536309
# ToN_IoT_IoT_Garage_Door_Multiclass                            0.712334
# ToN_IoT_IoT_Modbus_Multiclass                                 0.652301
# ToN_IoT_IoT_Motion_Light_Multiclass                           0.579514
# ToN_IoT_IoT_Thermostat_Multiclass                             0.631765
# ToN_IoT_IoT_Weather_Multiclass                                0.654480
# ToN_IoT_Linux_Disk_Multiclass                                 0.622287
# ToN_IoT_Linux_Memory_Multiclass                               0.623067
# ToN_IoT_Linux_Process_Multiclass                              0.586126
# ToN_IoT_Network_Multiclass                                    0.607593
# ToN_IoT_Windows_10_Multiclass                                 0.431428
# ToN_IoT_Windows_7_Multiclass                                  0.473571
#
#                                                     metrics_used  groups_used
# dataset_id
# CIC_IDS_2017_Multiclass                                       10            5
# CIC_IOT_Dataset2023_Multiclass                                10            5
# IoT_23_Multiclass                                             10            5
# IoT_Network_Intrusion_Macro_Multiclass                        10            5
# IoT_Network_Intrusion_Micro_Multiclass                        10            5
# KDD_Cup_1999_Multiclass                                       10            5
# UNSW_NB15_Multiclass                                          10            5
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                     10            5
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                10            5
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                        10            5
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                         10            5
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...            10            5
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                    10            5
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                 10            5
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                      10            5
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                      10            5
# BoT_IoT_Macro_Multiclass                                      10            5
# BoT_IoT_Micro_Multiclass                                      10            5
# CICAPT_IIoT_Phase2_Macro_Multiclass                           10            5
# CICAPT_IIoT_Phase2_Micro_Multiclass                           10            5
# CICEVSE2024_EVSE-A_Macro_Multiclass                           10            5
# CICEVSE2024_EVSE-A_Micro_Multiclass                           10            5
# CICEVSE2024_EVSE-B_Macro_Multiclass                           10            5
# CICEVSE2024_EVSE-B_Micro_Multiclass                           10            5
# CICIoMT2024_Bluetooth_Multiclass                              10            5
# CICIoMT2024_WiFi_and_MQTT_Multiclass                          10            5
# CICIoV2024_Decimal_Macro_Multiclass                           10            5
# CICIoV2024_Decimal_Micro_Multiclass                           10            5
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                          10            5
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                           10            5
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                    10            5
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                    10            5
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                   10            5
# NIDS_CIC-BoT-IoT_Multiclass                                   10            5
# NIDS_CIC-ToN-IoT_Multiclass                                   10            5
# NIDS_NF-BoT-IoT_Multiclass                                    10            5
# NIDS_NF-BoT-IoT-v2_Multiclass                                 10            5
# NIDS_NF-BoT-IoT-v3_Multiclass                                 10            5
# NIDS_NF-CICIDS2018-v3_Multiclass                              10            5
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                            10            5
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                         10            5
# NIDS_NF-ToN-IoT_Multiclass                                    10            5
# NIDS_NF-ToN-IoT-v2_Multiclass                                 10            5
# NIDS_NF-ToN-IoT-v3_Multiclass                                 10            5
# NIDS_NF-UNSW-NB15_Multiclass                                  10            5
# NIDS_NF-UNSW-NB15-v2_Multiclass                               10            5
# NIDS_NF-UNSW-NB15-v3_Multiclass                               10            5
# NIDS_NF-UQ-NIDS_Multiclass                                    10            5
# NIDS_NF-UQ-NIDS-v2_Multiclass                                 10            5
# N_BaIoT_Danmini_Doorbell_Multiclass                           10            5
# N_BaIoT_Ecobee_Thermostat_Multiclass                          10            5
# N_BaIoT_Ennio_Doorbell_Multiclass                             10            5
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass               10            5
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...            10            5
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...            10            5
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                  10            5
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...            10            5
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...            10            5
# ToN_IoT_IoT_Fridge_Multiclass                                 10            5
# ToN_IoT_IoT_GPS_Tracker_Multiclass                            10            5
# ToN_IoT_IoT_Garage_Door_Multiclass                            10            5
# ToN_IoT_IoT_Modbus_Multiclass                                 10            5
# ToN_IoT_IoT_Motion_Light_Multiclass                            8            4
# ToN_IoT_IoT_Thermostat_Multiclass                             10            5
# ToN_IoT_IoT_Weather_Multiclass                                10            5
# ToN_IoT_Linux_Disk_Multiclass                                 10            5
# ToN_IoT_Linux_Memory_Multiclass                               10            5
# ToN_IoT_Linux_Process_Multiclass                              10            5
# ToN_IoT_Network_Multiclass                                    10            5
# ToN_IoT_Windows_10_Multiclass                                 10            5
# ToN_IoT_Windows_7_Multiclass                                  10            5

# %%
cols_to_drop = [
    "Feature_Relevance_difficulty", "Local_Overlap_difficulty", 
    "Boundary_Hardness_difficulty", "Global_Structure_difficulty", 
    "Class_Distribution_Separation_difficulty", 
    "metrics_used", "groups_used"
]

df_ordered_pretty = format_and_color_columns(
    df_ordered.drop(columns=cols_to_drop).loc[valid_order],
    color_map_dict={'overall_difficulty': 'RdYlGn_r'},
    alpha=0.5
)

with open("tables/table_2.tex", "w") as f:
    f.write(df_ordered_pretty.to_string())

df_ordered_pretty
# Out:
# /tmp/ipykernel_17604/3793402051.py:37: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '\cellcolor[rgb]{0.963, 0.985, 0.825} 0.520' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_colored.loc[i, col] = (
#                                                    anova_f_mean  \
# dataset_id
# CIC_IDS_2017_Multiclass                                   1.000
# CIC_IOT_Dataset2023_Multiclass                            0.996
# IoT_23_Multiclass                                         1.000
# IoT_Network_Intrusion_Macro_Multiclass                    1.000
# IoT_Network_Intrusion_Micro_Multiclass                    1.000
# KDD_Cup_1999_Multiclass                                   0.990
# UNSW_NB15_Multiclass                                      0.999
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                 1.000
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass            0.996
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                    1.000
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                     1.000
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...        0.999
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                1.000
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass             0.991
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                  1.000
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                  0.998
# BoT_IoT_Macro_Multiclass                                  0.999
# BoT_IoT_Micro_Multiclass                                  0.998
# CICAPT_IIoT_Phase2_Macro_Multiclass                       1.000
# CICAPT_IIoT_Phase2_Micro_Multiclass                       1.000
# CICEVSE2024_EVSE-A_Macro_Multiclass                       0.994
# CICEVSE2024_EVSE-A_Micro_Multiclass                       0.000
# CICEVSE2024_EVSE-B_Macro_Multiclass                       0.997
# CICEVSE2024_EVSE-B_Micro_Multiclass                       0.990
# CICIoMT2024_Bluetooth_Multiclass                          1.000
# CICIoMT2024_WiFi_and_MQTT_Multiclass                      0.990
# CICIoV2024_Decimal_Macro_Multiclass                       1.000
# CICIoV2024_Decimal_Micro_Multiclass                       1.000
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                      0.958
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                       0.991
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                0.967
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                1.000
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass               1.000
# NIDS_CIC-BoT-IoT_Multiclass                               0.999
# NIDS_CIC-ToN-IoT_Multiclass                               1.000
# NIDS_NF-BoT-IoT_Multiclass                                1.000
# NIDS_NF-BoT-IoT-v2_Multiclass                             1.000
# NIDS_NF-BoT-IoT-v3_Multiclass                             0.999
# NIDS_NF-CICIDS2018-v3_Multiclass                          0.998
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                        0.999
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                     0.995
# NIDS_NF-ToN-IoT_Multiclass                                1.000
# NIDS_NF-ToN-IoT-v2_Multiclass                             0.999
# NIDS_NF-ToN-IoT-v3_Multiclass                             0.998
# NIDS_NF-UNSW-NB15_Multiclass                              1.000
# NIDS_NF-UNSW-NB15-v2_Multiclass                           1.000
# NIDS_NF-UNSW-NB15-v3_Multiclass                           0.997
# NIDS_NF-UQ-NIDS_Multiclass                                1.000
# NIDS_NF-UQ-NIDS-v2_Multiclass                             1.000
# N_BaIoT_Danmini_Doorbell_Multiclass                       0.808
# N_BaIoT_Ecobee_Thermostat_Multiclass                      0.987
# N_BaIoT_Ennio_Doorbell_Multiclass                         0.994
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass           0.993
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...        0.999
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...        0.999
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass              0.991
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...        0.998
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...        0.980
# ToN_IoT_IoT_Fridge_Multiclass                             1.000
# ToN_IoT_IoT_GPS_Tracker_Multiclass                        1.000
# ToN_IoT_IoT_Garage_Door_Multiclass                        1.000
# ToN_IoT_IoT_Modbus_Multiclass                             1.000
# ToN_IoT_IoT_Motion_Light_Multiclass                       1.000
# ToN_IoT_IoT_Thermostat_Multiclass                         1.000
# ToN_IoT_IoT_Weather_Multiclass                            1.000
# ToN_IoT_Linux_Disk_Multiclass                             1.000
# ToN_IoT_Linux_Memory_Multiclass                           1.000
# ToN_IoT_Linux_Process_Multiclass                          1.000
# ToN_IoT_Network_Multiclass                                1.000
# ToN_IoT_Windows_10_Multiclass                             1.000
# ToN_IoT_Windows_7_Multiclass                              1.000
#
#                                                    mutual_info_mean  \
# dataset_id
# CIC_IDS_2017_Multiclass                                       0.821
# CIC_IOT_Dataset2023_Multiclass                                0.267
# IoT_23_Multiclass                                             0.815
# IoT_Network_Intrusion_Macro_Multiclass                        0.958
# IoT_Network_Intrusion_Micro_Multiclass                        0.953
# KDD_Cup_1999_Multiclass                                       0.736
# UNSW_NB15_Multiclass                                          0.937
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                     0.814
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                0.787
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                        0.673
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                         0.983
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...            0.542
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                    0.744
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                 0.229
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                      0.907
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                      0.900
# BoT_IoT_Macro_Multiclass                                      0.908
# BoT_IoT_Micro_Multiclass                                      0.469
# CICAPT_IIoT_Phase2_Macro_Multiclass                           1.000
# CICAPT_IIoT_Phase2_Micro_Multiclass                           1.000
# CICEVSE2024_EVSE-A_Macro_Multiclass                           0.346
# CICEVSE2024_EVSE-A_Micro_Multiclass                           0.164
# CICEVSE2024_EVSE-B_Macro_Multiclass                           0.332
# CICEVSE2024_EVSE-B_Micro_Multiclass                           0.120
# CICIoMT2024_Bluetooth_Multiclass                              0.872
# CICIoMT2024_WiFi_and_MQTT_Multiclass                          0.280
# CICIoV2024_Decimal_Macro_Multiclass                           0.959
# CICIoV2024_Decimal_Micro_Multiclass                           0.918
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                          0.711
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                           0.580
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                    0.321
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                    0.310
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                   0.411
# NIDS_CIC-BoT-IoT_Multiclass                                   0.928
# NIDS_CIC-ToN-IoT_Multiclass                                   0.483
# NIDS_NF-BoT-IoT_Multiclass                                    0.848
# NIDS_NF-BoT-IoT-v2_Multiclass                                 0.653
# NIDS_NF-BoT-IoT-v3_Multiclass                                 0.840
# NIDS_NF-CICIDS2018-v3_Multiclass                              0.826
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                            0.668
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                         0.590
# NIDS_NF-ToN-IoT_Multiclass                                    0.836
# NIDS_NF-ToN-IoT-v2_Multiclass                                 0.753
# NIDS_NF-ToN-IoT-v3_Multiclass                                 0.739
# NIDS_NF-UNSW-NB15_Multiclass                                  0.888
# NIDS_NF-UNSW-NB15-v2_Multiclass                               0.717
# NIDS_NF-UNSW-NB15-v3_Multiclass                               0.865
# NIDS_NF-UQ-NIDS_Multiclass                                    0.650
# NIDS_NF-UQ-NIDS-v2_Multiclass                                 0.672
# N_BaIoT_Danmini_Doorbell_Multiclass                           0.029
# N_BaIoT_Ecobee_Thermostat_Multiclass                          0.112
# N_BaIoT_Ennio_Doorbell_Multiclass                             0.350
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass               0.056
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...            0.139
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...            0.135
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                  0.214
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...            0.015
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...            0.112
# ToN_IoT_IoT_Fridge_Multiclass                                 1.000
# ToN_IoT_IoT_GPS_Tracker_Multiclass                            0.000
# ToN_IoT_IoT_Garage_Door_Multiclass                            0.875
# ToN_IoT_IoT_Modbus_Multiclass                                 0.997
# ToN_IoT_IoT_Motion_Light_Multiclass                           1.000
# ToN_IoT_IoT_Thermostat_Multiclass                             0.883
# ToN_IoT_IoT_Weather_Multiclass                                0.934
# ToN_IoT_Linux_Disk_Multiclass                                 0.881
# ToN_IoT_Linux_Memory_Multiclass                               0.930
# ToN_IoT_Linux_Process_Multiclass                              0.908
# ToN_IoT_Network_Multiclass                                    0.836
# ToN_IoT_Windows_10_Multiclass                                 0.612
# ToN_IoT_Windows_7_Multiclass                                  0.705
#
#                                                    pca_centroid_distance_pca_centroid_score  \
# dataset_id
# CIC_IDS_2017_Multiclass                                                               0.224
# CIC_IOT_Dataset2023_Multiclass                                                        0.128
# IoT_23_Multiclass                                                                     0.237
# IoT_Network_Intrusion_Macro_Multiclass                                                0.041
# IoT_Network_Intrusion_Micro_Multiclass                                                0.049
# KDD_Cup_1999_Multiclass                                                               0.107
# UNSW_NB15_Multiclass                                                                  0.066
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                                             0.051
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                                        0.227
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                                0.168
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                                                 0.096
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                                    0.112
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                                            0.193
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                                         0.067
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                                              0.084
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                                              0.983
# BoT_IoT_Macro_Multiclass                                                              0.187
# BoT_IoT_Micro_Multiclass                                                              0.205
# CICAPT_IIoT_Phase2_Macro_Multiclass                                                   0.029
# CICAPT_IIoT_Phase2_Micro_Multiclass                                                   0.041
# CICEVSE2024_EVSE-A_Macro_Multiclass                                                   1.000
# CICEVSE2024_EVSE-A_Micro_Multiclass                                                   0.811
# CICEVSE2024_EVSE-B_Macro_Multiclass                                                   0.281
# CICEVSE2024_EVSE-B_Micro_Multiclass                                                   0.232
# CICIoMT2024_Bluetooth_Multiclass                                                      0.002
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                                  0.147
# CICIoV2024_Decimal_Macro_Multiclass                                                   0.026
# CICIoV2024_Decimal_Micro_Multiclass                                                   0.022
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                                  0.246
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                                   0.094
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                                            0.078
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                                            0.026
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                                           0.056
# NIDS_CIC-BoT-IoT_Multiclass                                                           0.369
# NIDS_CIC-ToN-IoT_Multiclass                                                           0.143
# NIDS_NF-BoT-IoT_Multiclass                                                            0.057
# NIDS_NF-BoT-IoT-v2_Multiclass                                                         0.085
# NIDS_NF-BoT-IoT-v3_Multiclass                                                         0.329
# NIDS_NF-CICIDS2018-v3_Multiclass                                                      0.511
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                                    0.131
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                                 0.319
# NIDS_NF-ToN-IoT_Multiclass                                                            0.023
# NIDS_NF-ToN-IoT-v2_Multiclass                                                         0.096
# NIDS_NF-ToN-IoT-v3_Multiclass                                                         0.109
# NIDS_NF-UNSW-NB15_Multiclass                                                          0.063
# NIDS_NF-UNSW-NB15-v2_Multiclass                                                       0.062
# NIDS_NF-UNSW-NB15-v3_Multiclass                                                       0.056
# NIDS_NF-UQ-NIDS_Multiclass                                                            0.068
# NIDS_NF-UQ-NIDS-v2_Multiclass                                                         0.145
# N_BaIoT_Danmini_Doorbell_Multiclass                                                   0.367
# N_BaIoT_Ecobee_Thermostat_Multiclass                                                  0.300
# N_BaIoT_Ennio_Doorbell_Multiclass                                                     0.636
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                                       0.191
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                                    0.194
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                                    0.196
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                                          0.282
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                                    0.208
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                                    0.306
# ToN_IoT_IoT_Fridge_Multiclass                                                         0.000
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                                    0.000
# ToN_IoT_IoT_Garage_Door_Multiclass                                                    0.001
# ToN_IoT_IoT_Modbus_Multiclass                                                         0.002
# ToN_IoT_IoT_Motion_Light_Multiclass                                                   0.000
# ToN_IoT_IoT_Thermostat_Multiclass                                                     0.006
# ToN_IoT_IoT_Weather_Multiclass                                                        0.028
# ToN_IoT_Linux_Disk_Multiclass                                                         0.012
# ToN_IoT_Linux_Memory_Multiclass                                                       0.034
# ToN_IoT_Linux_Process_Multiclass                                                      0.017
# ToN_IoT_Network_Multiclass                                                            0.037
# ToN_IoT_Windows_10_Multiclass                                                         0.181
# ToN_IoT_Windows_7_Multiclass                                                          0.234
#
#                                                    mahalanobis_class_distance_mean  \
# dataset_id
# CIC_IDS_2017_Multiclass                                                      0.178
# CIC_IOT_Dataset2023_Multiclass                                               0.391
# IoT_23_Multiclass                                                            0.734
# IoT_Network_Intrusion_Macro_Multiclass                                       0.576
# IoT_Network_Intrusion_Micro_Multiclass                                       0.578
# KDD_Cup_1999_Multiclass                                                      0.549
# UNSW_NB15_Multiclass                                                         0.305
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                                    0.358
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                               0.504
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                       0.231
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                                        0.298
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                           0.417
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                                   0.566
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                                0.423
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                                     0.318
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                                     0.438
# BoT_IoT_Macro_Multiclass                                                     0.576
# BoT_IoT_Micro_Multiclass                                                     0.621
# CICAPT_IIoT_Phase2_Macro_Multiclass                                          0.321
# CICAPT_IIoT_Phase2_Micro_Multiclass                                          0.321
# CICEVSE2024_EVSE-A_Macro_Multiclass                                          0.684
# CICEVSE2024_EVSE-A_Micro_Multiclass                                          0.722
# CICEVSE2024_EVSE-B_Macro_Multiclass                                          0.495
# CICEVSE2024_EVSE-B_Micro_Multiclass                                          0.541
# CICIoMT2024_Bluetooth_Multiclass                                             0.705
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                         0.474
# CICIoV2024_Decimal_Macro_Multiclass                                          0.677
# CICIoV2024_Decimal_Micro_Multiclass                                          0.679
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                         0.525
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                          0.666
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                                   0.647
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                                   0.705
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                                  0.639
# NIDS_CIC-BoT-IoT_Multiclass                                                  0.260
# NIDS_CIC-ToN-IoT_Multiclass                                                  0.282
# NIDS_NF-BoT-IoT_Multiclass                                                   0.711
# NIDS_NF-BoT-IoT-v2_Multiclass                                                0.456
# NIDS_NF-BoT-IoT-v3_Multiclass                                                0.443
# NIDS_NF-CICIDS2018-v3_Multiclass                                             0.363
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                           0.702
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                        0.468
# NIDS_NF-ToN-IoT_Multiclass                                                   0.740
# NIDS_NF-ToN-IoT-v2_Multiclass                                                0.398
# NIDS_NF-ToN-IoT-v3_Multiclass                                                0.397
# NIDS_NF-UNSW-NB15_Multiclass                                                 0.666
# NIDS_NF-UNSW-NB15-v2_Multiclass                                              0.348
# NIDS_NF-UNSW-NB15-v3_Multiclass                                              0.325
# NIDS_NF-UQ-NIDS_Multiclass                                                   0.703
# NIDS_NF-UQ-NIDS-v2_Multiclass                                                0.433
# N_BaIoT_Danmini_Doorbell_Multiclass                                          0.406
# N_BaIoT_Ecobee_Thermostat_Multiclass                                         0.375
# N_BaIoT_Ennio_Doorbell_Multiclass                                            0.365
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                              0.388
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                           0.329
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                           0.307
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                                 0.415
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                           0.357
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                           0.371
# ToN_IoT_IoT_Fridge_Multiclass                                                0.825
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                           0.863
# ToN_IoT_IoT_Garage_Door_Multiclass                                           0.875
# ToN_IoT_IoT_Modbus_Multiclass                                                0.738
# ToN_IoT_IoT_Motion_Light_Multiclass                                          1.000
# ToN_IoT_IoT_Thermostat_Multiclass                                            0.830
# ToN_IoT_IoT_Weather_Multiclass                                               0.785
# ToN_IoT_Linux_Disk_Multiclass                                                0.848
# ToN_IoT_Linux_Memory_Multiclass                                              0.720
# ToN_IoT_Linux_Process_Multiclass                                             0.603
# ToN_IoT_Network_Multiclass                                                   0.635
# ToN_IoT_Windows_10_Multiclass                                                0.003
# ToN_IoT_Windows_7_Multiclass                                                 0.099
#
#                                                    svm_margin_mean  \
# dataset_id
# CIC_IDS_2017_Multiclass                                      0.706
# CIC_IOT_Dataset2023_Multiclass                               0.925
# IoT_23_Multiclass                                            0.769
# IoT_Network_Intrusion_Macro_Multiclass                       0.798
# IoT_Network_Intrusion_Micro_Multiclass                       0.803
# KDD_Cup_1999_Multiclass                                      0.694
# UNSW_NB15_Multiclass                                         0.616
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                    0.922
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass               0.681
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                       0.800
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                        0.000
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...           0.738
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                   0.783
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                0.669
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                     0.623
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                     0.666
# BoT_IoT_Macro_Multiclass                                     0.929
# BoT_IoT_Micro_Multiclass                                     0.914
# CICAPT_IIoT_Phase2_Macro_Multiclass                          0.652
# CICAPT_IIoT_Phase2_Micro_Multiclass                          0.651
# CICEVSE2024_EVSE-A_Macro_Multiclass                          0.710
# CICEVSE2024_EVSE-A_Micro_Multiclass                          0.729
# CICEVSE2024_EVSE-B_Macro_Multiclass                          0.673
# CICEVSE2024_EVSE-B_Micro_Multiclass                          0.763
# CICIoMT2024_Bluetooth_Multiclass                             0.930
# CICIoMT2024_WiFi_and_MQTT_Multiclass                         0.872
# CICIoV2024_Decimal_Macro_Multiclass                          0.712
# CICIoV2024_Decimal_Micro_Multiclass                          0.727
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                         0.731
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                          0.820
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                   0.659
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                   0.774
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                  0.631
# NIDS_CIC-BoT-IoT_Multiclass                                  0.962
# NIDS_CIC-ToN-IoT_Multiclass                                  0.774
# NIDS_NF-BoT-IoT_Multiclass                                   0.938
# NIDS_NF-BoT-IoT-v2_Multiclass                                0.845
# NIDS_NF-BoT-IoT-v3_Multiclass                                0.881
# NIDS_NF-CICIDS2018-v3_Multiclass                             0.737
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                           0.800
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                        0.744
# NIDS_NF-ToN-IoT_Multiclass                                   0.960
# NIDS_NF-ToN-IoT-v2_Multiclass                                0.894
# NIDS_NF-ToN-IoT-v3_Multiclass                                0.885
# NIDS_NF-UNSW-NB15_Multiclass                                 0.785
# NIDS_NF-UNSW-NB15-v2_Multiclass                              0.800
# NIDS_NF-UNSW-NB15-v3_Multiclass                              0.539
# NIDS_NF-UQ-NIDS_Multiclass                                   0.868
# NIDS_NF-UQ-NIDS-v2_Multiclass                                0.840
# N_BaIoT_Danmini_Doorbell_Multiclass                          0.703
# N_BaIoT_Ecobee_Thermostat_Multiclass                         0.743
# N_BaIoT_Ennio_Doorbell_Multiclass                            0.757
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass              0.733
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...           0.724
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...           0.697
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                 0.713
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...           0.751
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...           0.755
# ToN_IoT_IoT_Fridge_Multiclass                                0.805
# ToN_IoT_IoT_GPS_Tracker_Multiclass                           1.000
# ToN_IoT_IoT_Garage_Door_Multiclass                           0.816
# ToN_IoT_IoT_Modbus_Multiclass                                0.841
# ToN_IoT_IoT_Motion_Light_Multiclass                          0.795
# ToN_IoT_IoT_Thermostat_Multiclass                            0.896
# ToN_IoT_IoT_Weather_Multiclass                               0.812
# ToN_IoT_Linux_Disk_Multiclass                                0.922
# ToN_IoT_Linux_Memory_Multiclass                              0.848
# ToN_IoT_Linux_Process_Multiclass                             0.978
# ToN_IoT_Network_Multiclass                                   0.899
# ToN_IoT_Windows_10_Multiclass                                0.543
# ToN_IoT_Windows_7_Multiclass                                 0.639
#
#                                                    class_proba_entropy_mean  \
# dataset_id
# CIC_IDS_2017_Multiclass                                               0.011
# CIC_IOT_Dataset2023_Multiclass                                        0.421
# IoT_23_Multiclass                                                     0.103
# IoT_Network_Intrusion_Macro_Multiclass                                0.178
# IoT_Network_Intrusion_Micro_Multiclass                                0.180
# KDD_Cup_1999_Multiclass                                               0.008
# UNSW_NB15_Multiclass                                                  0.031
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                             0.507
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                        0.013
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                0.174
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                                 0.003
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                    0.058
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                            0.139
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                         0.043
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                              0.053
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                              0.013
# BoT_IoT_Macro_Multiclass                                              0.282
# BoT_IoT_Micro_Multiclass                                              0.256
# CICAPT_IIoT_Phase2_Macro_Multiclass                                   0.000
# CICAPT_IIoT_Phase2_Micro_Multiclass                                   0.000
# CICEVSE2024_EVSE-A_Macro_Multiclass                                   0.098
# CICEVSE2024_EVSE-A_Micro_Multiclass                                   0.096
# CICEVSE2024_EVSE-B_Macro_Multiclass                                   0.107
# CICEVSE2024_EVSE-B_Micro_Multiclass                                   0.149
# CICIoMT2024_Bluetooth_Multiclass                                      0.307
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                  0.206
# CICIoV2024_Decimal_Macro_Multiclass                                   0.018
# CICIoV2024_Decimal_Micro_Multiclass                                   0.038
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                  0.104
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                   0.338
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                            0.007
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                            0.195
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                           0.009
# NIDS_CIC-BoT-IoT_Multiclass                                           0.403
# NIDS_CIC-ToN-IoT_Multiclass                                           0.132
# NIDS_NF-BoT-IoT_Multiclass                                            0.458
# NIDS_NF-BoT-IoT-v2_Multiclass                                         0.233
# NIDS_NF-BoT-IoT-v3_Multiclass                                         0.224
# NIDS_NF-CICIDS2018-v3_Multiclass                                      0.016
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                    0.130
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                 0.028
# NIDS_NF-ToN-IoT_Multiclass                                            0.516
# NIDS_NF-ToN-IoT-v2_Multiclass                                         0.317
# NIDS_NF-ToN-IoT-v3_Multiclass                                         0.237
# NIDS_NF-UNSW-NB15_Multiclass                                          0.178
# NIDS_NF-UNSW-NB15-v2_Multiclass                                       0.239
# NIDS_NF-UNSW-NB15-v3_Multiclass                                       0.045
# NIDS_NF-UQ-NIDS_Multiclass                                            0.391
# NIDS_NF-UQ-NIDS-v2_Multiclass                                         0.218
# N_BaIoT_Danmini_Doorbell_Multiclass                                   0.030
# N_BaIoT_Ecobee_Thermostat_Multiclass                                  0.050
# N_BaIoT_Ennio_Doorbell_Multiclass                                     0.114
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                       0.048
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                    0.093
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                    0.079
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                          0.129
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                    0.086
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                    0.047
# ToN_IoT_IoT_Fridge_Multiclass                                         0.936
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                    0.739
# ToN_IoT_IoT_Garage_Door_Multiclass                                    0.997
# ToN_IoT_IoT_Modbus_Multiclass                                         0.345
# ToN_IoT_IoT_Motion_Light_Multiclass                                   1.000
# ToN_IoT_IoT_Thermostat_Multiclass                                     0.645
# ToN_IoT_IoT_Weather_Multiclass                                        0.305
# ToN_IoT_Linux_Disk_Multiclass                                         0.563
# ToN_IoT_Linux_Memory_Multiclass                                       0.371
# ToN_IoT_Linux_Process_Multiclass                                      0.668
# ToN_IoT_Network_Multiclass                                            0.395
# ToN_IoT_Windows_10_Multiclass                                         0.040
# ToN_IoT_Windows_7_Multiclass                                          0.032
#
#                                                    intrinsic_dimensionality_intrinsic_dimensionality_percent  \
# dataset_id
# CIC_IDS_2017_Multiclass                                                                         0.171
# CIC_IOT_Dataset2023_Multiclass                                                                  0.333
# IoT_23_Multiclass                                                                               0.500
# IoT_Network_Intrusion_Macro_Multiclass                                                          0.208
# IoT_Network_Intrusion_Micro_Multiclass                                                          0.208
# KDD_Cup_1999_Multiclass                                                                         0.200
# UNSW_NB15_Multiclass                                                                            0.200
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                                                       0.233
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                                                  0.159
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                                          0.192
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                                                           0.250
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                                              0.239
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                                                      0.260
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                                                   0.101
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                                                        0.239
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                                                        0.188
# BoT_IoT_Macro_Multiclass                                                                        0.400
# BoT_IoT_Micro_Multiclass                                                                        0.400
# CICAPT_IIoT_Phase2_Macro_Multiclass                                                             0.188
# CICAPT_IIoT_Phase2_Micro_Multiclass                                                             0.188
# CICEVSE2024_EVSE-A_Macro_Multiclass                                                             0.162
# CICEVSE2024_EVSE-A_Micro_Multiclass                                                             0.162
# CICEVSE2024_EVSE-B_Macro_Multiclass                                                             0.074
# CICEVSE2024_EVSE-B_Micro_Multiclass                                                             0.074
# CICIoMT2024_Bluetooth_Multiclass                                                                0.429
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                                            0.295
# CICIoV2024_Decimal_Macro_Multiclass                                                             0.375
# CICIoV2024_Decimal_Micro_Multiclass                                                             0.375
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                                            0.244
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                                             0.220
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                                                      0.143
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                                                      0.412
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                                                     0.250
# NIDS_CIC-BoT-IoT_Multiclass                                                                     0.139
# NIDS_CIC-ToN-IoT_Multiclass                                                                     0.141
# NIDS_NF-BoT-IoT_Multiclass                                                                      0.500
# NIDS_NF-BoT-IoT-v2_Multiclass                                                                   0.421
# NIDS_NF-BoT-IoT-v3_Multiclass                                                                   0.348
# NIDS_NF-CICIDS2018-v3_Multiclass                                                                0.311
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                                              0.400
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                                           0.432
# NIDS_NF-ToN-IoT_Multiclass                                                                      0.500
# NIDS_NF-ToN-IoT-v2_Multiclass                                                                   0.500
# NIDS_NF-ToN-IoT-v3_Multiclass                                                                   0.413
# NIDS_NF-UNSW-NB15_Multiclass                                                                    0.500
# NIDS_NF-UNSW-NB15-v2_Multiclass                                                                 0.316
# NIDS_NF-UNSW-NB15-v3_Multiclass                                                                 0.239
# NIDS_NF-UQ-NIDS_Multiclass                                                                      0.500
# NIDS_NF-UQ-NIDS-v2_Multiclass                                                                   0.500
# N_BaIoT_Danmini_Doorbell_Multiclass                                                             0.113
# N_BaIoT_Ecobee_Thermostat_Multiclass                                                            0.096
# N_BaIoT_Ennio_Doorbell_Multiclass                                                               0.174
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                                                 0.122
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                                              0.087
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                                              0.087
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                                                    0.148
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                                              0.113
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                                              0.130
# ToN_IoT_IoT_Fridge_Multiclass                                                                   1.000
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                                              0.500
# ToN_IoT_IoT_Garage_Door_Multiclass                                                              1.000
# ToN_IoT_IoT_Modbus_Multiclass                                                                   1.000
# ToN_IoT_IoT_Motion_Light_Multiclass                                                             0.000
# ToN_IoT_IoT_Thermostat_Multiclass                                                               0.500
# ToN_IoT_IoT_Weather_Multiclass                                                                  1.000
# ToN_IoT_Linux_Disk_Multiclass                                                                   0.600
# ToN_IoT_Linux_Memory_Multiclass                                                                 0.778
# ToN_IoT_Linux_Process_Multiclass                                                                0.333
# ToN_IoT_Network_Multiclass                                                                      0.225
# ToN_IoT_Windows_10_Multiclass                                                                   0.310
# ToN_IoT_Windows_7_Multiclass                                                                    0.260
#
#                                                    calinski_harabasz_calinski_harabasz_score  \
# dataset_id
# CIC_IDS_2017_Multiclass                                                                0.947
# CIC_IOT_Dataset2023_Multiclass                                                         0.268
# IoT_23_Multiclass                                                                      0.995
# IoT_Network_Intrusion_Macro_Multiclass                                                 0.998
# IoT_Network_Intrusion_Micro_Multiclass                                                 0.999
# KDD_Cup_1999_Multiclass                                                                0.848
# UNSW_NB15_Multiclass                                                                   0.951
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                                              0.991
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                                         0.743
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                                 0.959
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                                                  0.998
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                                     0.925
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                                             0.985
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                                          0.147
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                                               0.950
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                                               0.760
# BoT_IoT_Macro_Multiclass                                                               0.827
# BoT_IoT_Micro_Multiclass                                                               0.799
# CICAPT_IIoT_Phase2_Macro_Multiclass                                                    1.000
# CICAPT_IIoT_Phase2_Micro_Multiclass                                                    1.000
# CICEVSE2024_EVSE-A_Macro_Multiclass                                                    0.881
# CICEVSE2024_EVSE-A_Micro_Multiclass                                                    0.874
# CICEVSE2024_EVSE-B_Macro_Multiclass                                                    0.919
# CICEVSE2024_EVSE-B_Micro_Multiclass                                                    0.938
# CICIoMT2024_Bluetooth_Multiclass                                                       1.000
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                                   0.000
# CICIoV2024_Decimal_Macro_Multiclass                                                    1.000
# CICIoV2024_Decimal_Micro_Multiclass                                                    1.000
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                                   0.554
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                                    0.946
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                                             0.976
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                                             0.997
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                                            0.964
# NIDS_CIC-BoT-IoT_Multiclass                                                            0.816
# NIDS_CIC-ToN-IoT_Multiclass                                                            0.960
# NIDS_NF-BoT-IoT_Multiclass                                                             0.983
# NIDS_NF-BoT-IoT-v2_Multiclass                                                          0.973
# NIDS_NF-BoT-IoT-v3_Multiclass                                                          0.832
# NIDS_NF-CICIDS2018-v3_Multiclass                                                       0.443
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                                     0.848
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                                  0.710
# NIDS_NF-ToN-IoT_Multiclass                                                             0.986
# NIDS_NF-ToN-IoT-v2_Multiclass                                                          0.938
# NIDS_NF-ToN-IoT-v3_Multiclass                                                          0.805
# NIDS_NF-UNSW-NB15_Multiclass                                                           0.990
# NIDS_NF-UNSW-NB15-v2_Multiclass                                                        0.995
# NIDS_NF-UNSW-NB15-v3_Multiclass                                                        0.978
# NIDS_NF-UQ-NIDS_Multiclass                                                             0.984
# NIDS_NF-UQ-NIDS-v2_Multiclass                                                          0.933
# N_BaIoT_Danmini_Doorbell_Multiclass                                                    0.841
# N_BaIoT_Ecobee_Thermostat_Multiclass                                                   0.820
# N_BaIoT_Ennio_Doorbell_Multiclass                                                      0.971
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                                        0.825
# ...
# NIDS_NF-UNSW-NB15-v3_Multiclass                                                        0.585
# NIDS_NF-UQ-NIDS_Multiclass                                                             0.458
# NIDS_NF-UQ-NIDS-v2_Multiclass                                                          0.719
# N_BaIoT_Danmini_Doorbell_Multiclass                                                    0.227
# N_BaIoT_Ecobee_Thermostat_Multiclass                                                   0.274
# N_BaIoT_Ennio_Doorbell_Multiclass                                                      0.297
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                                        0.324
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                                     0.345
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                                     0.334
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                                           0.349
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                                     0.361
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                                     0.289
# ToN_IoT_IoT_Fridge_Multiclass                                                          0.000
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                                     0.000
# ToN_IoT_IoT_Garage_Door_Multiclass                                                     0.558
# ToN_IoT_IoT_Modbus_Multiclass                                                          0.000
# ToN_IoT_IoT_Motion_Light_Multiclass                                                    0.000
# ToN_IoT_IoT_Thermostat_Multiclass                                                      0.297
# ToN_IoT_IoT_Weather_Multiclass                                                         0.000
# ToN_IoT_Linux_Disk_Multiclass                                                          0.002
# ToN_IoT_Linux_Memory_Multiclass                                                        0.014
# ToN_IoT_Linux_Process_Multiclass                                                       0.079
# ToN_IoT_Network_Multiclass                                                             0.739
# ToN_IoT_Windows_10_Multiclass                                                          0.138
# ToN_IoT_Windows_7_Multiclass                                                           0.166
#
#                                                    class_imbalance_normalized_entropy  \
# dataset_id
# CIC_IDS_2017_Multiclass                                                         0.816
# CIC_IOT_Dataset2023_Multiclass                                                  0.144
# IoT_23_Multiclass                                                               0.765
# IoT_Network_Intrusion_Macro_Multiclass                                          0.706
# IoT_Network_Intrusion_Micro_Multiclass                                          0.795
# KDD_Cup_1999_Multiclass                                                         0.790
# UNSW_NB15_Multiclass                                                            0.890
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass                                       0.240
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass                                  0.753
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass                                          0.458
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass                                           0.901
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...                              0.358
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass                                      0.432
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass                                   0.442
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass                                        0.669
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass                                        0.468
# BoT_IoT_Macro_Multiclass                                                        0.474
# BoT_IoT_Micro_Multiclass                                                        0.322
# CICAPT_IIoT_Phase2_Macro_Multiclass                                             1.000
# CICAPT_IIoT_Phase2_Micro_Multiclass                                             1.000
# CICEVSE2024_EVSE-A_Macro_Multiclass                                             0.300
# CICEVSE2024_EVSE-A_Micro_Multiclass                                             0.255
# CICEVSE2024_EVSE-B_Macro_Multiclass                                             0.544
# CICEVSE2024_EVSE-B_Micro_Multiclass                                             0.404
# CICIoMT2024_Bluetooth_Multiclass                                                0.056
# CICIoMT2024_WiFi_and_MQTT_Multiclass                                            0.213
# CICIoV2024_Decimal_Macro_Multiclass                                             0.939
# CICIoV2024_Decimal_Micro_Multiclass                                             0.929
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                                            0.546
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                                             0.059
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass                                      0.309
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass                                      0.155
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass                                     0.390
# NIDS_CIC-BoT-IoT_Multiclass                                                     0.312
# NIDS_CIC-ToN-IoT_Multiclass                                                     0.541
# NIDS_NF-BoT-IoT_Multiclass                                                      0.234
# NIDS_NF-BoT-IoT-v2_Multiclass                                                   0.182
# NIDS_NF-BoT-IoT-v3_Multiclass                                                   0.431
# NIDS_NF-CICIDS2018-v3_Multiclass                                                0.825
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                                              0.727
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass                                           0.666
# NIDS_NF-ToN-IoT_Multiclass                                                      0.363
# NIDS_NF-ToN-IoT-v2_Multiclass                                                   0.258
# NIDS_NF-ToN-IoT-v3_Multiclass                                                   0.303
# NIDS_NF-UNSW-NB15_Multiclass                                                    0.758
# NIDS_NF-UNSW-NB15-v2_Multiclass                                                 0.554
# NIDS_NF-UNSW-NB15-v3_Multiclass                                                 0.829
# NIDS_NF-UQ-NIDS_Multiclass                                                      0.518
# NIDS_NF-UQ-NIDS-v2_Multiclass                                                   0.475
# N_BaIoT_Danmini_Doorbell_Multiclass                                             0.201
# N_BaIoT_Ecobee_Thermostat_Multiclass                                            0.209
# N_BaIoT_Ennio_Doorbell_Multiclass                                               0.240
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass                                 0.189
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...                              0.168
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...                              0.179
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass                                    0.251
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...                              0.193
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...                              0.201
# ToN_IoT_IoT_Fridge_Multiclass                                                   0.000
# ToN_IoT_IoT_GPS_Tracker_Multiclass                                              0.261
# ToN_IoT_IoT_Garage_Door_Multiclass                                              0.000
# ToN_IoT_IoT_Modbus_Multiclass                                                   0.599
# ToN_IoT_IoT_Motion_Light_Multiclass                                             0.000
# ToN_IoT_IoT_Thermostat_Multiclass                                               0.262
# ToN_IoT_IoT_Weather_Multiclass                                                  0.687
# ToN_IoT_Linux_Disk_Multiclass                                                   0.396
# ToN_IoT_Linux_Memory_Multiclass                                                 0.541
# ToN_IoT_Linux_Process_Multiclass                                                0.278
# ToN_IoT_Network_Multiclass                                                      0.346
# ToN_IoT_Windows_10_Multiclass                                                   0.491
# ToN_IoT_Windows_7_Multiclass                                                    0.602
#
#                                                                             overall_difficulty
# dataset_id
# CIC_IDS_2017_Multiclass                             \cellcolor[rgb]{0.963, 0.985, 0.825} 0.520
# CIC_IOT_Dataset2023_Multiclass                      \cellcolor[rgb]{0.813, 0.920, 0.706} 0.463
# IoT_23_Multiclass                                   \cellcolor[rgb]{0.970, 0.695, 0.623} 0.647
# IoT_Network_Intrusion_Macro_Multiclass              \cellcolor[rgb]{0.998, 0.916, 0.753} 0.580
# IoT_Network_Intrusion_Micro_Multiclass              \cellcolor[rgb]{0.998, 0.928, 0.763} 0.576
# KDD_Cup_1999_Multiclass                             \cellcolor[rgb]{0.990, 0.996, 0.861} 0.532
# UNSW_NB15_Multiclass                                \cellcolor[rgb]{0.997, 0.862, 0.708} 0.599
# BCCC_CIC-BCCC-NRC-ACI-IOT-2023_Multiclass           \cellcolor[rgb]{0.998, 0.935, 0.769} 0.573
# BCCC_CIC-BCCC-NRC-Edge-IIoTSet-2022_Multiclass      \cellcolor[rgb]{0.961, 0.983, 0.821} 0.519
# BCCC_CIC-BCCC-NRC-IoMT-2024_Multiclass              \cellcolor[rgb]{0.999, 0.977, 0.837} 0.550
# BCCC_CIC-BCCC-NRC-IoT-2022_Multiclass               \cellcolor[rgb]{0.808, 0.918, 0.706} 0.462
# BCCC_CIC-BCCC-NRC-IoT-2023-Original_Training_an...  \cellcolor[rgb]{0.898, 0.957, 0.755} 0.492
# BCCC_CIC-BCCC-NRC-IoT-HCRL-2019_Multiclass          \cellcolor[rgb]{0.997, 0.885, 0.727} 0.592
# BCCC_CIC-BCCC-NRC-MQTTIoT-IDS-2020_Multiclass       \cellcolor[rgb]{0.500, 0.704, 0.608} 0.362
# BCCC_CIC-BCCC-NRC-TONIoT-2021_Multiclass            \cellcolor[rgb]{0.999, 0.977, 0.837} 0.550
# BCCC_CIC-BCCC-NRC-UQ-IOT-2022_Multiclass            \cellcolor[rgb]{0.998, 0.944, 0.781} 0.570
# BoT_IoT_Macro_Multiclass                            \cellcolor[rgb]{0.992, 0.809, 0.675} 0.616
# BoT_IoT_Micro_Multiclass                            \cellcolor[rgb]{0.999, 0.956, 0.801} 0.562
# CICAPT_IIoT_Phase2_Macro_Multiclass                 \cellcolor[rgb]{0.961, 0.983, 0.821} 0.519
# CICAPT_IIoT_Phase2_Micro_Multiclass                 \cellcolor[rgb]{0.963, 0.985, 0.825} 0.520
# CICEVSE2024_EVSE-A_Macro_Multiclass                 \cellcolor[rgb]{0.998, 0.949, 0.789} 0.567
# CICEVSE2024_EVSE-A_Micro_Multiclass                 \cellcolor[rgb]{0.630, 0.836, 0.677} 0.415
# CICEVSE2024_EVSE-B_Macro_Multiclass                 \cellcolor[rgb]{0.928, 0.970, 0.777} 0.504
# CICEVSE2024_EVSE-B_Micro_Multiclass                 \cellcolor[rgb]{0.859, 0.940, 0.729} 0.479
# CICIoMT2024_Bluetooth_Multiclass                    \cellcolor[rgb]{0.993, 0.997, 0.865} 0.533
# CICIoMT2024_WiFi_and_MQTT_Multiclass                \cellcolor[rgb]{0.550, 0.796, 0.656} 0.397
# CICIoV2024_Decimal_Macro_Multiclass                 \cellcolor[rgb]{0.997, 0.901, 0.740} 0.585
# CICIoV2024_Decimal_Micro_Multiclass                 \cellcolor[rgb]{0.998, 0.928, 0.763} 0.576
# EDGE-IIOTSET_DNN-EdgeIIoT_Multiclass                \cellcolor[rgb]{0.972, 0.988, 0.837} 0.525
# EDGE-IIOTSET_ML-EdgeIIoT_Multiclass                 \cellcolor[rgb]{0.993, 0.997, 0.865} 0.533
# MQTT_IoT_IDS2020_BiflowFeatures_Multiclass          \cellcolor[rgb]{0.677, 0.859, 0.688} 0.427
# MQTT_IoT_IDS2020_PacketFeatures_Multiclass          \cellcolor[rgb]{0.925, 0.969, 0.773} 0.502
# MQTT_IoT_IDS2020_UniflowFeatures_Multiclass         \cellcolor[rgb]{0.813, 0.920, 0.706} 0.464
# NIDS_CIC-BoT-IoT_Multiclass                         \cellcolor[rgb]{0.997, 0.866, 0.711} 0.598
# NIDS_CIC-ToN-IoT_Multiclass                         \cellcolor[rgb]{0.827, 0.926, 0.709} 0.468
# NIDS_NF-BoT-IoT_Multiclass                          \cellcolor[rgb]{0.982, 0.739, 0.643} 0.635
# NIDS_NF-BoT-IoT-v2_Multiclass                       \cellcolor[rgb]{0.996, 0.998, 0.869} 0.535
# NIDS_NF-BoT-IoT-v3_Multiclass                       \cellcolor[rgb]{0.998, 0.932, 0.766} 0.575
# NIDS_NF-CICIDS2018-v3_Multiclass                    \cellcolor[rgb]{0.981, 0.992, 0.849} 0.528
# NIDS_NF-CSE-CIC-IDS2018_Multiclass                  \cellcolor[rgb]{1.000, 0.987, 0.853} 0.545
# NIDS_NF-CSE-CIC-IDS2018-v2_Multiclass               \cellcolor[rgb]{0.955, 0.981, 0.813} 0.515
# NIDS_NF-ToN-IoT_Multiclass                          \cellcolor[rgb]{0.985, 0.759, 0.652} 0.629
# NIDS_NF-ToN-IoT-v2_Multiclass                       \cellcolor[rgb]{0.998, 0.912, 0.750} 0.582
# NIDS_NF-ToN-IoT-v3_Multiclass                       \cellcolor[rgb]{0.999, 0.977, 0.837} 0.550
# NIDS_NF-UNSW-NB15_Multiclass                        \cellcolor[rgb]{0.988, 0.784, 0.664} 0.622
# NIDS_NF-UNSW-NB15-v2_Multiclass                     \cellcolor[rgb]{0.997, 0.862, 0.708} 0.600
# NIDS_NF-UNSW-NB15-v3_Multiclass                     \cellcolor[rgb]{1.000, 0.985, 0.849} 0.546
# NIDS_NF-UQ-NIDS_Multiclass                          \cellcolor[rgb]{0.992, 0.814, 0.678} 0.614
# NIDS_NF-UQ-NIDS-v2_Multiclass                       \cellcolor[rgb]{0.997, 0.878, 0.721} 0.594
# N_BaIoT_Danmini_Doorbell_Multiclass                 \cellcolor[rgb]{0.514, 0.730, 0.621} 0.373
# N_BaIoT_Ecobee_Thermostat_Multiclass                \cellcolor[rgb]{0.550, 0.796, 0.656} 0.397
# N_BaIoT_Ennio_Doorbell_Multiclass                   \cellcolor[rgb]{0.890, 0.953, 0.750} 0.490
# N_BaIoT_Philips_B120N10_Baby_Monitor_Multiclass     \cellcolor[rgb]{0.536, 0.770, 0.642} 0.387
# N_BaIoT_Provision_PT_737E_Security_Camera_Multi...  \cellcolor[rgb]{0.560, 0.802, 0.659} 0.400
# N_BaIoT_Provision_PT_838_Security_Camera_Multic...  \cellcolor[rgb]{0.542, 0.781, 0.648} 0.392
# N_BaIoT_Samsung_SNH_1011_N_Webcam_Multiclass        \cellcolor[rgb]{0.725, 0.881, 0.697} 0.439
# N_BaIoT_SimpleHome_XCS7_1002_WHT_Security_Camer...  \cellcolor[rgb]{0.554, 0.799, 0.658} 0.398
# N_BaIoT_SimpleHome_XCS7_1003_WHT_Security_Camer...  \cellcolor[rgb]{0.595, 0.819, 0.668} 0.407
# ToN_IoT_IoT_Fridge_Multiclass                       \cellcolor[rgb]{0.954, 0.662, 0.608} 0.657
# ToN_IoT_IoT_GPS_Tracker_Multiclass                  \cellcolor[rgb]{0.999, 0.999, 0.873} 0.536
# ToN_IoT_IoT_Garage_Door_Multiclass                  \cellcolor[rgb]{0.824, 0.500, 0.575} 0.712
# ToN_IoT_IoT_Modbus_Multiclass                       \cellcolor[rgb]{0.961, 0.676, 0.614} 0.652
# ToN_IoT_IoT_Motion_Light_Multiclass                 \cellcolor[rgb]{0.998, 0.916, 0.753} 0.580
# ToN_IoT_IoT_Thermostat_Multiclass                   \cellcolor[rgb]{0.983, 0.749, 0.648} 0.632
# ToN_IoT_IoT_Weather_Multiclass                      \cellcolor[rgb]{0.958, 0.672, 0.612} 0.654
# ToN_IoT_Linux_Disk_Multiclass                       \cellcolor[rgb]{0.988, 0.784, 0.664} 0.622
# ToN_IoT_Linux_Memory_Multiclass                     \cellcolor[rgb]{0.988, 0.784, 0.664} 0.623
# ToN_IoT_Linux_Process_Multiclass                    \cellcolor[rgb]{0.997, 0.901, 0.740} 0.586
# ToN_IoT_Network_Multiclass                          \cellcolor[rgb]{0.996, 0.839, 0.689} 0.608
# ToN_IoT_Windows_10_Multiclass                       \cellcolor[rgb]{0.694, 0.868, 0.693} 0.431
# ToN_IoT_Windows_7_Multiclass                        \cellcolor[rgb]{0.843, 0.933, 0.719} 0.474

# %%
# Compute min and max of overall_difficulty
vmin = df_ordered['overall_difficulty'].min()
vmax = df_ordered['overall_difficulty'].max()

# Select and style (don't include 'dataset_id' as it's now the index)
styled_df = df_ordered[['overall_difficulty', 'metrics_used', 'groups_used']].style \
    .background_gradient(subset=['overall_difficulty'], cmap='RdYlGn_r', vmin=vmin, vmax=vmax) \
    .format({'overall_difficulty': '{:.3f}'})

styled_df
